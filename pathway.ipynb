# %%
# 导入必要的库
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.tree import DecisionTreeClassifier
import torch
import numpy as np
import random
from sklearn.model_selection import StratifiedKFold, cross_val_predict
from sklearn.model_selection import cross_val_score
from sklearn.neural_network import MLPClassifier
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.impute import KNNImputer

# %%
seed=42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer

def drop_and_impute_knn(dataframe, threshold=0.2, n_neighbors=5):
    """
    删除 DataFrame 中除第一列外 0 的数量超过指定比例的特征，并对剩余特征使用 KNN 进行填充。
    
    :param dataframe: pandas DataFrame，要处理的数据。
    :param threshold: float, 0 的数量占比阈值，默认为 20%。
    :param n_neighbors: int, KNN 算法的邻居数量，默认为 5。
    :return: pandas DataFrame, 处理后的 DataFrame。
    """
    # 确认是一个 pandas DataFrame
    if not isinstance(dataframe, pd.DataFrame):
        raise ValueError("数据应该是 pandas DataFrame 类型。")
    
    # 分离第一列和其他列
    first_col = dataframe.iloc[:, 0]
    other_cols = dataframe.iloc[:, 1:]
    
    # 计算每个特征中 0 的占比
    zero_ratio = (other_cols == 0).mean()

    # 找出需要删除的特征
    cols_to_drop = zero_ratio[zero_ratio > threshold].index.tolist()
    
    # 删除超过阈值的特征
    dataframe_remaining = other_cols.drop(columns=cols_to_drop)
    
    # 将剩余的 0 替换为 np.nan，以便后续使用 KNNImputer 填充
    dataframe_remaining = dataframe_remaining.replace(0, np.nan)
    
    # 使用 KNNImputer 对剩余的 NaN 值进行填充
    imputer = KNNImputer(n_neighbors=n_neighbors)
    dataframe_imputed = pd.DataFrame(imputer.fit_transform(dataframe_remaining), columns=dataframe_remaining.columns)
    
    # 将填充后的数据与第一列合并
    result = pd.concat([first_col, dataframe_imputed], axis=1)
    
    return result

# %%
Methylation_pathgway = pd.read_csv('../../DATA/BRCA/GO_BRCA_Methylation.csv').sort_values('pvalue')
# 筛选 pvalue 小于 0.05 的行
Methylation_pathgway = Methylation_pathgway[Methylation_pathgway['pvalue'] < 0.05]
Methylation_pathgway
# Out:
#       Unnamed: 0          ID  \
# 0     GO:0048568  GO:0048568
# 1     GO:0060562  GO:0060562
# 2     GO:0048880  GO:0048880
# 3     GO:0009410  GO:0009410
# 4     GO:0150063  GO:0150063
# ...          ...         ...
# 2781  GO:0060038  GO:0060038
# 2782  GO:0032507  GO:0032507
# 2783  GO:0050771  GO:0050771
# 2784  GO:0050994  GO:0050994
# 2785  GO:1901224  GO:1901224
#
#                                             Description  GeneRatio    BgRatio  \
# 0                           embryonic organ development  428/14958  455/18888
# 1                         epithelial tube morphogenesis  321/14958  335/18888
# 2                            sensory system development  381/14958  403/18888
# 3                       response to xenobiotic stimulus  417/14958  444/18888
# 4                             visual system development  375/14958  397/18888
# ...                                                 ...        ...        ...
# 2781                  cardiac muscle cell proliferation   53/14958   60/18888
# 2782            maintenance of protein location in cell   58/14958   66/18888
# 2783                negative regulation of axonogenesis   58/14958   66/18888
# 2784              regulation of lipid catabolic process   58/14958   66/18888
# 2785  positive regulation of non-canonical NF-kappaB...   58/14958   66/18888
#
#       RichFactor  FoldEnrichment    zScore        pvalue      p.adjust  \
# 0       0.940659        1.187804  7.911061  2.560457e-19  1.627682e-15
# 1       0.958209        1.209965  7.564556  1.207893e-18  2.841966e-15
# 2       0.945409        1.193802  7.672263  1.765703e-18  2.841966e-15
# 3       0.939189        1.185948  7.735291  1.788243e-18  2.841966e-15
# 4       0.944584        1.192760  7.572771  5.252381e-18  6.677877e-15
# ...          ...             ...       ...           ...           ...
# 2781    0.883333        1.115416  1.746881  4.959483e-02  1.133265e-01
# 2782    0.878788        1.109677  1.741309  4.976146e-02  1.135440e-01
# 2783    0.878788        1.109677  1.741309  4.976146e-02  1.135440e-01
# 2784    0.878788        1.109677  1.741309  4.976146e-02  1.135440e-01
# 2785    0.878788        1.109677  1.741309  4.976146e-02  1.135440e-01
#
#             qvalue                                             geneID  Count
# 0     9.624621e-16  PROX1/SH2B3/RSPO3/HOXD3/HMX2/SHOX2/GJB6/MAPK1/...    428
# 1     1.680478e-15  SFRP1/PROX1/APAF1/COL4A1/WNT6/CSMD1/MTSS1/RNF2...    321
# 2     1.680478e-15  NPHP4/PROX1/ATOH7/TTC8/COL4A1/BARHL2/WNT6/NRL/...    381
# 3     1.680478e-15  SFRP1/PTK2B/FECH/THBS1/EHMT2/ABCC1/TP53I13/TGI...    417
# 4     3.948685e-15  NPHP4/PROX1/ATOH7/TTC8/COL4A1/BARHL2/WNT6/NRL/...    375
# ...            ...                                                ...    ...
# 2781  6.701091e-02  YAP1/HEY2/JARID2/ZFPM2/NOTCH1/GATA6/MAPK11/ABL...     53
# 2782  6.713953e-02  RER1/ANK3/TAF8/SYNE1/PARK7/VPS13D/OS9/TOPORS/T...     58
# 2783  6.713953e-02  DAB1/DCC/SEMA6B/EPHA7/MAP2/WNT3A/SPP1/SEMA5B/S...     58
# 2784  6.713953e-02  THRA/ALK/DAGLB/ADORA1/IRS2/TWIST1/SCT/ABCB11/P...     58
# 2785  6.713953e-02  TRIM56/IL12B/SASH1/NMI/RC3H2/RC3H1/TRIM26/IL23...     58
#
# [2786 rows x 13 columns]

# %%
# 读取制表符分隔的TSV文件
Methylation = pd.read_csv('../../DATA/BRCA/Human__TCGA_BRCA__JHU_USC__Methylation__Meth450__01_28_2016__BI__Gene__Firehose_Methylation_Prepocessor_common_samples.tsv', sep='\t')
Methylation = drop_and_impute_knn(Methylation)
# 显示 DataFrame
Methylation
# Out:
#        Unnamed: 0    RBL2   VDAC3   ACTN1  ATP2A1   SFRP1   NIPA2  MAN1B1  \
# 0    TCGA.D8.A1JH -0.4509  0.4213  0.0930  0.3937 -0.4201 -0.4868  0.3541
# 1    TCGA.OL.A5RW -0.4254 -0.4610  0.2416  0.3397 -0.4719 -0.4823  0.4368
# 2    TCGA.XX.A899 -0.4500 -0.4721  0.2597  0.4152  0.0244 -0.4843  0.4211
# 3    TCGA.S3.A6ZH -0.4691 -0.4842  0.3224  0.3773  0.0580 -0.4843  0.4313
# 4    TCGA.AQ.A54N -0.4274 -0.4688  0.3504  0.4143 -0.4804 -0.4821  0.4365
# ..            ...     ...     ...     ...     ...     ...     ...     ...
# 765  TCGA.GM.A5PX -0.4509 -0.4651  0.1044  0.3838 -0.2495 -0.4849  0.4210
# 766  TCGA.AC.A5XU -0.4519 -0.4496  0.2791  0.3522  0.0507 -0.4827  0.3946
# 767  TCGA.AR.A1AN -0.4365 -0.4557  0.2503  0.3619 -0.3741 -0.4859  0.4141
# 768  TCGA.E9.A1RG -0.4411 -0.4636  0.3023  0.3655 -0.4125 -0.4859  0.4484
# 769  TCGA.BH.A0GY -0.4040 -0.4451  0.2583  0.4197 -0.4713 -0.4898  0.4665
#
#      TSEN34  LRRC16A  ...   BAGE5    BAGE   BAGE2   BAGE4   BAGE3  MIR637  \
# 0   -0.4127  -0.4370  ...  0.2392  0.2392  0.2392  0.2392  0.2392  0.4185
# 1   -0.4491  -0.4721  ...  0.0235  0.0235  0.0235  0.0235  0.0235  0.3673
# 2   -0.4391  -0.4622  ...  0.1998  0.1998  0.1998  0.1998  0.1998  0.3908
# 3   -0.4730  -0.4724  ... -0.1330 -0.1330 -0.1330 -0.1330 -0.1330  0.3684
# 4   -0.4529  -0.4526  ...  0.0714  0.0714  0.0714  0.0714  0.0714  0.4140
# ..      ...      ...  ...     ...     ...     ...     ...     ...     ...
# 765 -0.4537  -0.4714  ...  0.0580  0.0580  0.0580  0.0580  0.0580  0.3742
# 766 -0.4647  -0.4718  ... -0.1007 -0.1007 -0.1007 -0.1007 -0.1007  0.3618
# 767 -0.4222  -0.4679  ...  0.1202  0.1202  0.1202  0.1202  0.1202  0.3812
# 768 -0.4481  -0.4766  ... -0.1603 -0.1603 -0.1603 -0.1603 -0.1603  0.4360
# 769 -0.4733  -0.4649  ...  0.1718  0.1718  0.1718  0.1718  0.1718  0.4258
#
#      LOC100130932  GOLGA8F  GOLGA8G   MIR7-1
# 0          0.3816   0.0083   0.0083 -0.31684
# 1          0.4267   0.0293   0.0293 -0.28100
# 2          0.4161  -0.0702  -0.0702 -0.25980
# 3          0.3430  -0.2010  -0.2010 -0.20920
# 4          0.3309   0.0635   0.0635 -0.32324
# ..            ...      ...      ...      ...
# 765        0.3665  -0.1194  -0.1194 -0.31230
# 766        0.4120  -0.2217  -0.2217 -0.36300
# 767        0.4325  -0.0542  -0.0542 -0.35290
# 768        0.4096  -0.1610  -0.1610 -0.35610
# 769        0.4433  -0.1414  -0.1414 -0.15630
#
# [770 rows x 20107 columns]

# %%
# 提取 geneID 列中每一行的基因ID，并存储为列表
gene_ids = Methylation_pathgway['geneID'].apply(lambda x: x.split('/'))
gene_ids
# Out:
# 0       [PROX1, SH2B3, RSPO3, HOXD3, HMX2, SHOX2, GJB6...
# 1       [SFRP1, PROX1, APAF1, COL4A1, WNT6, CSMD1, MTS...
# 2       [NPHP4, PROX1, ATOH7, TTC8, COL4A1, BARHL2, WN...
# 3       [SFRP1, PTK2B, FECH, THBS1, EHMT2, ABCC1, TP53...
# 4       [NPHP4, PROX1, ATOH7, TTC8, COL4A1, BARHL2, WN...
#                               ...
# 2781    [YAP1, HEY2, JARID2, ZFPM2, NOTCH1, GATA6, MAP...
# 2782    [RER1, ANK3, TAF8, SYNE1, PARK7, VPS13D, OS9, ...
# 2783    [DAB1, DCC, SEMA6B, EPHA7, MAP2, WNT3A, SPP1, ...
# 2784    [THRA, ALK, DAGLB, ADORA1, IRS2, TWIST1, SCT, ...
# 2785    [TRIM56, IL12B, SASH1, NMI, RC3H2, RC3H1, TRIM...
# Name: geneID, Length: 2786, dtype: object

# %%
# # 创建一个空的数据框来存储所有PCA结果
# BRCA_Methylation = pd.DataFrame()

# # 设置累计解释方差的阈值
# explained_variance_threshold = 0.95

# # 对每一行的基因数据进行PCA
# for i, gene_list in enumerate(gene_ids):
#     # 找到Methylation数据框中与gene_list对应的列
#     matching_columns = [col for col in Methylation.columns if col in gene_list]
#     # 提取这些列的数据
#     data = Methylation[matching_columns]
    
#     # 确保数据足够进行PCA（至少需要两个基因）
#     if len(matching_columns) > 1:
#         # 初始化PCA
#         pca = PCA()
#         pca.fit(data)
        
#         # 计算累计解释方差
#         cumulative_explained_variance = pca.explained_variance_ratio_.cumsum()
        
#         # 确定达到阈值的主成分数k
#         k = next(i for i, total_variance in enumerate(cumulative_explained_variance) if total_variance >= explained_variance_threshold) + 1
        
#         # 重新运行PCA，保留前k个主成分
#         pca = PCA(n_components=k)
#         pca_result = pca.fit_transform(data)
        
#         # 将PCA结果转换为DataFrame，并添加索引信息
#         pca_df = pd.DataFrame(pca_result, columns=[f'PC{j+1}_row_{i}' for j in range(k)])
        
#         # 合并PCA结果到总数据框
#         BRCA_Methylation = pd.concat([BRCA_Methylation, pca_df], axis=1)
#     else:
#         print(f"Row {i} does not have enough genes for PCA.")

# # 显示最终合并的PCA结果
# BRCA_Methylation

# %%
# # 创建一个空的数据框来存储所有PCA结果
# BRCA_Methylation = pd.DataFrame()

# # 对每一行的基因数据进行PCA
# for i, gene_list in enumerate(gene_ids):
#     # 找到Methylation数据框中与gene_list对应的列
#     matching_columns = [col for col in Methylation.columns if col in gene_list]
#     # 提取这些列的数据
#     data = Methylation[matching_columns]
    
#     # 确保数据足够进行PCA（至少需要两个基因）
#     if len(matching_columns) > 1:
#         # 初始化PCA，并指定n_components为1
#         pca = PCA(n_components=1)
#         pca_result = pca.fit_transform(data)
        
#         # 将PCA结果转换为DataFrame，并添加索引信息
#         pca_df = pd.DataFrame(pca_result, columns=[f'PC1_row_{i}'])
        
#         # 合并PCA结果到总数据框
#         BRCA_Methylation = pd.concat([BRCA_Methylation, pca_df], axis=1)
#     else:
#         print(f"Row {i} does not have enough genes for PCA.")

# # 显示最终合并的PCA结果
# BRCA_Methylation

# %%
# 创建一个空的数据框来存储所有结果
BRCA_Methylation = pd.DataFrame()

# 对每一行的基因数据进行拼接
for i, gene_list in enumerate(gene_ids):
    # 找到Methylation数据框中与gene_list对应的列
    matching_columns = [col for col in Methylation.columns if col in gene_list]
    
    # 去重，保留唯一的基因列
    unique_columns = list(dict.fromkeys(matching_columns))  # 保留顺序的去重方法
    
    # 提取这些唯一列的数据
    data = Methylation[unique_columns]
    
    # 确保有匹配到的基因列
    if len(unique_columns) > 0:
        # 检查是否有重复的列
        unique_columns_to_add = [col for col in unique_columns if col not in BRCA_Methylation.columns]
        
        # 如果没有重复列，将新列的数据直接拼接
        if unique_columns_to_add:
            data_to_add = data[unique_columns_to_add]
            BRCA_Methylation = pd.concat([BRCA_Methylation, data_to_add], axis=1)
        else:
            print(f"Row {i} does not have new unique columns to add.")
    else:
        print(f"Row {i} does not have matching genes to concatenate.")

# 显示最终拼接的结果
BRCA_Methylation
# Out:
# Row 4 does not have new unique columns to add.
# Row 5 does not have new unique columns to add.
# Row 7 does not have new unique columns to add.
# Row 10 does not have new unique columns to add.
# Row 14 does not have new unique columns to add.
# Row 16 does not have new unique columns to add.
# Row 26 does not have new unique columns to add.
# Row 35 does not have new unique columns to add.
# Row 40 does not have new unique columns to add.
# Row 43 does not have new unique columns to add.
# Row 47 does not have new unique columns to add.
# Row 50 does not have new unique columns to add.
# Row 51 does not have new unique columns to add.
# Row 62 does not have new unique columns to add.
# Row 64 does not have new unique columns to add.
# Row 65 does not have new unique columns to add.
# Row 67 does not have new unique columns to add.
# Row 68 does not have new unique columns to add.
# Row 69 does not have new unique columns to add.
# Row 70 does not have new unique columns to add.
# Row 73 does not have new unique columns to add.
# Row 74 does not have new unique columns to add.
# Row 80 does not have new unique columns to add.
# Row 85 does not have new unique columns to add.
# Row 87 does not have new unique columns to add.
# Row 92 does not have new unique columns to add.
# Row 94 does not have new unique columns to add.
# Row 95 does not have new unique columns to add.
# Row 105 does not have new unique columns to add.
# Row 106 does not have new unique columns to add.
# Row 110 does not have new unique columns to add.
# Row 113 does not have new unique columns to add.
# Row 115 does not have new unique columns to add.
# Row 120 does not have new unique columns to add.
# Row 122 does not have new unique columns to add.
# Row 124 does not have new unique columns to add.
# Row 129 does not have new unique columns to add.
# Row 135 does not have new unique columns to add.
# Row 136 does not have new unique columns to add.
# Row 137 does not have new unique columns to add.
# Row 139 does not have new unique columns to add.
# Row 141 does not have new unique columns to add.
# Row 146 does not have new unique columns to add.
# Row 149 does not have new unique columns to add.
# Row 151 does not have new unique columns to add.
# Row 153 does not have new unique columns to add.
# Row 154 does not have new unique columns to add.
# Row 156 does not have new unique columns to add.
# Row 158 does not have new unique columns to add.
# Row 160 does not have new unique columns to add.
# Row 162 does not have new unique columns to add.
# Row 163 does not have new unique columns to add.
# Row 166 does not have new unique columns to add.
# Row 168 does not have new unique columns to add.
# Row 170 does not have new unique columns to add.
# Row 172 does not have new unique columns to add.
# Row 173 does not have new unique columns to add.
# Row 174 does not have new unique columns to add.
# Row 175 does not have new unique columns to add.
# Row 176 does not have new unique columns to add.
# Row 178 does not have new unique columns to add.
# Row 179 does not have new unique columns to add.
# Row 182 does not have new unique columns to add.
# Row 184 does not have new unique columns to add.
# Row 188 does not have new unique columns to add.
# Row 192 does not have new unique columns to add.
# Row 193 does not have new unique columns to add.
# Row 194 does not have new unique columns to add.
# Row 195 does not have new unique columns to add.
# Row 200 does not have new unique columns to add.
# Row 202 does not have new unique columns to add.
# Row 203 does not have new unique columns to add.
# Row 204 does not have new unique columns to add.
# Row 207 does not have new unique columns to add.
# Row 208 does not have new unique columns to add.
# Row 209 does not have new unique columns to add.
# Row 210 does not have new unique columns to add.
# Row 212 does not have new unique columns to add.
# Row 216 does not have new unique columns to add.
# Row 217 does not have new unique columns to add.
# Row 218 does not have new unique columns to add.
# Row 220 does not have new unique columns to add.
# Row 221 does not have new unique columns to add.
# Row 224 does not have new unique columns to add.
# Row 225 does not have new unique columns to add.
# Row 227 does not have new unique columns to add.
# Row 231 does not have new unique columns to add.
# Row 233 does not have new unique columns to add.
# Row 234 does not have new unique columns to add.
# Row 235 does not have new unique columns to add.
# Row 237 does not have new unique columns to add.
# Row 238 does not have new unique columns to add.
# Row 239 does not have new unique columns to add.
# Row 241 does not have new unique columns to add.
# Row 243 does not have new unique columns to add.
# Row 244 does not have new unique columns to add.
# Row 245 does not have new unique columns to add.
# Row 249 does not have new unique columns to add.
# Row 251 does not have new unique columns to add.
# Row 254 does not have new unique columns to add.
# Row 256 does not have new unique columns to add.
# Row 257 does not have new unique columns to add.
# Row 259 does not have new unique columns to add.
# Row 260 does not have new unique columns to add.
# Row 261 does not have new unique columns to add.
# Row 262 does not have new unique columns to add.
# Row 263 does not have new unique columns to add.
# Row 264 does not have new unique columns to add.
# Row 265 does not have new unique columns to add.
# Row 266 does not have new unique columns to add.
# Row 269 does not have new unique columns to add.
# Row 270 does not have new unique columns to add.
# Row 273 does not have new unique columns to add.
# Row 275 does not have new unique columns to add.
# Row 277 does not have new unique columns to add.
# Row 278 does not have new unique columns to add.
# Row 279 does not have new unique columns to add.
# Row 280 does not have new unique columns to add.
# Row 281 does not have new unique columns to add.
# Row 282 does not have new unique columns to add.
# Row 284 does not have new unique columns to add.
# Row 286 does not have new unique columns to add.
# Row 290 does not have new unique columns to add.
# Row 291 does not have new unique columns to add.
# Row 292 does not have new unique columns to add.
# Row 293 does not have new unique columns to add.
# Row 298 does not have new unique columns to add.
# Row 299 does not have new unique columns to add.
# Row 301 does not have new unique columns to add.
# Row 302 does not have new unique columns to add.
# Row 303 does not have new unique columns to add.
# Row 304 does not have new unique columns to add.
# Row 305 does not have new unique columns to add.
# Row 307 does not have new unique columns to add.
# Row 308 does not have new unique columns to add.
# Row 309 does not have new unique columns to add.
# Row 310 does not have new unique columns to add.
# Row 311 does not have new unique columns to add.
# Row 314 does not have new unique columns to add.
# Row 315 does not have new unique columns to add.
# Row 318 does not have new unique columns to add.
# Row 320 does not have new unique columns to add.
# Row 321 does not have new unique columns to add.
# Row 322 does not have new unique columns to add.
# Row 323 does not have new unique columns to add.
# Row 324 does not have new unique columns to add.
# Row 325 does not have new unique columns to add.
# Row 326 does not have new unique columns to add.
# Row 327 does not have new unique columns to add.
# Row 328 does not have new unique columns to add.
# Row 329 does not have new unique columns to add.
# Row 330 does not have new unique columns to add.
# Row 332 does not have new unique columns to add.
# Row 333 does not have new unique columns to add.
# Row 334 does not have new unique columns to add.
# Row 335 does not have new unique columns to add.
# Row 337 does not have new unique columns to add.
# Row 338 does not have new unique columns to add.
# Row 339 does not have new unique columns to add.
# Row 341 does not have new unique columns to add.
# Row 342 does not have new unique columns to add.
# Row 343 does not have new unique columns to add.
# Row 344 does not have new unique columns to add.
# Row 346 does not have new unique columns to add.
# Row 347 does not have new unique columns to add.
# Row 349 does not have new unique columns to add.
# Row 351 does not have new unique columns to add.
# Row 352 does not have new unique columns to add.
# Row 355 does not have new unique columns to add.
# Row 356 does not have new unique columns to add.
# Row 359 does not have new unique columns to add.
# Row 360 does not have new unique columns to add.
# Row 362 does not have new unique columns to add.
# Row 363 does not have new unique columns to add.
# Row 365 does not have new unique columns to add.
# Row 366 does not have new unique columns to add.
# Row 367 does not have new unique columns to add.
# Row 368 does not have new unique columns to add.
# Row 370 does not have new unique columns to add.
# Row 371 does not have new unique columns to add.
# Row 376 does not have new unique columns to add.
# Row 383 does not have new unique columns to add.
# Row 384 does not have new unique columns to add.
# Row 385 does not have new unique columns to add.
# Row 386 does not have new unique columns to add.
# Row 388 does not have new unique columns to add.
# Row 389 does not have new unique columns to add.
# Row 393 does not have new unique columns to add.
# Row 396 does not have new unique columns to add.
# Row 397 does not have new unique columns to add.
# Row 398 does not have new unique columns to add.
# Row 401 does not have new unique columns to add.
# Row 402 does not have new unique columns to add.
# Row 403 does not have new unique columns to add.
# Row 405 does not have new unique columns to add.
# Row 406 does not have new unique columns to add.
# Row 408 does not have new unique columns to add.
# Row 409 does not have new unique columns to add.
# Row 410 does not have new unique columns to add.
# Row 411 does not have new unique columns to add.
# Row 413 does not have new unique columns to add.
# Row 414 does not have new unique columns to add.
# Row 415 does not have new unique columns to add.
# Row 416 does not have new unique columns to add.
# Row 418 does not have new unique columns to add.
# Row 419 does not have new unique columns to add.
# Row 420 does not have new unique columns to add.
# Row 421 does not have new unique columns to add.
# Row 422 does not have new unique columns to add.
# Row 423 does not have new unique columns to add.
# Row 424 does not have new unique columns to add.
# Row 425 does not have new unique columns to add.
# Row 426 does not have new unique columns to add.
# Row 428 does not have new unique columns to add.
# Row 429 does not have new unique columns to add.
# Row 430 does not have new unique columns to add.
# Row 431 does not have new unique columns to add.
# Row 432 does not have new unique columns to add.
# Row 433 does not have new unique columns to add.
# Row 436 does not have new unique columns to add.
# Row 437 does not have new unique columns to add.
# Row 438 does not have new unique columns to add.
# Row 440 does not have new unique columns to add.
# Row 441 does not have new unique columns to add.
# Row 443 does not have new unique columns to add.
# Row 444 does not have new unique columns to add.
# Row 445 does not have new unique columns to add.
# Row 446 does not have new unique columns to add.
# Row 448 does not have new unique columns to add.
# Row 450 does not have new unique columns to add.
# Row 451 does not have new unique columns to add.
# Row 452 does not have new unique columns to add.
# Row 454 does not have new unique columns to add.
# Row 460 does not have new unique columns to add.
# Row 461 does not have new unique columns to add.
# Row 463 does not have new unique columns to add.
# Row 464 does not have new unique columns to add.
# Row 465 does not have new unique columns to add.
# Row 466 does not have new unique columns to add.
# Row 468 does not have new unique columns to add.
# Row 469 does not have new unique columns to add.
# Row 470 does not have new unique columns to add.
# Row 474 does not have new unique columns to add.
# Row 475 does not have new unique columns to add.
# Row 476 does not have new unique columns to add.
# Row 477 does not have new unique columns to add.
# Row 478 does not have new unique columns to add.
# Row 479 does not have new unique columns to add.
# Row 481 does not have new unique columns to add.
# Row 483 does not have new unique columns to add.
# Row 484 does not have new unique columns to add.
# Row 487 does not have new unique columns to add.
# Row 488 does not have new unique columns to add.
# Row 489 does not have new unique columns to add.
# Row 490 does not have new unique columns to add.
# Row 491 does not have new unique columns to add.
# Row 492 does not have new unique columns to add.
# Row 493 does not have new unique columns to add.
# Row 494 does not have new unique columns to add.
# Row 495 does not have new unique columns to add.
# Row 496 does not have new unique columns to add.
# Row 497 does not have new unique columns to add.
# Row 498 does not have new unique columns to add.
# Row 499 does not have new unique columns to add.
# Row 501 does not have new unique columns to add.
# Row 502 does not have new unique columns to add.
# Row 505 does not have new unique columns to add.
# Row 506 does not have new unique columns to add.
# Row 508 does not have new unique columns to add.
# Row 510 does not have new unique columns to add.
# Row 512 does not have new unique columns to add.
# Row 514 does not have new unique columns to add.
# Row 515 does not have new unique columns to add.
# Row 516 does not have new unique columns to add.
# Row 517 does not have new unique columns to add.
# Row 518 does not have new unique columns to add.
# Row 519 does not have new unique columns to add.
# Row 520 does not have new unique columns to add.
# Row 522 does not have new unique columns to add.
# Row 523 does not have new unique columns to add.
# Row 524 does not have new unique columns to add.
# Row 525 does not have new unique columns to add.
# Row 526 does not have new unique columns to add.
# Row 527 does not have new unique columns to add.
# Row 528 does not have new unique columns to add.
# Row 531 does not have new unique columns to add.
# Row 532 does not have new unique columns to add.
# Row 533 does not have new unique columns to add.
# Row 534 does not have new unique columns to add.
# Row 535 does not have new unique columns to add.
# Row 536 does not have new unique columns to add.
# Row 537 does not have new unique columns to add.
# Row 540 does not have new unique columns to add.
# Row 541 does not have new unique columns to add.
# Row 542 does not have new unique columns to add.
# Row 543 does not have new unique columns to add.
# Row 545 does not have new unique columns to add.
# Row 546 does not have new unique columns to add.
# Row 548 does not have new unique columns to add.
# Row 549 does not have new unique columns to add.
# Row 550 does not have new unique columns to add.
# Row 551 does not have new unique columns to add.
# Row 552 does not have new unique columns to add.
# Row 553 does not have new unique columns to add.
# Row 554 does not have new unique columns to add.
# Row 556 does not have new unique columns to add.
# Row 557 does not have new unique columns to add.
# Row 560 does not have new unique columns to add.
# Row 561 does not have new unique columns to add.
# Row 563 does not have new unique columns to add.
# Row 565 does not have new unique columns to add.
# Row 566 does not have new unique columns to add.
# Row 567 does not have new unique columns to add.
# Row 568 does not have new unique columns to add.
# Row 569 does not have new unique columns to add.
# Row 570 does not have new unique columns to add.
# Row 571 does not have new unique columns to add.
# Row 572 does not have new unique columns to add.
# Row 573 does not have new unique columns to add.
# Row 574 does not have new unique columns to add.
# Row 575 does not have new unique columns to add.
# Row 576 does not have new unique columns to add.
# Row 577 does not have new unique columns to add.
# Row 578 does not have new unique columns to add.
# Row 579 does not have new unique columns to add.
# Row 580 does not have new unique columns to add.
# Row 581 does not have new unique columns to add.
# Row 582 does not have new unique columns to add.
# Row 584 does not have new unique columns to add.
# Row 586 does not have new unique columns to add.
# Row 587 does not have new unique columns to add.
# Row 588 does not have new unique columns to add.
# Row 589 does not have new unique columns to add.
# Row 591 does not have new unique columns to add.
# Row 592 does not have new unique columns to add.
# Row 593 does not have new unique columns to add.
# Row 594 does not have new unique columns to add.
# Row 595 does not have new unique columns to add.
# Row 596 does not have new unique columns to add.
# Row 597 does not have new unique columns to add.
# Row 599 does not have new unique columns to add.
# Row 600 does not have new unique columns to add.
# Row 601 does not have new unique columns to add.
# Row 602 does not have new unique columns to add.
# Row 605 does not have new unique columns to add.
# Row 606 does not have new unique columns to add.
# Row 607 does not have new unique columns to add.
# Row 609 does not have new unique columns to add.
# Row 610 does not have new unique columns to add.
# Row 611 does not have new unique columns to add.
# Row 612 does not have new unique columns to add.
# Row 613 does not have new unique columns to add.
# Row 614 does not have new unique columns to add.
# Row 616 does not have new unique columns to add.
# Row 617 does not have new unique columns to add.
# Row 619 does not have new unique columns to add.
# Row 620 does not have new unique columns to add.
# Row 621 does not have new unique columns to add.
# Row 623 does not have new unique columns to add.
# Row 624 does not have new unique columns to add.
# Row 625 does not have new unique columns to add.
# Row 626 does not have new unique columns to add.
# Row 627 does not have new unique columns to add.
# Row 628 does not have new unique columns to add.
# Row 629 does not have new unique columns to add.
# Row 631 does not have new unique columns to add.
# Row 632 does not have new unique columns to add.
# Row 633 does not have new unique columns to add.
# Row 634 does not have new unique columns to add.
# Row 636 does not have new unique columns to add.
# Row 637 does not have new unique columns to add.
# Row 638 does not have new unique columns to add.
# Row 639 does not have new unique columns to add.
# Row 640 does not have new unique columns to add.
# Row 641 does not have new unique columns to add.
# Row 642 does not have new unique columns to add.
# Row 643 does not have new unique columns to add.
# Row 645 does not have new unique columns to add.
# Row 646 does not have new unique columns to add.
# Row 648 does not have new unique columns to add.
# Row 650 does not have new unique columns to add.
# Row 651 does not have new unique columns to add.
# Row 652 does not have new unique columns to add.
# Row 653 does not have new unique columns to add.
# Row 654 does not have new unique columns to add.
# Row 655 does not have new unique columns to add.
# Row 656 does not have new unique columns to add.
# Row 657 does not have new unique columns to add.
# Row 658 does not have new unique columns to add.
# Row 661 does not have new unique columns to add.
# Row 662 does not have new unique columns to add.
# Row 663 does not have new unique columns to add.
# Row 665 does not have new unique columns to add.
# Row 666 does not have new unique columns to add.
# Row 667 does not have new unique columns to add.
# Row 668 does not have new unique columns to add.
# Row 672 does not have new unique columns to add.
# Row 674 does not have new unique columns to add.
# Row 675 does not have new unique columns to add.
# Row 676 does not have new unique columns to add.
# Row 677 does not have new unique columns to add.
# Row 678 does not have new unique columns to add.
# Row 679 does not have new unique columns to add.
# Row 681 does not have new unique columns to add.
# Row 682 does not have new unique columns to add.
# Row 684 does not have new unique columns to add.
# Row 686 does not have new unique columns to add.
# Row 687 does not have new unique columns to add.
# Row 688 does not have new unique columns to add.
# Row 689 does not have new unique columns to add.
# Row 690 does not have new unique columns to add.
# Row 691 does not have new unique columns to add.
# Row 692 does not have new unique columns to add.
# Row 693 does not have new unique columns to add.
# Row 695 does not have new unique columns to add.
# Row 696 does not have new unique columns to add.
# Row 697 does not have new unique columns to add.
# Row 698 does not have new unique columns to add.
# Row 699 does not have new unique columns to add.
# Row 700 does not have new unique columns to add.
# Row 701 does not have new unique columns to add.
# Row 702 does not have new unique columns to add.
# Row 703 does not have new unique columns to add.
# Row 704 does not have new unique columns to add.
# Row 705 does not have new unique columns to add.
# Row 707 does not have new unique columns to add.
# Row 708 does not have new unique columns to add.
# Row 709 does not have new unique columns to add.
# Row 710 does not have new unique columns to add.
# Row 711 does not have new unique columns to add.
# Row 712 does not have new unique columns to add.
# Row 713 does not have new unique columns to add.
# Row 714 does not have new unique columns to add.
# Row 715 does not have new unique columns to add.
# Row 717 does not have new unique columns to add.
# Row 718 does not have new unique columns to add.
# Row 719 does not have new unique columns to add.
# Row 720 does not have new unique columns to add.
# Row 721 does not have new unique columns to add.
# Row 722 does not have new unique columns to add.
# Row 724 does not have new unique columns to add.
# Row 726 does not have new unique columns to add.
# Row 728 does not have new unique columns to add.
# Row 730 does not have new unique columns to add.
# Row 731 does not have new unique columns to add.
# Row 732 does not have new unique columns to add.
# Row 733 does not have new unique columns to add.
# Row 734 does not have new unique columns to add.
# Row 735 does not have new unique columns to add.
# Row 736 does not have new unique columns to add.
# Row 737 does not have new unique columns to add.
# Row 738 does not have new unique columns to add.
# Row 740 does not have new unique columns to add.
# Row 741 does not have new unique columns to add.
# Row 742 does not have new unique columns to add.
# Row 744 does not have new unique columns to add.
# Row 745 does not have new unique columns to add.
# Row 747 does not have new unique columns to add.
# Row 750 does not have new unique columns to add.
# Row 752 does not have new unique columns to add.
# Row 754 does not have new unique columns to add.
# Row 755 does not have new unique columns to add.
# Row 756 does not have new unique columns to add.
# Row 757 does not have new unique columns to add.
# Row 758 does not have new unique columns to add.
# Row 759 does not have new unique columns to add.
# Row 760 does not have new unique columns to add.
# Row 761 does not have new unique columns to add.
# Row 763 does not have new unique columns to add.
# Row 764 does not have new unique columns to add.
# Row 765 does not have new unique columns to add.
# Row 766 does not have new unique columns to add.
# Row 767 does not have new unique columns to add.
# Row 769 does not have new unique columns to add.
# Row 770 does not have new unique columns to add.
# Row 771 does not have new unique columns to add.
# Row 772 does not have new unique columns to add.
# Row 773 does not have new unique columns to add.
# Row 775 does not have new unique columns to add.
# Row 777 does not have new unique columns to add.
# Row 779 does not have new unique columns to add.
# Row 780 does not have new unique columns to add.
# Row 781 does not have new unique columns to add.
# Row 782 does not have new unique columns to add.
# Row 783 does not have new unique columns to add.
# Row 785 does not have new unique columns to add.
# Row 787 does not have new unique columns to add.
# Row 788 does not have new unique columns to add.
# Row 789 does not have new unique columns to add.
# Row 790 does not have new unique columns to add.
# Row 791 does not have new unique columns to add.
# Row 792 does not have new unique columns to add.
# Row 794 does not have new unique columns to add.
# Row 797 does not have new unique columns to add.
# Row 798 does not have new unique columns to add.
# Row 799 does not have new unique columns to add.
# Row 800 does not have new unique columns to add.
# Row 803 does not have new unique columns to add.
# Row 804 does not have new unique columns to add.
# Row 805 does not have new unique columns to add.
# Row 806 does not have new unique columns to add.
# Row 807 does not have new unique columns to add.
# Row 808 does not have new unique columns to add.
# Row 809 does not have new unique columns to add.
# Row 810 does not have new unique columns to add.
# Row 811 does not have new unique columns to add.
# Row 812 does not have new unique columns to add.
# Row 813 does not have new unique columns to add.
# Row 814 does not have new unique columns to add.
# Row 815 does not have new unique columns to add.
# Row 816 does not have new unique columns to add.
# Row 817 does not have new unique columns to add.
# Row 818 does not have new unique columns to add.
# Row 819 does not have new unique columns to add.
# Row 820 does not have new unique columns to add.
# Row 822 does not have new unique columns to add.
# Row 823 does not have new unique columns to add.
# Row 824 does not have new unique columns to add.
# Row 825 does not have new unique columns to add.
# Row 826 does not have new unique columns to add.
# Row 827 does not have new unique columns to add.
# Row 828 does not have new unique columns to add.
# Row 832 does not have new unique columns to add.
# Row 833 does not have new unique columns to add.
# Row 835 does not have new unique columns to add.
# Row 836 does not have new unique columns to add.
# Row 837 does not have new unique columns to add.
# Row 839 does not have new unique columns to add.
# Row 840 does not have new unique columns to add.
# Row 844 does not have new unique columns to add.
# Row 846 does not have new unique columns to add.
# Row 847 does not have new unique columns to add.
# Row 848 does not have new unique columns to add.
# Row 849 does not have new unique columns to add.
# Row 851 does not have new unique columns to add.
# Row 852 does not have new unique columns to add.
# Row 853 does not have new unique columns to add.
# Row 854 does not have new unique columns to add.
# Row 856 does not have new unique columns to add.
# Row 859 does not have new unique columns to add.
# Row 860 does not have new unique columns to add.
# Row 861 does not have new unique columns to add.
# Row 862 does not have new unique columns to add.
# Row 863 does not have new unique columns to add.
# Row 864 does not have new unique columns to add.
# Row 865 does not have new unique columns to add.
# Row 866 does not have new unique columns to add.
# Row 867 does not have new unique columns to add.
# Row 868 does not have new unique columns to add.
# Row 869 does not have new unique columns to add.
# Row 870 does not have new unique columns to add.
# Row 871 does not have new unique columns to add.
# Row 872 does not have new unique columns to add.
# Row 873 does not have new unique columns to add.
# Row 874 does not have new unique columns to add.
# Row 875 does not have new unique columns to add.
# Row 876 does not have new unique columns to add.
# Row 877 does not have new unique columns to add.
# Row 879 does not have new unique columns to add.
# Row 880 does not have new unique columns to add.
# Row 881 does not have new unique columns to add.
# Row 882 does not have new unique columns to add.
# Row 883 does not have new unique columns to add.
# Row 884 does not have new unique columns to add.
# Row 885 does not have new unique columns to add.
# Row 886 does not have new unique columns to add.
# Row 887 does not have new unique columns to add.
# Row 888 does not have new unique columns to add.
# Row 889 does not have new unique columns to add.
# Row 890 does not have new unique columns to add.
# Row 891 does not have new unique columns to add.
# Row 892 does not have new unique columns to add.
# Row 893 does not have new unique columns to add.
# Row 894 does not have new unique columns to add.
# Row 895 does not have new unique columns to add.
# Row 896 does not have new unique columns to add.
# Row 897 does not have new unique columns to add.
# Row 898 does not have new unique columns to add.
# Row 899 does not have new unique columns to add.
# Row 900 does not have new unique columns to add.
# Row 901 does not have new unique columns to add.
# Row 902 does not have new unique columns to add.
# Row 903 does not have new unique columns to add.
# Row 904 does not have new unique columns to add.
# Row 905 does not have new unique columns to add.
# Row 906 does not have new unique columns to add.
# Row 907 does not have new unique columns to add.
# Row 908 does not have new unique columns to add.
# Row 909 does not have new unique columns to add.
# Row 910 does not have new unique columns to add.
# Row 911 does not have new unique columns to add.
# Row 912 does not have new unique columns to add.
# Row 913 does not have new unique columns to add.
# Row 914 does not have new unique columns to add.
# Row 915 does not have new unique columns to add.
# Row 916 does not have new unique columns to add.
# Row 917 does not have new unique columns to add.
# Row 918 does not have new unique columns to add.
# Row 919 does not have new unique columns to add.
# Row 920 does not have new unique columns to add.
# Row 921 does not have new unique columns to add.
# Row 922 does not have new unique columns to add.
# Row 923 does not have new unique columns to add.
# Row 924 does not have new unique columns to add.
# Row 925 does not have new unique columns to add.
# Row 926 does not have new unique columns to add.
# Row 927 does not have new unique columns to add.
# Row 928 does not have new unique columns to add.
# Row 929 does not have new unique columns to add.
# Row 930 does not have new unique columns to add.
# Row 931 does not have new unique columns to add.
# Row 932 does not have new unique columns to add.
# Row 933 does not have new unique columns to add.
# Row 934 does not have new unique columns to add.
# Row 935 does not have new unique columns to add.
# Row 936 does not have new unique columns to add.
# Row 937 does not have new unique columns to add.
# Row 939 does not have new unique columns to add.
# Row 940 does not have new unique columns to add.
# Row 941 does not have new unique columns to add.
# Row 942 does not have new unique columns to add.
# Row 943 does not have new unique columns to add.
# Row 944 does not have new unique columns to add.
# Row 945 does not have new unique columns to add.
# Row 946 does not have new unique columns to add.
# Row 947 does not have new unique columns to add.
# Row 948 does not have new unique columns to add.
# Row 949 does not have new unique columns to add.
# Row 950 does not have new unique columns to add.
# Row 951 does not have new unique columns to add.
# Row 952 does not have new unique columns to add.
# Row 953 does not have new unique columns to add.
# Row 954 does not have new unique columns to add.
# Row 955 does not have new unique columns to add.
# Row 956 does not have new unique columns to add.
# Row 957 does not have new unique columns to add.
# Row 958 does not have new unique columns to add.
# Row 960 does not have new unique columns to add.
# Row 962 does not have new unique columns to add.
# Row 963 does not have new unique columns to add.
# Row 964 does not have new unique columns to add.
# Row 965 does not have new unique columns to add.
# Row 966 does not have new unique columns to add.
# Row 967 does not have new unique columns to add.
# Row 968 does not have new unique columns to add.
# Row 969 does not have new unique columns to add.
# Row 970 does not have new unique columns to add.
# Row 971 does not have new unique columns to add.
# Row 972 does not have new unique columns to add.
# Row 973 does not have new unique columns to add.
# Row 974 does not have new unique columns to add.
# Row 975 does not have new unique columns to add.
# Row 976 does not have new unique columns to add.
# Row 977 does not have new unique columns to add.
# Row 979 does not have new unique columns to add.
# Row 980 does not have new unique columns to add.
# Row 981 does not have new unique columns to add.
# Row 985 does not have new unique columns to add.
# Row 986 does not have new unique columns to add.
# Row 987 does not have new unique columns to add.
# Row 988 does not have new unique columns to add.
# Row 989 does not have new unique columns to add.
# Row 990 does not have new unique columns to add.
# Row 991 does not have new unique columns to add.
# Row 992 does not have new unique columns to add.
# Row 993 does not have new unique columns to add.
# Row 994 does not have new unique columns to add.
# Row 995 does not have new unique columns to add.
# Row 996 does not have new unique columns to add.
# Row 997 does not have new unique columns to add.
# Row 998 does not have new unique columns to add.
# Row 999 does not have new unique columns to add.
# Row 1000 does not have new unique columns to add.
# Row 1001 does not have new unique columns to add.
# Row 1002 does not have new unique columns to add.
# Row 1003 does not have new unique columns to add.
# Row 1004 does not have new unique columns to add.
# Row 1006 does not have new unique columns to add.
# Row 1008 does not have new unique columns to add.
# Row 1009 does not have new unique columns to add.
# Row 1010 does not have new unique columns to add.
# Row 1011 does not have new unique columns to add.
# Row 1012 does not have new unique columns to add.
# Row 1013 does not have new unique columns to add.
# Row 1014 does not have new unique columns to add.
# Row 1015 does not have new unique columns to add.
# Row 1017 does not have new unique columns to add.
# Row 1018 does not have new unique columns to add.
# Row 1021 does not have new unique columns to add.
# Row 1022 does not have new unique columns to add.
# Row 1023 does not have new unique columns to add.
# Row 1024 does not have new unique columns to add.
# Row 1025 does not have new unique columns to add.
# Row 1026 does not have new unique columns to add.
# Row 1027 does not have new unique columns to add.
# Row 1028 does not have new unique columns to add.
# Row 1029 does not have new unique columns to add.
# Row 1030 does not have new unique columns to add.
# Row 1031 does not have new unique columns to add.
# Row 1033 does not have new unique columns to add.
# Row 1035 does not have new unique columns to add.
# Row 1036 does not have new unique columns to add.
# Row 1037 does not have new unique columns to add.
# Row 1038 does not have new unique columns to add.
# Row 1039 does not have new unique columns to add.
# Row 1040 does not have new unique columns to add.
# Row 1041 does not have new unique columns to add.
# Row 1042 does not have new unique columns to add.
# Row 1044 does not have new unique columns to add.
# Row 1045 does not have new unique columns to add.
# Row 1046 does not have new unique columns to add.
# Row 1047 does not have new unique columns to add.
# Row 1048 does not have new unique columns to add.
# Row 1049 does not have new unique columns to add.
# Row 1050 does not have new unique columns to add.
# Row 1051 does not have new unique columns to add.
# Row 1052 does not have new unique columns to add.
# Row 1053 does not have new unique columns to add.
# Row 1054 does not have new unique columns to add.
# Row 1055 does not have new unique columns to add.
# Row 1056 does not have new unique columns to add.
# Row 1057 does not have new unique columns to add.
# Row 1058 does not have new unique columns to add.
# Row 1059 does not have new unique columns to add.
# Row 1060 does not have new unique columns to add.
# Row 1061 does not have new unique columns to add.
# Row 1062 does not have new unique columns to add.
# Row 1063 does not have new unique columns to add.
# Row 1064 does not have new unique columns to add.
# Row 1065 does not have new unique columns to add.
# Row 1066 does not have new unique columns to add.
# Row 1067 does not have new unique columns to add.
# Row 1068 does not have new unique columns to add.
# Row 1069 does not have new unique columns to add.
# Row 1071 does not have new unique columns to add.
# Row 1072 does not have new unique columns to add.
# Row 1073 does not have new unique columns to add.
# Row 1074 does not have new unique columns to add.
# Row 1075 does not have new unique columns to add.
# Row 1076 does not have new unique columns to add.
# Row 1077 does not have new unique columns to add.
# Row 1078 does not have new unique columns to add.
# Row 1079 does not have new unique columns to add.
# Row 1080 does not have new unique columns to add.
# Row 1082 does not have new unique columns to add.
# Row 1083 does not have new unique columns to add.
# Row 1084 does not have new unique columns to add.
# Row 1085 does not have new unique columns to add.
# Row 1086 does not have new unique columns to add.
# Row 1087 does not have new unique columns to add.
# Row 1089 does not have new unique columns to add.
# Row 1090 does not have new unique columns to add.
# Row 1091 does not have new unique columns to add.
# Row 1093 does not have new unique columns to add.
# Row 1094 does not have new unique columns to add.
# Row 1095 does not have new unique columns to add.
# Row 1096 does not have new unique columns to add.
# Row 1097 does not have new unique columns to add.
# Row 1098 does not have new unique columns to add.
# Row 1100 does not have new unique columns to add.
# Row 1101 does not have new unique columns to add.
# Row 1102 does not have new unique columns to add.
# Row 1103 does not have new unique columns to add.
# Row 1105 does not have new unique columns to add.
# Row 1106 does not have new unique columns to add.
# Row 1107 does not have new unique columns to add.
# Row 1108 does not have new unique columns to add.
# Row 1110 does not have new unique columns to add.
# Row 1112 does not have new unique columns to add.
# Row 1113 does not have new unique columns to add.
# Row 1114 does not have new unique columns to add.
# Row 1115 does not have new unique columns to add.
# Row 1116 does not have new unique columns to add.
# Row 1117 does not have new unique columns to add.
# Row 1118 does not have new unique columns to add.
# Row 1119 does not have new unique columns to add.
# Row 1120 does not have new unique columns to add.
# Row 1121 does not have new unique columns to add.
# Row 1122 does not have new unique columns to add.
# Row 1123 does not have new unique columns to add.
# Row 1124 does not have new unique columns to add.
# Row 1125 does not have new unique columns to add.
# Row 1126 does not have new unique columns to add.
# Row 1127 does not have new unique columns to add.
# Row 1129 does not have new unique columns to add.
# Row 1130 does not have new unique columns to add.
# Row 1131 does not have new unique columns to add.
# Row 1132 does not have new unique columns to add.
# Row 1133 does not have new unique columns to add.
# Row 1134 does not have new unique columns to add.
# Row 1135 does not have new unique columns to add.
# Row 1136 does not have new unique columns to add.
# Row 1137 does not have new unique columns to add.
# Row 1138 does not have new unique columns to add.
# Row 1139 does not have new unique columns to add.
# Row 1140 does not have new unique columns to add.
# Row 1141 does not have new unique columns to add.
# Row 1142 does not have new unique columns to add.
# Row 1143 does not have new unique columns to add.
# Row 1144 does not have new unique columns to add.
# Row 1145 does not have new unique columns to add.
# Row 1146 does not have new unique columns to add.
# Row 1148 does not have new unique columns to add.
# Row 1149 does not have new unique columns to add.
# Row 1150 does not have new unique columns to add.
# Row 1151 does not have new unique columns to add.
# Row 1152 does not have new unique columns to add.
# Row 1153 does not have new unique columns to add.
# Row 1154 does not have new unique columns to add.
# Row 1155 does not have new unique columns to add.
# Row 1156 does not have new unique columns to add.
# Row 1157 does not have new unique columns to add.
# Row 1158 does not have new unique columns to add.
# Row 1159 does not have new unique columns to add.
# Row 1160 does not have new unique columns to add.
# Row 1161 does not have new unique columns to add.
# Row 1162 does not have new unique columns to add.
# Row 1163 does not have new unique columns to add.
# Row 1164 does not have new unique columns to add.
# Row 1165 does not have new unique columns to add.
# Row 1166 does not have new unique columns to add.
# Row 1167 does not have new unique columns to add.
# Row 1169 does not have new unique columns to add.
# Row 1171 does not have new unique columns to add.
# Row 1172 does not have new unique columns to add.
# Row 1173 does not have new unique columns to add.
# Row 1174 does not have new unique columns to add.
# Row 1175 does not have new unique columns to add.
# Row 1177 does not have new unique columns to add.
# Row 1178 does not have new unique columns to add.
# Row 1179 does not have new unique columns to add.
# Row 1180 does not have new unique columns to add.
# Row 1181 does not have new unique columns to add.
# Row 1182 does not have new unique columns to add.
# Row 1183 does not have new unique columns to add.
# Row 1184 does not have new unique columns to add.
# Row 1185 does not have new unique columns to add.
# Row 1186 does not have new unique columns to add.
# Row 1187 does not have new unique columns to add.
# Row 1188 does not have new unique columns to add.
# Row 1191 does not have new unique columns to add.
# Row 1192 does not have new unique columns to add.
# Row 1193 does not have new unique columns to add.
# Row 1194 does not have new unique columns to add.
# Row 1195 does not have new unique columns to add.
# Row 1196 does not have new unique columns to add.
# Row 1197 does not have new unique columns to add.
# Row 1198 does not have new unique columns to add.
# Row 1199 does not have new unique columns to add.
# Row 1200 does not have new unique columns to add.
# Row 1201 does not have new unique columns to add.
# Row 1202 does not have new unique columns to add.
# Row 1203 does not have new unique columns to add.
# Row 1204 does not have new unique columns to add.
# Row 1205 does not have new unique columns to add.
# Row 1206 does not have new unique columns to add.
# Row 1207 does not have new unique columns to add.
# Row 1208 does not have new unique columns to add.
# Row 1209 does not have new unique columns to add.
# Row 1210 does not have new unique columns to add.
# Row 1211 does not have new unique columns to add.
# Row 1212 does not have new unique columns to add.
# Row 1213 does not have new unique columns to add.
# Row 1216 does not have new unique columns to add.
# Row 1217 does not have new unique columns to add.
# Row 1218 does not have new unique columns to add.
# Row 1219 does not have new unique columns to add.
# Row 1220 does not have new unique columns to add.
# Row 1221 does not have new unique columns to add.
# Row 1222 does not have new unique columns to add.
# Row 1223 does not have new unique columns to add.
# Row 1224 does not have new unique columns to add.
# Row 1226 does not have new unique columns to add.
# Row 1227 does not have new unique columns to add.
# Row 1228 does not have new unique columns to add.
# Row 1229 does not have new unique columns to add.
# Row 1230 does not have new unique columns to add.
# Row 1231 does not have new unique columns to add.
# Row 1232 does not have new unique columns to add.
# Row 1233 does not have new unique columns to add.
# Row 1234 does not have new unique columns to add.
# Row 1237 does not have new unique columns to add.
# Row 1238 does not have new unique columns to add.
# Row 1239 does not have new unique columns to add.
# Row 1240 does not have new unique columns to add.
# Row 1242 does not have new unique columns to add.
# Row 1243 does not have new unique columns to add.
# Row 1244 does not have new unique columns to add.
# Row 1245 does not have new unique columns to add.
# Row 1247 does not have new unique columns to add.
# Row 1248 does not have new unique columns to add.
# Row 1249 does not have new unique columns to add.
# Row 1250 does not have new unique columns to add.
# Row 1251 does not have new unique columns to add.
# Row 1252 does not have new unique columns to add.
# Row 1254 does not have new unique columns to add.
# Row 1255 does not have new unique columns to add.
# Row 1256 does not have new unique columns to add.
# Row 1257 does not have new unique columns to add.
# Row 1258 does not have new unique columns to add.
# Row 1259 does not have new unique columns to add.
# Row 1260 does not have new unique columns to add.
# Row 1261 does not have new unique columns to add.
# Row 1262 does not have new unique columns to add.
# Row 1263 does not have new unique columns to add.
# Row 1264 does not have new unique columns to add.
# Row 1265 does not have new unique columns to add.
# Row 1266 does not have new unique columns to add.
# Row 1267 does not have new unique columns to add.
# Row 1268 does not have new unique columns to add.
# Row 1269 does not have new unique columns to add.
# Row 1270 does not have new unique columns to add.
# Row 1271 does not have new unique columns to add.
# Row 1272 does not have new unique columns to add.
# Row 1273 does not have new unique columns to add.
# Row 1275 does not have new unique columns to add.
# Row 1276 does not have new unique columns to add.
# Row 1277 does not have new unique columns to add.
# Row 1278 does not have new unique columns to add.
# Row 1279 does not have new unique columns to add.
# Row 1280 does not have new unique columns to add.
# Row 1281 does not have new unique columns to add.
# Row 1282 does not have new unique columns to add.
# Row 1283 does not have new unique columns to add.
# Row 1284 does not have new unique columns to add.
# Row 1285 does not have new unique columns to add.
# Row 1286 does not have new unique columns to add.
# Row 1287 does not have new unique columns to add.
# Row 1288 does not have new unique columns to add.
# Row 1289 does not have new unique columns to add.
# Row 1290 does not have new unique columns to add.
# Row 1291 does not have new unique columns to add.
# Row 1292 does not have new unique columns to add.
# Row 1293 does not have new unique columns to add.
# Row 1294 does not have new unique columns to add.
# Row 1295 does not have new unique columns to add.
# Row 1296 does not have new unique columns to add.
# Row 1297 does not have new unique columns to add.
# Row 1298 does not have new unique columns to add.
# Row 1299 does not have new unique columns to add.
# Row 1300 does not have new unique columns to add.
# Row 1301 does not have new unique columns to add.
# Row 1302 does not have new unique columns to add.
# Row 1303 does not have new unique columns to add.
# Row 1304 does not have new unique columns to add.
# Row 1305 does not have new unique columns to add.
# Row 1306 does not have new unique columns to add.
# Row 1307 does not have new unique columns to add.
# Row 1308 does not have new unique columns to add.
# Row 1309 does not have new unique columns to add.
# Row 1311 does not have new unique columns to add.
# Row 1312 does not have new unique columns to add.
# Row 1313 does not have new unique columns to add.
# Row 1314 does not have new unique columns to add.
# Row 1315 does not have new unique columns to add.
# Row 1316 does not have new unique columns to add.
# Row 1317 does not have new unique columns to add.
# Row 1320 does not have new unique columns to add.
# Row 1321 does not have new unique columns to add.
# Row 1322 does not have new unique columns to add.
# Row 1323 does not have new unique columns to add.
# Row 1325 does not have new unique columns to add.
# Row 1326 does not have new unique columns to add.
# Row 1328 does not have new unique columns to add.
# Row 1331 does not have new unique columns to add.
# Row 1332 does not have new unique columns to add.
# Row 1333 does not have new unique columns to add.
# Row 1334 does not have new unique columns to add.
# Row 1335 does not have new unique columns to add.
# Row 1336 does not have new unique columns to add.
# Row 1337 does not have new unique columns to add.
# Row 1338 does not have new unique columns to add.
# Row 1339 does not have new unique columns to add.
# Row 1340 does not have new unique columns to add.
# ...
# Row 2495 does not have new unique columns to add.
# Row 2496 does not have new unique columns to add.
# Row 2497 does not have new unique columns to add.
# Row 2498 does not have new unique columns to add.
# Row 2499 does not have new unique columns to add.
# Row 2500 does not have new unique columns to add.
# Row 2501 does not have new unique columns to add.
# Row 2502 does not have new unique columns to add.
# Row 2503 does not have new unique columns to add.
# Row 2504 does not have new unique columns to add.
# Row 2506 does not have new unique columns to add.
# Row 2507 does not have new unique columns to add.
# Row 2509 does not have new unique columns to add.
# Row 2510 does not have new unique columns to add.
# Row 2511 does not have new unique columns to add.
# Row 2512 does not have new unique columns to add.
# Row 2514 does not have new unique columns to add.
# Row 2515 does not have new unique columns to add.
# Row 2516 does not have new unique columns to add.
# Row 2517 does not have new unique columns to add.
# Row 2518 does not have new unique columns to add.
# Row 2519 does not have new unique columns to add.
# Row 2520 does not have new unique columns to add.
# Row 2521 does not have new unique columns to add.
# Row 2522 does not have new unique columns to add.
# Row 2523 does not have new unique columns to add.
# Row 2524 does not have new unique columns to add.
# Row 2525 does not have new unique columns to add.
# Row 2526 does not have new unique columns to add.
# Row 2527 does not have new unique columns to add.
# Row 2528 does not have new unique columns to add.
# Row 2529 does not have new unique columns to add.
# Row 2530 does not have new unique columns to add.
# Row 2531 does not have new unique columns to add.
# Row 2532 does not have new unique columns to add.
# Row 2533 does not have new unique columns to add.
# Row 2534 does not have new unique columns to add.
# Row 2535 does not have new unique columns to add.
# Row 2536 does not have new unique columns to add.
# Row 2537 does not have new unique columns to add.
# Row 2538 does not have new unique columns to add.
# Row 2539 does not have new unique columns to add.
# Row 2540 does not have new unique columns to add.
# Row 2541 does not have new unique columns to add.
# Row 2542 does not have new unique columns to add.
# Row 2543 does not have new unique columns to add.
# Row 2544 does not have new unique columns to add.
# Row 2545 does not have new unique columns to add.
# Row 2546 does not have new unique columns to add.
# Row 2547 does not have new unique columns to add.
# Row 2548 does not have new unique columns to add.
# Row 2549 does not have new unique columns to add.
# Row 2550 does not have new unique columns to add.
# Row 2551 does not have new unique columns to add.
# Row 2552 does not have new unique columns to add.
# Row 2553 does not have new unique columns to add.
# Row 2554 does not have new unique columns to add.
# Row 2555 does not have new unique columns to add.
# Row 2556 does not have new unique columns to add.
# Row 2557 does not have new unique columns to add.
# Row 2558 does not have new unique columns to add.
# Row 2559 does not have new unique columns to add.
# Row 2560 does not have new unique columns to add.
# Row 2561 does not have new unique columns to add.
# Row 2562 does not have new unique columns to add.
# Row 2563 does not have new unique columns to add.
# Row 2564 does not have new unique columns to add.
# Row 2565 does not have new unique columns to add.
# Row 2566 does not have new unique columns to add.
# Row 2567 does not have new unique columns to add.
# Row 2569 does not have new unique columns to add.
# Row 2572 does not have new unique columns to add.
# Row 2573 does not have new unique columns to add.
# Row 2574 does not have new unique columns to add.
# Row 2575 does not have new unique columns to add.
# Row 2576 does not have new unique columns to add.
# Row 2577 does not have new unique columns to add.
# Row 2578 does not have new unique columns to add.
# Row 2580 does not have new unique columns to add.
# Row 2581 does not have new unique columns to add.
# Row 2582 does not have new unique columns to add.
# Row 2583 does not have new unique columns to add.
# Row 2584 does not have new unique columns to add.
# Row 2585 does not have new unique columns to add.
# Row 2586 does not have new unique columns to add.
# Row 2587 does not have new unique columns to add.
# Row 2588 does not have new unique columns to add.
# Row 2589 does not have new unique columns to add.
# Row 2590 does not have new unique columns to add.
# Row 2591 does not have new unique columns to add.
# Row 2592 does not have new unique columns to add.
# Row 2593 does not have new unique columns to add.
# Row 2594 does not have new unique columns to add.
# Row 2595 does not have new unique columns to add.
# Row 2596 does not have new unique columns to add.
# Row 2597 does not have new unique columns to add.
# Row 2598 does not have new unique columns to add.
# Row 2599 does not have new unique columns to add.
# Row 2600 does not have new unique columns to add.
# Row 2601 does not have new unique columns to add.
# Row 2602 does not have new unique columns to add.
# Row 2603 does not have new unique columns to add.
# Row 2604 does not have new unique columns to add.
# Row 2605 does not have new unique columns to add.
# Row 2606 does not have new unique columns to add.
# Row 2607 does not have new unique columns to add.
# Row 2608 does not have new unique columns to add.
# Row 2610 does not have new unique columns to add.
# Row 2611 does not have new unique columns to add.
# Row 2612 does not have new unique columns to add.
# Row 2613 does not have new unique columns to add.
# Row 2614 does not have new unique columns to add.
# Row 2615 does not have new unique columns to add.
# Row 2616 does not have new unique columns to add.
# Row 2617 does not have new unique columns to add.
# Row 2618 does not have new unique columns to add.
# Row 2619 does not have new unique columns to add.
# Row 2620 does not have new unique columns to add.
# Row 2621 does not have new unique columns to add.
# Row 2622 does not have new unique columns to add.
# Row 2623 does not have new unique columns to add.
# Row 2624 does not have new unique columns to add.
# Row 2625 does not have new unique columns to add.
# Row 2626 does not have new unique columns to add.
# Row 2627 does not have new unique columns to add.
# Row 2628 does not have new unique columns to add.
# Row 2629 does not have new unique columns to add.
# Row 2630 does not have new unique columns to add.
# Row 2631 does not have new unique columns to add.
# Row 2632 does not have new unique columns to add.
# Row 2634 does not have new unique columns to add.
# Row 2635 does not have new unique columns to add.
# Row 2636 does not have new unique columns to add.
# Row 2637 does not have new unique columns to add.
# Row 2638 does not have new unique columns to add.
# Row 2639 does not have new unique columns to add.
# Row 2640 does not have new unique columns to add.
# Row 2641 does not have new unique columns to add.
# Row 2642 does not have new unique columns to add.
# Row 2645 does not have new unique columns to add.
# Row 2646 does not have new unique columns to add.
# Row 2647 does not have new unique columns to add.
# Row 2648 does not have new unique columns to add.
# Row 2649 does not have new unique columns to add.
# Row 2650 does not have new unique columns to add.
# Row 2651 does not have new unique columns to add.
# Row 2652 does not have new unique columns to add.
# Row 2653 does not have new unique columns to add.
# Row 2654 does not have new unique columns to add.
# Row 2655 does not have new unique columns to add.
# Row 2656 does not have new unique columns to add.
# Row 2657 does not have new unique columns to add.
# Row 2659 does not have new unique columns to add.
# Row 2660 does not have new unique columns to add.
# Row 2661 does not have new unique columns to add.
# Row 2662 does not have new unique columns to add.
# Row 2663 does not have new unique columns to add.
# Row 2665 does not have new unique columns to add.
# Row 2666 does not have new unique columns to add.
# Row 2667 does not have new unique columns to add.
# Row 2668 does not have new unique columns to add.
# Row 2669 does not have new unique columns to add.
# Row 2670 does not have new unique columns to add.
# Row 2671 does not have new unique columns to add.
# Row 2672 does not have new unique columns to add.
# Row 2673 does not have new unique columns to add.
# Row 2674 does not have new unique columns to add.
# Row 2675 does not have new unique columns to add.
# Row 2676 does not have new unique columns to add.
# Row 2677 does not have new unique columns to add.
# Row 2678 does not have new unique columns to add.
# Row 2679 does not have new unique columns to add.
# Row 2680 does not have new unique columns to add.
# Row 2681 does not have new unique columns to add.
# Row 2682 does not have new unique columns to add.
# Row 2683 does not have new unique columns to add.
# Row 2684 does not have new unique columns to add.
# Row 2685 does not have new unique columns to add.
# Row 2686 does not have new unique columns to add.
# Row 2687 does not have new unique columns to add.
# Row 2688 does not have new unique columns to add.
# Row 2689 does not have new unique columns to add.
# Row 2690 does not have new unique columns to add.
# Row 2691 does not have new unique columns to add.
# Row 2692 does not have new unique columns to add.
# Row 2693 does not have new unique columns to add.
# Row 2694 does not have new unique columns to add.
# Row 2695 does not have new unique columns to add.
# Row 2696 does not have new unique columns to add.
# Row 2697 does not have new unique columns to add.
# Row 2698 does not have new unique columns to add.
# Row 2699 does not have new unique columns to add.
# Row 2700 does not have new unique columns to add.
# Row 2701 does not have new unique columns to add.
# Row 2702 does not have new unique columns to add.
# Row 2703 does not have new unique columns to add.
# Row 2704 does not have new unique columns to add.
# Row 2705 does not have new unique columns to add.
# Row 2706 does not have new unique columns to add.
# Row 2707 does not have new unique columns to add.
# Row 2708 does not have new unique columns to add.
# Row 2709 does not have new unique columns to add.
# Row 2710 does not have new unique columns to add.
# Row 2711 does not have new unique columns to add.
# Row 2712 does not have new unique columns to add.
# Row 2713 does not have new unique columns to add.
# Row 2714 does not have new unique columns to add.
# Row 2715 does not have new unique columns to add.
# Row 2716 does not have new unique columns to add.
# Row 2717 does not have new unique columns to add.
# Row 2718 does not have new unique columns to add.
# Row 2719 does not have new unique columns to add.
# Row 2720 does not have new unique columns to add.
# Row 2721 does not have new unique columns to add.
# Row 2722 does not have new unique columns to add.
# Row 2723 does not have new unique columns to add.
# Row 2724 does not have new unique columns to add.
# Row 2725 does not have new unique columns to add.
# Row 2726 does not have new unique columns to add.
# Row 2727 does not have new unique columns to add.
# Row 2728 does not have new unique columns to add.
# Row 2729 does not have new unique columns to add.
# Row 2730 does not have new unique columns to add.
# Row 2731 does not have new unique columns to add.
# Row 2732 does not have new unique columns to add.
# Row 2733 does not have new unique columns to add.
# Row 2734 does not have new unique columns to add.
# Row 2735 does not have new unique columns to add.
# Row 2736 does not have new unique columns to add.
# Row 2737 does not have new unique columns to add.
# Row 2738 does not have new unique columns to add.
# Row 2739 does not have new unique columns to add.
# Row 2740 does not have new unique columns to add.
# Row 2741 does not have new unique columns to add.
# Row 2744 does not have new unique columns to add.
# Row 2745 does not have new unique columns to add.
# Row 2747 does not have new unique columns to add.
# Row 2748 does not have new unique columns to add.
# Row 2749 does not have new unique columns to add.
# Row 2750 does not have new unique columns to add.
# Row 2751 does not have new unique columns to add.
# Row 2752 does not have new unique columns to add.
# Row 2753 does not have new unique columns to add.
# Row 2754 does not have new unique columns to add.
# Row 2755 does not have new unique columns to add.
# Row 2756 does not have new unique columns to add.
# Row 2757 does not have new unique columns to add.
# Row 2758 does not have new unique columns to add.
# Row 2759 does not have new unique columns to add.
# Row 2761 does not have new unique columns to add.
# Row 2762 does not have new unique columns to add.
# Row 2763 does not have new unique columns to add.
# Row 2764 does not have new unique columns to add.
# Row 2765 does not have new unique columns to add.
# Row 2766 does not have new unique columns to add.
# Row 2767 does not have new unique columns to add.
# Row 2768 does not have new unique columns to add.
# Row 2769 does not have new unique columns to add.
# Row 2770 does not have new unique columns to add.
# Row 2771 does not have new unique columns to add.
# Row 2772 does not have new unique columns to add.
# Row 2773 does not have new unique columns to add.
# Row 2774 does not have new unique columns to add.
# Row 2775 does not have new unique columns to add.
# Row 2776 does not have new unique columns to add.
# Row 2777 does not have new unique columns to add.
# Row 2778 does not have new unique columns to add.
# Row 2779 does not have new unique columns to add.
# Row 2780 does not have new unique columns to add.
# Row 2781 does not have new unique columns to add.
# Row 2782 does not have new unique columns to add.
# Row 2783 does not have new unique columns to add.
# Row 2784 does not have new unique columns to add.
# Row 2785 does not have new unique columns to add.
#       PROX1   SH2B3   RSPO3   HOXD3    HMX2   SHOX2    GJB6   MAPK1  PDGFRA  \
# 0   -0.3947  0.3193  0.1971 -0.0426 -0.1288 -0.1590 -0.2084 -0.4558 -0.2251
# 1   -0.4754  0.3408  0.0615  0.1237 -0.4644 -0.0780 -0.4734 -0.4738 -0.3987
# 2   -0.0863  0.3551  0.1403  0.1394 -0.2340 -0.0532 -0.1977 -0.4763 -0.0906
# 3   -0.2583  0.3964  0.0686  0.3516 -0.4030  0.0850 -0.3241 -0.4781  0.1752
# 4   -0.4699  0.3242 -0.2212  0.3626 -0.4097  0.3497 -0.4797 -0.4764 -0.3897
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 765 -0.2350  0.3391  0.1727  0.2844 -0.0159  0.0174  0.0221 -0.4761 -0.1010
# 766 -0.0497  0.3121  0.3168  0.3675  0.0914  0.1603 -0.0460 -0.4770  0.0527
# 767  0.0042  0.3174  0.2500  0.3374 -0.4054  0.0424 -0.4743 -0.4672 -0.0599
# 768 -0.2187  0.3242  0.3495  0.3104 -0.2608 -0.3840 -0.4116 -0.4801  0.0197
# 769 -0.1571  0.4010  0.0384  0.2748 -0.4530  0.0819 -0.4746 -0.4606 -0.2833
#
#       TEAD3  ...   NOP56  PIH1D2  EXOSC1   REXO4  TRMT112  PRTFDC1   PRDM2  \
# 0   -0.2197  ... -0.0756 -0.4602 -0.4225 -0.0336  -0.3139  -0.4096 -0.4102
# 1   -0.3110  ... -0.3802 -0.4293 -0.4798 -0.0455  -0.3757  -0.4630 -0.4789
# 2   -0.2305  ... -0.3447 -0.3862 -0.4814  0.0116  -0.3964  -0.3886 -0.4801
# 3   -0.3810  ... -0.4279 -0.3667 -0.4777  0.1632  -0.4000  -0.4271 -0.4775
# 4   -0.3840  ... -0.3979 -0.4168 -0.4850  0.0333  -0.3639  -0.4688 -0.4766
# ..      ...  ...     ...     ...     ...     ...      ...      ...     ...
# 765 -0.2657  ... -0.1847 -0.4424 -0.4846 -0.0152  -0.3879   0.0175 -0.4792
# 766 -0.2806  ... -0.4468 -0.4221 -0.4839 -0.0538  -0.3578  -0.4032 -0.4811
# 767 -0.3227  ... -0.3062 -0.4441 -0.4820 -0.0172  -0.3558  -0.0246 -0.4811
# 768 -0.3545  ...  0.0776 -0.4326 -0.4855  0.0375  -0.3625  -0.0044 -0.4801
# 769 -0.2887  ... -0.4080 -0.4045 -0.4853  0.1468  -0.3325   0.2211 -0.4729
#
#       MTFMT  EIF1AD   FCGRT
# 0   -0.4736 -0.4522 -0.1503
# 1   -0.4707 -0.4813 -0.3234
# 2   -0.4754 -0.4828 -0.0965
# 3   -0.4725 -0.4843 -0.3937
# 4   -0.4649 -0.4830 -0.3935
# ..      ...     ...     ...
# 765 -0.4734 -0.4823 -0.0147
# 766 -0.4659 -0.4825  0.1493
# 767 -0.4745 -0.4823  0.0561
# 768 -0.4746 -0.4842 -0.2489
# 769 -0.4636 -0.4844 -0.0703
#
# [770 rows x 12049 columns]

# %%
# 获取所有列名
columns = BRCA_Methylation.columns

# 检查是否有重复的列名
duplicate_columns = columns[columns.duplicated()]

# 输出重复列名
if len(duplicate_columns) > 0:
    print("Duplicate column names found:", duplicate_columns.tolist())
else:
    print("No duplicate column names found.")
# Out:
# No duplicate column names found.

# %%
BRCA_Methylation.to_csv('../../DATA/BRCA/BRCA_Methylation.csv', index=False)

# %%
SCNA_pathgway = pd.read_csv('../../DATA/BRCA/GO_BRCA_SCNA.csv').sort_values('pvalue')
# 筛选 pvalue 小于 0.05 的行
SCNA_pathgway = SCNA_pathgway[SCNA_pathgway['pvalue'] < 0.05]
SCNA_pathgway
# Out:
#       Unnamed: 0          ID  \
# 0     GO:1903131  GO:1903131
# 1     GO:0099177  GO:0099177
# 2     GO:0050804  GO:0050804
# 3     GO:0060562  GO:0060562
# 4     GO:0048880  GO:0048880
# ...          ...         ...
# 2049  GO:0006906  GO:0006906
# 2050  GO:0031644  GO:0031644
# 2055  GO:0060390  GO:0060390
# 2054  GO:0045123  GO:0045123
# 2056  GO:1901796  GO:1901796
#
#                                             Description  GeneRatio    BgRatio  \
# 0                      mononuclear cell differentiation  473/16655  484/18888
# 1                regulation of trans-synaptic signaling  481/16655  494/18888
# 2          modulation of chemical synaptic transmission  480/16655  493/18888
# 3                         epithelial tube morphogenesis  331/16655  335/18888
# 4                            sensory system development  395/16655  403/18888
# ...                                                 ...        ...        ...
# 2049                                     vesicle fusion  111/16655  119/18888
# 2050               regulation of nervous system process  111/16655  119/18888
# 2055     regulation of SMAD protein signal transduction   71/16655   75/18888
# 2054                             cellular extravasation   71/16655   75/18888
# 2056  regulation of signal transduction by p53 class...  101/16655  108/18888
#
#       RichFactor  FoldEnrichment    zScore        pvalue      p.adjust  \
# 0       0.977273        1.108299  6.591773  4.752687e-15  3.021283e-11
# 1       0.973684        1.104230  6.411014  4.791826e-14  1.038009e-10
# 2       0.973631        1.104169  6.400628  5.308743e-14  1.038009e-10
# 3       0.988060        1.120533  6.078964  6.531438e-14  1.038009e-10
# 4       0.980149        1.111561  6.182520  1.252380e-13  1.334611e-10
# ...          ...             ...       ...           ...           ...
# 2049    0.932773        1.057834  1.728393  4.885606e-02  1.510779e-01
# 2050    0.932773        1.057834  1.728393  4.885606e-02  1.510779e-01
# 2055    0.946667        1.073590  1.743931  4.886207e-02  1.510779e-01
# 2054    0.946667        1.073590  1.743931  4.886207e-02  1.510779e-01
# 2056    0.935185        1.060569  1.723949  4.974587e-02  1.535434e-01
#
#             qvalue                                             geneID  Count
# 0     2.151216e-11  PRKCZ/RPL22/TNFRSF9/PIK3CD/CTNNBIP1/MTOR/PLA2G...    473
# 1     7.390838e-11  DVL1/PRKCZ/TPRG1L/CLSTN1/FBXO2/PINK1/EPHB2/CNR...    481
# 2     7.390838e-11  DVL1/PRKCZ/TPRG1L/CLSTN1/FBXO2/PINK1/EPHB2/CNR...    480
# 3     7.390838e-11  DVL1/HES5/SKI/RNF207/PIK3CD/CTNNBIP1/MTHFR/EPH...    331
# 4     9.502704e-11  GNB1/HES5/SAMD11/SKI/NPHP4/ANGPTL7/MFN2/EPHA2/...    395
# ...            ...                                                ...    ...
# 2049  1.075706e-01  VAMP3/ATP13A2/PLA2G5/STX12/VAV3/SEC22B/SNAPIN/...    111
# 2050  1.075706e-01  DVL1/PRKCZ/TNFRSF1B/NCMAP/DLGAP3/RGS4/TNR/ADOR...    111
# 2055  1.075706e-01  SKI/TGFBR3/TGFB2/PARP1/GDF7/EMILIN1/SPTBN1/BMP...     71
# 2054  1.075706e-01  PIK3CD/PTAFR/VCAM1/F11R/SELP/SELL/SELE/ADD2/IL...     71
# 2056  1.093261e-01  CHD5/MTOR/KDM1A/RPL11/ZMPSTE24/PLK3/MIR186/RPL...    101
#
# [2057 rows x 13 columns]

# %%
# 读取制表符分隔的TSV文件
SCNA = pd.read_csv('../../DATA/BRCA/Human__TCGA_BRCA__BI__SCNA__SNP_6.0__01_28_2016__BI__Gene__Firehose_GISTIC2_common_samples.tsv', sep='\t')
SCNA = drop_and_impute_knn(SCNA)
# 显示 DataFrame
SCNA
# Out:
#        Unnamed: 0  ACAP3  ACTRT2   AGRN  ANKRD65  ATAD3A  ATAD3B  ATAD3C  \
# 0    TCGA.D8.A1JH -0.001  -0.001 -0.001   -0.001  -0.001  -0.001  -0.001
# 1    TCGA.OL.A5RW  0.304   0.304  0.304    0.304   0.304   0.304   0.304
# 2    TCGA.XX.A899 -0.071  -0.071 -0.071   -0.071  -0.071  -0.071  -0.071
# 3    TCGA.S3.A6ZH -0.423  -0.423 -0.423   -0.423  -0.423  -0.423  -0.423
# 4    TCGA.AQ.A54N  0.100   0.100  0.100    0.100   0.100   0.100   0.100
# ..            ...    ...     ...    ...      ...     ...     ...     ...
# 765  TCGA.GM.A5PX -0.013  -0.013 -0.013   -0.013  -0.013  -0.013  -0.013
# 766  TCGA.AC.A5XU -0.525  -0.525 -0.525   -0.525  -0.525  -0.525  -0.525
# 767  TCGA.AR.A1AN  0.053   0.053  0.053    0.053   0.053   0.053   0.053
# 768  TCGA.E9.A1RG -0.373  -0.373 -0.373   -0.373  -0.373  -0.373  -0.373
# 769  TCGA.BH.A0GY -0.428  -0.428 -0.428   -0.428  -0.428  -0.428  -0.428
#
#      AURKAIP1  B3GALT6  ...  SMIM9  SNORA36A  SNORA56  TMLHE   VBP1  \
# 0      -0.001   -0.001  ...  0.030     0.030    0.030  0.030  0.030
# 1       0.304    0.304  ...  0.670     0.670    0.670  0.670  0.670
# 2      -0.071   -0.071  ...  0.001     0.001    0.001  0.001  0.001
# 3      -0.423   -0.423  ... -0.150    -0.150   -0.150 -0.150 -0.150
# 4       0.100    0.100  ... -0.462    -0.462   -0.462 -0.462 -0.462
# ..        ...      ...  ...    ...       ...      ...    ...    ...
# 765    -0.013   -0.013  ...  0.001     0.001    0.001  0.001  0.001
# 766    -0.525   -0.525  ...  0.022     0.022    0.022  0.022  0.022
# 767     0.053    0.053  ... -0.060    -0.060   -0.060 -0.060 -0.060
# 768    -0.373   -0.373  ... -0.150    -0.150   -0.150 -0.150 -0.150
# 769    -0.428   -0.428  ...  0.148     0.148    0.148  0.148  0.148
#
#      IL9R|ENSG00000124334.12  SPRY3|ENSG00000168939.6  \
# 0                      0.030                    0.030
# 1                      0.670                    0.670
# 2                      0.001                    0.001
# 3                     -0.150                   -0.150
# 4                     -0.462                   -0.462
# ..                       ...                      ...
# 765                    0.001                    0.001
# 766                    0.022                    0.022
# 767                   -0.060                   -0.060
# 768                   -0.150                   -0.150
# 769                    0.148                    0.148
#
#      VAMP7|ENSG00000124333.10  WASH6P|ENSG00000182484.10  \
# 0                       0.030                      0.030
# 1                       0.670                      0.670
# 2                       0.001                      0.001
# 3                      -0.150                     -0.150
# 4                      -0.462                     -0.462
# ..                        ...                        ...
# 765                     0.001                      0.001
# 766                     0.022                      0.022
# 767                    -0.060                     -0.060
# 768                    -0.150                     -0.150
# 769                     0.148                      0.148
#
#      WASIR1|ENSG00000185203.7
# 0                       0.030
# 1                       0.670
# 2                       0.001
# 3                      -0.150
# 4                      -0.462
# ..                        ...
# 765                     0.001
# 766                     0.022
# 767                    -0.060
# 768                    -0.150
# 769                     0.148
#
# [770 rows x 24777 columns]

# %%
# 提取 geneID 列中每一行的基因ID，并存储为列表
gene_ids = SCNA_pathgway['geneID'].apply(lambda x: x.split('/'))
gene_ids
# Out:
# 0       [PRKCZ, RPL22, TNFRSF9, PIK3CD, CTNNBIP1, MTOR...
# 1       [DVL1, PRKCZ, TPRG1L, CLSTN1, FBXO2, PINK1, EP...
# 2       [DVL1, PRKCZ, TPRG1L, CLSTN1, FBXO2, PINK1, EP...
# 3       [DVL1, HES5, SKI, RNF207, PIK3CD, CTNNBIP1, MT...
# 4       [GNB1, HES5, SAMD11, SKI, NPHP4, ANGPTL7, MFN2...
#                               ...
# 2049    [VAMP3, ATP13A2, PLA2G5, STX12, VAV3, SEC22B, ...
# 2050    [DVL1, PRKCZ, TNFRSF1B, NCMAP, DLGAP3, RGS4, T...
# 2055    [SKI, TGFBR3, TGFB2, PARP1, GDF7, EMILIN1, SPT...
# 2054    [PIK3CD, PTAFR, VCAM1, F11R, SELP, SELL, SELE,...
# 2056    [CHD5, MTOR, KDM1A, RPL11, ZMPSTE24, PLK3, MIR...
# Name: geneID, Length: 2057, dtype: object

# %%
# # 创建一个空的数据框来存储所有PCA结果
# BRCA_SCNA = pd.DataFrame()

# # 设置累计解释方差的阈值
# explained_variance_threshold = 0.95

# # 对每一行的基因数据进行PCA
# for i, gene_list in enumerate(gene_ids):
#     # 找到SCNA数据框中与gene_list对应的列
#     matching_columns = [col for col in SCNA.columns if col in gene_list]
#     # 提取这些列的数据
#     data = SCNA[matching_columns]
    
#     # 确保数据足够进行PCA（至少需要两个基因）
#     if len(matching_columns) > 1:
#         # 初始化PCA
#         pca = PCA()
#         pca.fit(data)
        
#         # 计算累计解释方差
#         cumulative_explained_variance = pca.explained_variance_ratio_.cumsum()
        
#         # 确定达到阈值的主成分数k
#         k = next(i for i, total_variance in enumerate(cumulative_explained_variance) if total_variance >= explained_variance_threshold) + 1
        
#         # 重新运行PCA，保留前k个主成分
#         pca = PCA(n_components=k)
#         pca_result = pca.fit_transform(data)
        
#         # 将PCA结果转换为DataFrame，并添加索引信息
#         pca_df = pd.DataFrame(pca_result, columns=[f'PC{j+1}_row_{i}' for j in range(k)])
        
#         # 合并PCA结果到总数据框
#         BRCA_SCNA = pd.concat([BRCA_SCNA, pca_df], axis=1)
#     else:
#         print(f"Row {i} does not have enough genes for PCA.")

# # 显示最终合并的PCA结果
# BRCA_SCNA

# %%
# # 创建一个空的数据框来存储所有PCA结果
# BRCA_SCNA = pd.DataFrame()

# # 对每一行的基因数据进行PCA
# for i, gene_list in enumerate(gene_ids):
#     # 找到Methylation数据框中与gene_list对应的列
#     matching_columns = [col for col in SCNA.columns if col in gene_list]
#     # 提取这些列的数据
#     data = SCNA[matching_columns]
    
#     # 确保数据足够进行PCA（至少需要两个基因）
#     if len(matching_columns) > 1:
#         # 初始化PCA，并指定n_components为1
#         pca = PCA(n_components=1)
#         pca_result = pca.fit_transform(data)
        
#         # 将PCA结果转换为DataFrame，并添加索引信息
#         pca_df = pd.DataFrame(pca_result, columns=[f'PC1_row_{i}'])
        
#         # 合并PCA结果到总数据框
#         BRCA_SCNA = pd.concat([BRCA_SCNA, pca_df], axis=1)
#     else:
#         print(f"Row {i} does not have enough genes for PCA.")

# # 显示最终合并的PCA结果
# BRCA_SCNA

# %%
# 创建一个空的数据框来存储所有结果
BRCA_SCNA = pd.DataFrame()

# 对每一行的基因数据进行拼接
for i, gene_list in enumerate(gene_ids):
    # 找到SCNA数据框中与gene_list对应的列
    matching_columns = [col for col in SCNA.columns if col in gene_list]
    
    # 去重，保留唯一的基因列
    unique_columns = list(dict.fromkeys(matching_columns))  # 保留顺序的去重方法
    
    # 提取这些唯一列的数据
    data = SCNA[unique_columns]
    
    # 确保有匹配到的基因列
    if len(unique_columns) > 0:
        # 检查是否有重复的列
        unique_columns_to_add = [col for col in unique_columns if col not in BRCA_SCNA.columns]
        
        # 如果没有重复列，将新列的数据直接拼接
        if unique_columns_to_add:
            data_to_add = data[unique_columns_to_add]
            BRCA_SCNA = pd.concat([BRCA_SCNA, data_to_add], axis=1)
        else:
            print(f"Row {i} does not have new unique columns to add.")
    else:
        print(f"Row {i} does not have matching genes to concatenate.")

# 显示最终拼接的结果
BRCA_SCNA
# Out:
# Row 2 does not have new unique columns to add.
# Row 7 does not have new unique columns to add.
# Row 8 does not have new unique columns to add.
# Row 9 does not have new unique columns to add.
# Row 16 does not have new unique columns to add.
# Row 20 does not have new unique columns to add.
# Row 25 does not have new unique columns to add.
# Row 28 does not have new unique columns to add.
# Row 29 does not have new unique columns to add.
# Row 41 does not have new unique columns to add.
# Row 45 does not have new unique columns to add.
# Row 52 does not have new unique columns to add.
# Row 54 does not have new unique columns to add.
# Row 61 does not have new unique columns to add.
# Row 64 does not have new unique columns to add.
# Row 66 does not have new unique columns to add.
# Row 71 does not have new unique columns to add.
# Row 75 does not have new unique columns to add.
# Row 76 does not have new unique columns to add.
# Row 77 does not have new unique columns to add.
# Row 80 does not have new unique columns to add.
# Row 82 does not have new unique columns to add.
# Row 83 does not have new unique columns to add.
# Row 88 does not have new unique columns to add.
# Row 90 does not have new unique columns to add.
# Row 91 does not have new unique columns to add.
# Row 96 does not have new unique columns to add.
# Row 100 does not have new unique columns to add.
# Row 101 does not have new unique columns to add.
# Row 107 does not have new unique columns to add.
# Row 109 does not have new unique columns to add.
# Row 110 does not have new unique columns to add.
# Row 115 does not have new unique columns to add.
# Row 117 does not have new unique columns to add.
# Row 122 does not have new unique columns to add.
# Row 124 does not have new unique columns to add.
# Row 125 does not have new unique columns to add.
# Row 128 does not have new unique columns to add.
# Row 131 does not have new unique columns to add.
# Row 135 does not have new unique columns to add.
# Row 136 does not have new unique columns to add.
# Row 138 does not have new unique columns to add.
# Row 142 does not have new unique columns to add.
# Row 143 does not have new unique columns to add.
# Row 145 does not have new unique columns to add.
# Row 146 does not have new unique columns to add.
# Row 150 does not have new unique columns to add.
# Row 151 does not have new unique columns to add.
# Row 153 does not have new unique columns to add.
# Row 154 does not have new unique columns to add.
# Row 155 does not have new unique columns to add.
# Row 156 does not have new unique columns to add.
# Row 157 does not have new unique columns to add.
# Row 158 does not have new unique columns to add.
# Row 160 does not have new unique columns to add.
# Row 161 does not have new unique columns to add.
# Row 162 does not have new unique columns to add.
# Row 164 does not have new unique columns to add.
# Row 165 does not have new unique columns to add.
# Row 167 does not have new unique columns to add.
# Row 173 does not have new unique columns to add.
# Row 174 does not have new unique columns to add.
# Row 176 does not have new unique columns to add.
# Row 179 does not have new unique columns to add.
# Row 181 does not have new unique columns to add.
# Row 182 does not have new unique columns to add.
# Row 183 does not have new unique columns to add.
# Row 187 does not have new unique columns to add.
# Row 189 does not have new unique columns to add.
# Row 190 does not have new unique columns to add.
# Row 191 does not have new unique columns to add.
# Row 193 does not have new unique columns to add.
# Row 194 does not have new unique columns to add.
# Row 196 does not have new unique columns to add.
# Row 197 does not have new unique columns to add.
# Row 198 does not have new unique columns to add.
# Row 199 does not have new unique columns to add.
# Row 201 does not have new unique columns to add.
# Row 202 does not have new unique columns to add.
# Row 203 does not have new unique columns to add.
# Row 207 does not have new unique columns to add.
# Row 208 does not have new unique columns to add.
# Row 209 does not have new unique columns to add.
# Row 211 does not have new unique columns to add.
# Row 212 does not have new unique columns to add.
# Row 213 does not have new unique columns to add.
# Row 216 does not have new unique columns to add.
# Row 217 does not have new unique columns to add.
# Row 223 does not have new unique columns to add.
# Row 225 does not have new unique columns to add.
# Row 228 does not have new unique columns to add.
# Row 231 does not have new unique columns to add.
# Row 232 does not have new unique columns to add.
# Row 233 does not have new unique columns to add.
# Row 234 does not have new unique columns to add.
# Row 240 does not have new unique columns to add.
# Row 241 does not have new unique columns to add.
# Row 242 does not have new unique columns to add.
# Row 243 does not have new unique columns to add.
# Row 244 does not have new unique columns to add.
# Row 246 does not have new unique columns to add.
# Row 248 does not have new unique columns to add.
# Row 253 does not have new unique columns to add.
# Row 257 does not have new unique columns to add.
# Row 258 does not have new unique columns to add.
# Row 259 does not have new unique columns to add.
# Row 261 does not have new unique columns to add.
# Row 262 does not have new unique columns to add.
# Row 264 does not have new unique columns to add.
# Row 265 does not have new unique columns to add.
# Row 266 does not have new unique columns to add.
# Row 267 does not have new unique columns to add.
# Row 269 does not have new unique columns to add.
# Row 272 does not have new unique columns to add.
# Row 273 does not have new unique columns to add.
# Row 274 does not have new unique columns to add.
# Row 275 does not have new unique columns to add.
# Row 276 does not have new unique columns to add.
# Row 279 does not have new unique columns to add.
# Row 280 does not have new unique columns to add.
# Row 282 does not have new unique columns to add.
# Row 283 does not have new unique columns to add.
# Row 284 does not have new unique columns to add.
# Row 285 does not have new unique columns to add.
# Row 287 does not have new unique columns to add.
# Row 288 does not have new unique columns to add.
# Row 292 does not have new unique columns to add.
# Row 293 does not have new unique columns to add.
# Row 299 does not have new unique columns to add.
# Row 300 does not have new unique columns to add.
# Row 305 does not have new unique columns to add.
# Row 306 does not have new unique columns to add.
# Row 307 does not have new unique columns to add.
# Row 308 does not have new unique columns to add.
# Row 309 does not have new unique columns to add.
# Row 310 does not have new unique columns to add.
# Row 311 does not have new unique columns to add.
# Row 312 does not have new unique columns to add.
# Row 314 does not have new unique columns to add.
# Row 320 does not have new unique columns to add.
# Row 321 does not have new unique columns to add.
# Row 322 does not have new unique columns to add.
# Row 324 does not have new unique columns to add.
# Row 325 does not have new unique columns to add.
# Row 327 does not have new unique columns to add.
# Row 328 does not have new unique columns to add.
# Row 330 does not have new unique columns to add.
# Row 331 does not have new unique columns to add.
# Row 332 does not have new unique columns to add.
# Row 335 does not have new unique columns to add.
# Row 337 does not have new unique columns to add.
# Row 339 does not have new unique columns to add.
# Row 340 does not have new unique columns to add.
# Row 341 does not have new unique columns to add.
# Row 342 does not have new unique columns to add.
# Row 343 does not have new unique columns to add.
# Row 344 does not have new unique columns to add.
# Row 345 does not have new unique columns to add.
# Row 346 does not have new unique columns to add.
# Row 349 does not have new unique columns to add.
# Row 353 does not have new unique columns to add.
# Row 355 does not have new unique columns to add.
# Row 356 does not have new unique columns to add.
# Row 357 does not have new unique columns to add.
# Row 358 does not have new unique columns to add.
# Row 360 does not have new unique columns to add.
# Row 361 does not have new unique columns to add.
# Row 362 does not have new unique columns to add.
# Row 364 does not have new unique columns to add.
# Row 365 does not have new unique columns to add.
# Row 367 does not have new unique columns to add.
# Row 368 does not have new unique columns to add.
# Row 369 does not have new unique columns to add.
# Row 370 does not have new unique columns to add.
# Row 371 does not have new unique columns to add.
# Row 372 does not have new unique columns to add.
# Row 373 does not have new unique columns to add.
# Row 374 does not have new unique columns to add.
# Row 375 does not have new unique columns to add.
# Row 377 does not have new unique columns to add.
# Row 378 does not have new unique columns to add.
# Row 381 does not have new unique columns to add.
# Row 382 does not have new unique columns to add.
# Row 385 does not have new unique columns to add.
# Row 386 does not have new unique columns to add.
# Row 389 does not have new unique columns to add.
# Row 392 does not have new unique columns to add.
# Row 394 does not have new unique columns to add.
# Row 396 does not have new unique columns to add.
# Row 398 does not have new unique columns to add.
# Row 399 does not have new unique columns to add.
# Row 400 does not have new unique columns to add.
# Row 401 does not have new unique columns to add.
# Row 402 does not have new unique columns to add.
# Row 404 does not have new unique columns to add.
# Row 408 does not have new unique columns to add.
# Row 410 does not have new unique columns to add.
# Row 411 does not have new unique columns to add.
# Row 413 does not have new unique columns to add.
# Row 415 does not have new unique columns to add.
# Row 416 does not have new unique columns to add.
# Row 417 does not have new unique columns to add.
# Row 418 does not have new unique columns to add.
# Row 419 does not have new unique columns to add.
# Row 420 does not have new unique columns to add.
# Row 421 does not have new unique columns to add.
# Row 422 does not have new unique columns to add.
# Row 423 does not have new unique columns to add.
# Row 424 does not have new unique columns to add.
# Row 425 does not have new unique columns to add.
# Row 426 does not have new unique columns to add.
# Row 427 does not have new unique columns to add.
# Row 429 does not have new unique columns to add.
# Row 430 does not have new unique columns to add.
# Row 431 does not have new unique columns to add.
# Row 432 does not have new unique columns to add.
# Row 433 does not have new unique columns to add.
# Row 434 does not have new unique columns to add.
# Row 435 does not have new unique columns to add.
# Row 436 does not have new unique columns to add.
# Row 437 does not have new unique columns to add.
# Row 438 does not have new unique columns to add.
# Row 439 does not have new unique columns to add.
# Row 440 does not have new unique columns to add.
# Row 441 does not have new unique columns to add.
# Row 446 does not have new unique columns to add.
# Row 449 does not have new unique columns to add.
# Row 450 does not have new unique columns to add.
# Row 451 does not have new unique columns to add.
# Row 452 does not have new unique columns to add.
# Row 456 does not have new unique columns to add.
# Row 457 does not have new unique columns to add.
# Row 458 does not have new unique columns to add.
# Row 459 does not have new unique columns to add.
# Row 460 does not have new unique columns to add.
# Row 461 does not have new unique columns to add.
# Row 464 does not have new unique columns to add.
# Row 465 does not have new unique columns to add.
# Row 468 does not have new unique columns to add.
# Row 469 does not have new unique columns to add.
# Row 471 does not have new unique columns to add.
# Row 472 does not have new unique columns to add.
# Row 473 does not have new unique columns to add.
# Row 474 does not have new unique columns to add.
# Row 475 does not have new unique columns to add.
# Row 477 does not have new unique columns to add.
# Row 480 does not have new unique columns to add.
# Row 481 does not have new unique columns to add.
# Row 482 does not have new unique columns to add.
# Row 483 does not have new unique columns to add.
# Row 484 does not have new unique columns to add.
# Row 486 does not have new unique columns to add.
# Row 489 does not have new unique columns to add.
# Row 490 does not have new unique columns to add.
# Row 491 does not have new unique columns to add.
# Row 493 does not have new unique columns to add.
# Row 501 does not have new unique columns to add.
# Row 502 does not have new unique columns to add.
# Row 503 does not have new unique columns to add.
# Row 504 does not have new unique columns to add.
# Row 505 does not have new unique columns to add.
# Row 506 does not have new unique columns to add.
# Row 507 does not have new unique columns to add.
# Row 508 does not have new unique columns to add.
# Row 511 does not have new unique columns to add.
# Row 512 does not have new unique columns to add.
# Row 513 does not have new unique columns to add.
# Row 514 does not have new unique columns to add.
# Row 515 does not have new unique columns to add.
# Row 516 does not have new unique columns to add.
# Row 519 does not have new unique columns to add.
# Row 520 does not have new unique columns to add.
# Row 521 does not have new unique columns to add.
# Row 522 does not have new unique columns to add.
# Row 524 does not have new unique columns to add.
# Row 525 does not have new unique columns to add.
# Row 526 does not have new unique columns to add.
# Row 527 does not have new unique columns to add.
# Row 528 does not have new unique columns to add.
# Row 530 does not have new unique columns to add.
# Row 531 does not have new unique columns to add.
# Row 533 does not have new unique columns to add.
# Row 535 does not have new unique columns to add.
# Row 537 does not have new unique columns to add.
# Row 538 does not have new unique columns to add.
# Row 539 does not have new unique columns to add.
# Row 541 does not have new unique columns to add.
# Row 542 does not have new unique columns to add.
# Row 543 does not have new unique columns to add.
# Row 545 does not have new unique columns to add.
# Row 546 does not have new unique columns to add.
# Row 547 does not have new unique columns to add.
# Row 548 does not have new unique columns to add.
# Row 549 does not have new unique columns to add.
# Row 551 does not have new unique columns to add.
# Row 553 does not have new unique columns to add.
# Row 554 does not have new unique columns to add.
# Row 555 does not have new unique columns to add.
# Row 559 does not have new unique columns to add.
# Row 560 does not have new unique columns to add.
# Row 561 does not have new unique columns to add.
# Row 562 does not have new unique columns to add.
# Row 564 does not have new unique columns to add.
# Row 565 does not have new unique columns to add.
# Row 566 does not have new unique columns to add.
# Row 567 does not have new unique columns to add.
# Row 568 does not have new unique columns to add.
# Row 569 does not have new unique columns to add.
# Row 570 does not have new unique columns to add.
# Row 572 does not have new unique columns to add.
# Row 573 does not have new unique columns to add.
# Row 574 does not have new unique columns to add.
# Row 576 does not have new unique columns to add.
# Row 578 does not have new unique columns to add.
# Row 579 does not have new unique columns to add.
# Row 581 does not have new unique columns to add.
# Row 584 does not have new unique columns to add.
# Row 585 does not have new unique columns to add.
# Row 586 does not have new unique columns to add.
# Row 587 does not have new unique columns to add.
# Row 588 does not have new unique columns to add.
# Row 590 does not have new unique columns to add.
# Row 591 does not have new unique columns to add.
# Row 592 does not have new unique columns to add.
# Row 593 does not have new unique columns to add.
# Row 594 does not have new unique columns to add.
# Row 595 does not have new unique columns to add.
# Row 596 does not have new unique columns to add.
# Row 597 does not have new unique columns to add.
# Row 600 does not have new unique columns to add.
# Row 601 does not have new unique columns to add.
# Row 602 does not have new unique columns to add.
# Row 603 does not have new unique columns to add.
# Row 604 does not have new unique columns to add.
# Row 605 does not have new unique columns to add.
# Row 606 does not have new unique columns to add.
# Row 607 does not have new unique columns to add.
# Row 609 does not have new unique columns to add.
# Row 610 does not have new unique columns to add.
# Row 612 does not have new unique columns to add.
# Row 613 does not have new unique columns to add.
# Row 614 does not have new unique columns to add.
# Row 615 does not have new unique columns to add.
# Row 616 does not have new unique columns to add.
# Row 617 does not have new unique columns to add.
# Row 618 does not have new unique columns to add.
# Row 619 does not have new unique columns to add.
# Row 620 does not have new unique columns to add.
# Row 621 does not have new unique columns to add.
# Row 622 does not have new unique columns to add.
# Row 623 does not have new unique columns to add.
# Row 624 does not have new unique columns to add.
# Row 625 does not have new unique columns to add.
# Row 626 does not have new unique columns to add.
# Row 627 does not have new unique columns to add.
# Row 630 does not have new unique columns to add.
# Row 631 does not have new unique columns to add.
# Row 633 does not have new unique columns to add.
# Row 634 does not have new unique columns to add.
# Row 635 does not have new unique columns to add.
# Row 636 does not have new unique columns to add.
# Row 637 does not have new unique columns to add.
# Row 638 does not have new unique columns to add.
# Row 639 does not have new unique columns to add.
# Row 641 does not have new unique columns to add.
# Row 642 does not have new unique columns to add.
# Row 643 does not have new unique columns to add.
# Row 648 does not have new unique columns to add.
# Row 649 does not have new unique columns to add.
# Row 650 does not have new unique columns to add.
# Row 651 does not have new unique columns to add.
# Row 652 does not have new unique columns to add.
# Row 654 does not have new unique columns to add.
# Row 655 does not have new unique columns to add.
# Row 656 does not have new unique columns to add.
# Row 657 does not have new unique columns to add.
# Row 658 does not have new unique columns to add.
# Row 659 does not have new unique columns to add.
# Row 661 does not have new unique columns to add.
# Row 662 does not have new unique columns to add.
# Row 663 does not have new unique columns to add.
# Row 665 does not have new unique columns to add.
# Row 666 does not have new unique columns to add.
# Row 667 does not have new unique columns to add.
# Row 669 does not have new unique columns to add.
# Row 670 does not have new unique columns to add.
# Row 673 does not have new unique columns to add.
# Row 675 does not have new unique columns to add.
# Row 676 does not have new unique columns to add.
# Row 678 does not have new unique columns to add.
# Row 679 does not have new unique columns to add.
# Row 680 does not have new unique columns to add.
# Row 681 does not have new unique columns to add.
# Row 683 does not have new unique columns to add.
# Row 685 does not have new unique columns to add.
# Row 687 does not have new unique columns to add.
# Row 688 does not have new unique columns to add.
# Row 689 does not have new unique columns to add.
# Row 690 does not have new unique columns to add.
# Row 691 does not have new unique columns to add.
# Row 692 does not have new unique columns to add.
# Row 693 does not have new unique columns to add.
# Row 694 does not have new unique columns to add.
# Row 695 does not have new unique columns to add.
# Row 696 does not have new unique columns to add.
# Row 697 does not have new unique columns to add.
# Row 698 does not have new unique columns to add.
# Row 699 does not have new unique columns to add.
# Row 701 does not have new unique columns to add.
# Row 702 does not have new unique columns to add.
# Row 703 does not have new unique columns to add.
# Row 704 does not have new unique columns to add.
# Row 705 does not have new unique columns to add.
# Row 706 does not have new unique columns to add.
# Row 707 does not have new unique columns to add.
# Row 708 does not have new unique columns to add.
# Row 709 does not have new unique columns to add.
# Row 710 does not have new unique columns to add.
# Row 711 does not have new unique columns to add.
# Row 712 does not have new unique columns to add.
# Row 714 does not have new unique columns to add.
# Row 717 does not have new unique columns to add.
# Row 718 does not have new unique columns to add.
# Row 719 does not have new unique columns to add.
# Row 722 does not have new unique columns to add.
# Row 723 does not have new unique columns to add.
# Row 724 does not have new unique columns to add.
# Row 725 does not have new unique columns to add.
# Row 727 does not have new unique columns to add.
# Row 729 does not have new unique columns to add.
# Row 730 does not have new unique columns to add.
# Row 731 does not have new unique columns to add.
# Row 735 does not have new unique columns to add.
# Row 736 does not have new unique columns to add.
# Row 737 does not have new unique columns to add.
# Row 739 does not have new unique columns to add.
# Row 740 does not have new unique columns to add.
# Row 741 does not have new unique columns to add.
# Row 742 does not have new unique columns to add.
# Row 744 does not have new unique columns to add.
# Row 746 does not have new unique columns to add.
# Row 747 does not have new unique columns to add.
# Row 749 does not have new unique columns to add.
# Row 752 does not have new unique columns to add.
# Row 753 does not have new unique columns to add.
# Row 754 does not have new unique columns to add.
# Row 755 does not have new unique columns to add.
# Row 756 does not have new unique columns to add.
# Row 759 does not have new unique columns to add.
# Row 760 does not have new unique columns to add.
# Row 762 does not have new unique columns to add.
# Row 763 does not have new unique columns to add.
# Row 765 does not have new unique columns to add.
# Row 767 does not have new unique columns to add.
# Row 768 does not have new unique columns to add.
# Row 769 does not have new unique columns to add.
# Row 771 does not have new unique columns to add.
# Row 772 does not have new unique columns to add.
# Row 773 does not have new unique columns to add.
# Row 774 does not have new unique columns to add.
# Row 775 does not have new unique columns to add.
# Row 777 does not have new unique columns to add.
# Row 778 does not have new unique columns to add.
# Row 780 does not have new unique columns to add.
# Row 781 does not have new unique columns to add.
# Row 782 does not have new unique columns to add.
# Row 783 does not have new unique columns to add.
# Row 785 does not have new unique columns to add.
# Row 786 does not have new unique columns to add.
# Row 789 does not have new unique columns to add.
# Row 790 does not have new unique columns to add.
# Row 791 does not have new unique columns to add.
# Row 792 does not have new unique columns to add.
# Row 793 does not have new unique columns to add.
# Row 796 does not have new unique columns to add.
# Row 797 does not have new unique columns to add.
# Row 799 does not have new unique columns to add.
# Row 801 does not have new unique columns to add.
# Row 802 does not have new unique columns to add.
# Row 803 does not have new unique columns to add.
# Row 804 does not have new unique columns to add.
# Row 807 does not have new unique columns to add.
# Row 808 does not have new unique columns to add.
# Row 809 does not have new unique columns to add.
# Row 810 does not have new unique columns to add.
# Row 811 does not have new unique columns to add.
# Row 812 does not have new unique columns to add.
# Row 813 does not have new unique columns to add.
# Row 814 does not have new unique columns to add.
# Row 815 does not have new unique columns to add.
# Row 818 does not have new unique columns to add.
# Row 820 does not have new unique columns to add.
# Row 821 does not have new unique columns to add.
# Row 822 does not have new unique columns to add.
# Row 823 does not have new unique columns to add.
# Row 824 does not have new unique columns to add.
# Row 825 does not have new unique columns to add.
# Row 827 does not have new unique columns to add.
# Row 828 does not have new unique columns to add.
# Row 829 does not have new unique columns to add.
# Row 830 does not have new unique columns to add.
# Row 831 does not have new unique columns to add.
# Row 832 does not have new unique columns to add.
# Row 833 does not have new unique columns to add.
# Row 834 does not have new unique columns to add.
# Row 836 does not have new unique columns to add.
# Row 837 does not have new unique columns to add.
# Row 839 does not have new unique columns to add.
# Row 840 does not have new unique columns to add.
# Row 841 does not have new unique columns to add.
# Row 842 does not have new unique columns to add.
# Row 843 does not have new unique columns to add.
# Row 845 does not have new unique columns to add.
# Row 847 does not have new unique columns to add.
# Row 848 does not have new unique columns to add.
# Row 849 does not have new unique columns to add.
# Row 851 does not have new unique columns to add.
# Row 852 does not have new unique columns to add.
# Row 853 does not have new unique columns to add.
# Row 854 does not have new unique columns to add.
# Row 855 does not have new unique columns to add.
# Row 860 does not have new unique columns to add.
# Row 863 does not have new unique columns to add.
# Row 865 does not have new unique columns to add.
# Row 867 does not have new unique columns to add.
# Row 868 does not have new unique columns to add.
# Row 869 does not have new unique columns to add.
# Row 870 does not have new unique columns to add.
# Row 871 does not have new unique columns to add.
# Row 872 does not have new unique columns to add.
# Row 873 does not have new unique columns to add.
# Row 874 does not have new unique columns to add.
# Row 875 does not have new unique columns to add.
# Row 876 does not have new unique columns to add.
# Row 877 does not have new unique columns to add.
# Row 878 does not have new unique columns to add.
# Row 879 does not have new unique columns to add.
# Row 880 does not have new unique columns to add.
# Row 881 does not have new unique columns to add.
# Row 882 does not have new unique columns to add.
# Row 883 does not have new unique columns to add.
# Row 884 does not have new unique columns to add.
# Row 885 does not have new unique columns to add.
# Row 886 does not have new unique columns to add.
# Row 888 does not have new unique columns to add.
# Row 889 does not have new unique columns to add.
# Row 890 does not have new unique columns to add.
# Row 891 does not have new unique columns to add.
# Row 892 does not have new unique columns to add.
# Row 893 does not have new unique columns to add.
# Row 894 does not have new unique columns to add.
# Row 895 does not have new unique columns to add.
# Row 896 does not have new unique columns to add.
# Row 900 does not have new unique columns to add.
# Row 902 does not have new unique columns to add.
# Row 903 does not have new unique columns to add.
# Row 904 does not have new unique columns to add.
# Row 905 does not have new unique columns to add.
# Row 906 does not have new unique columns to add.
# Row 907 does not have new unique columns to add.
# Row 909 does not have new unique columns to add.
# Row 911 does not have new unique columns to add.
# Row 913 does not have new unique columns to add.
# Row 914 does not have new unique columns to add.
# Row 915 does not have new unique columns to add.
# Row 916 does not have new unique columns to add.
# Row 917 does not have new unique columns to add.
# Row 918 does not have new unique columns to add.
# Row 919 does not have new unique columns to add.
# Row 920 does not have new unique columns to add.
# Row 921 does not have new unique columns to add.
# Row 922 does not have new unique columns to add.
# Row 923 does not have new unique columns to add.
# Row 924 does not have new unique columns to add.
# Row 925 does not have new unique columns to add.
# Row 926 does not have new unique columns to add.
# Row 927 does not have new unique columns to add.
# Row 928 does not have new unique columns to add.
# Row 929 does not have new unique columns to add.
# Row 930 does not have new unique columns to add.
# Row 931 does not have new unique columns to add.
# Row 934 does not have new unique columns to add.
# Row 935 does not have new unique columns to add.
# Row 936 does not have new unique columns to add.
# Row 937 does not have new unique columns to add.
# Row 938 does not have new unique columns to add.
# Row 939 does not have new unique columns to add.
# Row 940 does not have new unique columns to add.
# Row 941 does not have new unique columns to add.
# Row 943 does not have new unique columns to add.
# Row 944 does not have new unique columns to add.
# Row 945 does not have new unique columns to add.
# Row 946 does not have new unique columns to add.
# Row 947 does not have new unique columns to add.
# Row 948 does not have new unique columns to add.
# Row 950 does not have new unique columns to add.
# Row 951 does not have new unique columns to add.
# Row 952 does not have new unique columns to add.
# Row 953 does not have new unique columns to add.
# Row 954 does not have new unique columns to add.
# Row 956 does not have new unique columns to add.
# Row 957 does not have new unique columns to add.
# Row 958 does not have new unique columns to add.
# Row 960 does not have new unique columns to add.
# Row 961 does not have new unique columns to add.
# Row 962 does not have new unique columns to add.
# Row 963 does not have new unique columns to add.
# Row 964 does not have new unique columns to add.
# Row 965 does not have new unique columns to add.
# Row 967 does not have new unique columns to add.
# Row 968 does not have new unique columns to add.
# Row 969 does not have new unique columns to add.
# Row 970 does not have new unique columns to add.
# Row 971 does not have new unique columns to add.
# Row 972 does not have new unique columns to add.
# Row 973 does not have new unique columns to add.
# Row 974 does not have new unique columns to add.
# Row 975 does not have new unique columns to add.
# Row 976 does not have new unique columns to add.
# Row 977 does not have new unique columns to add.
# Row 978 does not have new unique columns to add.
# Row 979 does not have new unique columns to add.
# Row 980 does not have new unique columns to add.
# Row 981 does not have new unique columns to add.
# Row 982 does not have new unique columns to add.
# Row 983 does not have new unique columns to add.
# Row 985 does not have new unique columns to add.
# Row 986 does not have new unique columns to add.
# Row 988 does not have new unique columns to add.
# Row 989 does not have new unique columns to add.
# Row 990 does not have new unique columns to add.
# Row 991 does not have new unique columns to add.
# Row 992 does not have new unique columns to add.
# Row 993 does not have new unique columns to add.
# Row 994 does not have new unique columns to add.
# Row 995 does not have new unique columns to add.
# Row 996 does not have new unique columns to add.
# Row 997 does not have new unique columns to add.
# Row 998 does not have new unique columns to add.
# Row 999 does not have new unique columns to add.
# Row 1000 does not have new unique columns to add.
# Row 1001 does not have new unique columns to add.
# Row 1002 does not have new unique columns to add.
# Row 1003 does not have new unique columns to add.
# Row 1004 does not have new unique columns to add.
# Row 1005 does not have new unique columns to add.
# Row 1007 does not have new unique columns to add.
# Row 1008 does not have new unique columns to add.
# Row 1009 does not have new unique columns to add.
# Row 1010 does not have new unique columns to add.
# Row 1011 does not have new unique columns to add.
# Row 1012 does not have new unique columns to add.
# Row 1013 does not have new unique columns to add.
# Row 1014 does not have new unique columns to add.
# Row 1015 does not have new unique columns to add.
# Row 1017 does not have new unique columns to add.
# Row 1018 does not have new unique columns to add.
# Row 1020 does not have new unique columns to add.
# Row 1022 does not have new unique columns to add.
# Row 1023 does not have new unique columns to add.
# Row 1024 does not have new unique columns to add.
# Row 1026 does not have new unique columns to add.
# Row 1027 does not have new unique columns to add.
# Row 1028 does not have new unique columns to add.
# Row 1029 does not have new unique columns to add.
# Row 1031 does not have new unique columns to add.
# Row 1032 does not have new unique columns to add.
# Row 1033 does not have new unique columns to add.
# Row 1034 does not have new unique columns to add.
# Row 1035 does not have new unique columns to add.
# Row 1036 does not have new unique columns to add.
# Row 1037 does not have new unique columns to add.
# Row 1038 does not have new unique columns to add.
# Row 1039 does not have new unique columns to add.
# Row 1040 does not have new unique columns to add.
# Row 1041 does not have new unique columns to add.
# Row 1042 does not have new unique columns to add.
# Row 1043 does not have new unique columns to add.
# Row 1044 does not have new unique columns to add.
# Row 1045 does not have new unique columns to add.
# Row 1046 does not have new unique columns to add.
# Row 1047 does not have new unique columns to add.
# Row 1048 does not have new unique columns to add.
# Row 1049 does not have new unique columns to add.
# Row 1050 does not have new unique columns to add.
# Row 1051 does not have new unique columns to add.
# Row 1052 does not have new unique columns to add.
# Row 1053 does not have new unique columns to add.
# Row 1055 does not have new unique columns to add.
# Row 1056 does not have new unique columns to add.
# Row 1057 does not have new unique columns to add.
# Row 1058 does not have new unique columns to add.
# Row 1059 does not have new unique columns to add.
# Row 1060 does not have new unique columns to add.
# Row 1061 does not have new unique columns to add.
# Row 1063 does not have new unique columns to add.
# Row 1064 does not have new unique columns to add.
# Row 1066 does not have new unique columns to add.
# Row 1068 does not have new unique columns to add.
# Row 1069 does not have new unique columns to add.
# Row 1070 does not have new unique columns to add.
# Row 1071 does not have new unique columns to add.
# Row 1073 does not have new unique columns to add.
# Row 1074 does not have new unique columns to add.
# Row 1075 does not have new unique columns to add.
# Row 1076 does not have new unique columns to add.
# Row 1077 does not have new unique columns to add.
# Row 1079 does not have new unique columns to add.
# Row 1080 does not have new unique columns to add.
# Row 1081 does not have new unique columns to add.
# Row 1082 does not have new unique columns to add.
# Row 1083 does not have new unique columns to add.
# Row 1084 does not have new unique columns to add.
# Row 1085 does not have new unique columns to add.
# Row 1086 does not have new unique columns to add.
# Row 1088 does not have new unique columns to add.
# Row 1089 does not have new unique columns to add.
# Row 1090 does not have new unique columns to add.
# Row 1092 does not have new unique columns to add.
# Row 1093 does not have new unique columns to add.
# Row 1094 does not have new unique columns to add.
# Row 1095 does not have new unique columns to add.
# Row 1096 does not have new unique columns to add.
# Row 1098 does not have new unique columns to add.
# Row 1100 does not have new unique columns to add.
# Row 1102 does not have new unique columns to add.
# Row 1104 does not have new unique columns to add.
# Row 1105 does not have new unique columns to add.
# Row 1106 does not have new unique columns to add.
# Row 1107 does not have new unique columns to add.
# Row 1108 does not have new unique columns to add.
# Row 1109 does not have new unique columns to add.
# Row 1110 does not have new unique columns to add.
# Row 1111 does not have new unique columns to add.
# Row 1112 does not have new unique columns to add.
# Row 1113 does not have new unique columns to add.
# Row 1116 does not have new unique columns to add.
# Row 1117 does not have new unique columns to add.
# Row 1118 does not have new unique columns to add.
# Row 1119 does not have new unique columns to add.
# Row 1120 does not have new unique columns to add.
# Row 1121 does not have new unique columns to add.
# Row 1122 does not have new unique columns to add.
# Row 1123 does not have new unique columns to add.
# Row 1124 does not have new unique columns to add.
# Row 1125 does not have new unique columns to add.
# Row 1126 does not have new unique columns to add.
# Row 1127 does not have new unique columns to add.
# Row 1128 does not have new unique columns to add.
# Row 1129 does not have new unique columns to add.
# Row 1130 does not have new unique columns to add.
# Row 1131 does not have new unique columns to add.
# Row 1133 does not have new unique columns to add.
# Row 1134 does not have new unique columns to add.
# Row 1135 does not have new unique columns to add.
# Row 1136 does not have new unique columns to add.
# Row 1137 does not have new unique columns to add.
# Row 1138 does not have new unique columns to add.
# Row 1139 does not have new unique columns to add.
# Row 1141 does not have new unique columns to add.
# Row 1142 does not have new unique columns to add.
# Row 1143 does not have new unique columns to add.
# Row 1145 does not have new unique columns to add.
# Row 1146 does not have new unique columns to add.
# Row 1148 does not have new unique columns to add.
# Row 1149 does not have new unique columns to add.
# Row 1150 does not have new unique columns to add.
# Row 1151 does not have new unique columns to add.
# Row 1152 does not have new unique columns to add.
# Row 1153 does not have new unique columns to add.
# Row 1154 does not have new unique columns to add.
# Row 1155 does not have new unique columns to add.
# Row 1156 does not have new unique columns to add.
# Row 1157 does not have new unique columns to add.
# Row 1158 does not have new unique columns to add.
# Row 1159 does not have new unique columns to add.
# Row 1160 does not have new unique columns to add.
# Row 1161 does not have new unique columns to add.
# Row 1162 does not have new unique columns to add.
# Row 1163 does not have new unique columns to add.
# Row 1164 does not have new unique columns to add.
# Row 1165 does not have new unique columns to add.
# Row 1166 does not have new unique columns to add.
# Row 1167 does not have new unique columns to add.
# Row 1169 does not have new unique columns to add.
# Row 1170 does not have new unique columns to add.
# Row 1171 does not have new unique columns to add.
# Row 1172 does not have new unique columns to add.
# Row 1174 does not have new unique columns to add.
# Row 1175 does not have new unique columns to add.
# Row 1176 does not have new unique columns to add.
# Row 1178 does not have new unique columns to add.
# Row 1179 does not have new unique columns to add.
# Row 1180 does not have new unique columns to add.
# Row 1181 does not have new unique columns to add.
# Row 1182 does not have new unique columns to add.
# Row 1183 does not have new unique columns to add.
# Row 1184 does not have new unique columns to add.
# Row 1185 does not have new unique columns to add.
# Row 1186 does not have new unique columns to add.
# Row 1187 does not have new unique columns to add.
# Row 1188 does not have new unique columns to add.
# Row 1189 does not have new unique columns to add.
# Row 1190 does not have new unique columns to add.
# Row 1191 does not have new unique columns to add.
# Row 1192 does not have new unique columns to add.
# Row 1193 does not have new unique columns to add.
# Row 1194 does not have new unique columns to add.
# Row 1195 does not have new unique columns to add.
# Row 1196 does not have new unique columns to add.
# Row 1199 does not have new unique columns to add.
# Row 1200 does not have new unique columns to add.
# Row 1201 does not have new unique columns to add.
# Row 1202 does not have new unique columns to add.
# Row 1203 does not have new unique columns to add.
# Row 1204 does not have new unique columns to add.
# Row 1205 does not have new unique columns to add.
# Row 1206 does not have new unique columns to add.
# Row 1207 does not have new unique columns to add.
# Row 1208 does not have new unique columns to add.
# Row 1209 does not have new unique columns to add.
# Row 1210 does not have new unique columns to add.
# Row 1211 does not have new unique columns to add.
# Row 1212 does not have new unique columns to add.
# Row 1213 does not have new unique columns to add.
# Row 1214 does not have new unique columns to add.
# Row 1215 does not have new unique columns to add.
# Row 1216 does not have new unique columns to add.
# Row 1217 does not have new unique columns to add.
# Row 1218 does not have new unique columns to add.
# Row 1219 does not have new unique columns to add.
# Row 1220 does not have new unique columns to add.
# Row 1221 does not have new unique columns to add.
# Row 1222 does not have new unique columns to add.
# Row 1224 does not have new unique columns to add.
# Row 1225 does not have new unique columns to add.
# Row 1226 does not have new unique columns to add.
# Row 1227 does not have new unique columns to add.
# Row 1228 does not have new unique columns to add.
# Row 1229 does not have new unique columns to add.
# Row 1230 does not have new unique columns to add.
# Row 1232 does not have new unique columns to add.
# Row 1233 does not have new unique columns to add.
# Row 1234 does not have new unique columns to add.
# Row 1235 does not have new unique columns to add.
# Row 1236 does not have new unique columns to add.
# Row 1237 does not have new unique columns to add.
# Row 1238 does not have new unique columns to add.
# Row 1239 does not have new unique columns to add.
# Row 1240 does not have new unique columns to add.
# Row 1241 does not have new unique columns to add.
# Row 1242 does not have new unique columns to add.
# Row 1244 does not have new unique columns to add.
# Row 1245 does not have new unique columns to add.
# Row 1248 does not have new unique columns to add.
# Row 1250 does not have new unique columns to add.
# Row 1251 does not have new unique columns to add.
# Row 1252 does not have new unique columns to add.
# Row 1253 does not have new unique columns to add.
# Row 1255 does not have new unique columns to add.
# Row 1256 does not have new unique columns to add.
# Row 1257 does not have new unique columns to add.
# Row 1258 does not have new unique columns to add.
# Row 1259 does not have new unique columns to add.
# Row 1260 does not have new unique columns to add.
# Row 1261 does not have new unique columns to add.
# Row 1262 does not have new unique columns to add.
# Row 1263 does not have new unique columns to add.
# Row 1264 does not have new unique columns to add.
# Row 1265 does not have new unique columns to add.
# Row 1266 does not have new unique columns to add.
# Row 1267 does not have new unique columns to add.
# Row 1269 does not have new unique columns to add.
# Row 1270 does not have new unique columns to add.
# Row 1271 does not have new unique columns to add.
# Row 1273 does not have new unique columns to add.
# Row 1274 does not have new unique columns to add.
# Row 1275 does not have new unique columns to add.
# Row 1277 does not have new unique columns to add.
# Row 1278 does not have new unique columns to add.
# Row 1279 does not have new unique columns to add.
# Row 1280 does not have new unique columns to add.
# Row 1282 does not have new unique columns to add.
# Row 1283 does not have new unique columns to add.
# Row 1284 does not have new unique columns to add.
# Row 1285 does not have new unique columns to add.
# Row 1287 does not have new unique columns to add.
# Row 1288 does not have new unique columns to add.
# Row 1289 does not have new unique columns to add.
# Row 1290 does not have new unique columns to add.
# Row 1291 does not have new unique columns to add.
# Row 1292 does not have new unique columns to add.
# Row 1293 does not have new unique columns to add.
# Row 1294 does not have new unique columns to add.
# Row 1296 does not have new unique columns to add.
# Row 1297 does not have new unique columns to add.
# Row 1298 does not have new unique columns to add.
# Row 1299 does not have new unique columns to add.
# Row 1301 does not have new unique columns to add.
# Row 1302 does not have new unique columns to add.
# Row 1305 does not have new unique columns to add.
# Row 1306 does not have new unique columns to add.
# Row 1307 does not have new unique columns to add.
# Row 1308 does not have new unique columns to add.
# Row 1309 does not have new unique columns to add.
# Row 1310 does not have new unique columns to add.
# Row 1311 does not have new unique columns to add.
# Row 1312 does not have new unique columns to add.
# Row 1313 does not have new unique columns to add.
# Row 1315 does not have new unique columns to add.
# Row 1316 does not have new unique columns to add.
# Row 1317 does not have new unique columns to add.
# Row 1318 does not have new unique columns to add.
# Row 1319 does not have new unique columns to add.
# Row 1321 does not have new unique columns to add.
# Row 1323 does not have new unique columns to add.
# Row 1324 does not have new unique columns to add.
# Row 1325 does not have new unique columns to add.
# Row 1326 does not have new unique columns to add.
# Row 1327 does not have new unique columns to add.
# Row 1328 does not have new unique columns to add.
# Row 1329 does not have new unique columns to add.
# Row 1330 does not have new unique columns to add.
# Row 1331 does not have new unique columns to add.
# Row 1332 does not have new unique columns to add.
# Row 1333 does not have new unique columns to add.
# Row 1334 does not have new unique columns to add.
# Row 1335 does not have new unique columns to add.
# Row 1336 does not have new unique columns to add.
# Row 1337 does not have new unique columns to add.
# Row 1338 does not have new unique columns to add.
# Row 1339 does not have new unique columns to add.
# Row 1340 does not have new unique columns to add.
# Row 1341 does not have new unique columns to add.
# Row 1342 does not have new unique columns to add.
# Row 1343 does not have new unique columns to add.
# Row 1344 does not have new unique columns to add.
# Row 1345 does not have new unique columns to add.
# Row 1348 does not have new unique columns to add.
# Row 1349 does not have new unique columns to add.
# Row 1350 does not have new unique columns to add.
# Row 1351 does not have new unique columns to add.
# Row 1352 does not have new unique columns to add.
# Row 1353 does not have new unique columns to add.
# Row 1354 does not have new unique columns to add.
# Row 1355 does not have new unique columns to add.
# Row 1357 does not have new unique columns to add.
# Row 1359 does not have new unique columns to add.
# Row 1360 does not have new unique columns to add.
# Row 1361 does not have new unique columns to add.
# Row 1362 does not have new unique columns to add.
# Row 1363 does not have new unique columns to add.
# Row 1364 does not have new unique columns to add.
# Row 1365 does not have new unique columns to add.
# Row 1366 does not have new unique columns to add.
# Row 1367 does not have new unique columns to add.
# Row 1368 does not have new unique columns to add.
# Row 1369 does not have new unique columns to add.
# Row 1370 does not have new unique columns to add.
# Row 1371 does not have new unique columns to add.
# Row 1372 does not have new unique columns to add.
# Row 1373 does not have new unique columns to add.
# Row 1375 does not have new unique columns to add.
# Row 1376 does not have new unique columns to add.
# Row 1377 does not have new unique columns to add.
# Row 1379 does not have new unique columns to add.
# Row 1380 does not have new unique columns to add.
# Row 1381 does not have new unique columns to add.
# Row 1382 does not have new unique columns to add.
# Row 1383 does not have new unique columns to add.
# Row 1384 does not have new unique columns to add.
# Row 1385 does not have new unique columns to add.
# Row 1386 does not have new unique columns to add.
# ...
# Row 1762 does not have new unique columns to add.
# Row 1763 does not have new unique columns to add.
# Row 1764 does not have new unique columns to add.
# Row 1765 does not have new unique columns to add.
# Row 1768 does not have new unique columns to add.
# Row 1769 does not have new unique columns to add.
# Row 1770 does not have new unique columns to add.
# Row 1771 does not have new unique columns to add.
# Row 1772 does not have new unique columns to add.
# Row 1773 does not have new unique columns to add.
# Row 1774 does not have new unique columns to add.
# Row 1775 does not have new unique columns to add.
# Row 1776 does not have new unique columns to add.
# Row 1777 does not have new unique columns to add.
# Row 1778 does not have new unique columns to add.
# Row 1779 does not have new unique columns to add.
# Row 1780 does not have new unique columns to add.
# Row 1781 does not have new unique columns to add.
# Row 1782 does not have new unique columns to add.
# Row 1783 does not have new unique columns to add.
# Row 1784 does not have new unique columns to add.
# Row 1785 does not have new unique columns to add.
# Row 1786 does not have new unique columns to add.
# Row 1787 does not have new unique columns to add.
# Row 1788 does not have new unique columns to add.
# Row 1789 does not have new unique columns to add.
# Row 1790 does not have new unique columns to add.
# Row 1791 does not have new unique columns to add.
# Row 1792 does not have new unique columns to add.
# Row 1793 does not have new unique columns to add.
# Row 1794 does not have new unique columns to add.
# Row 1795 does not have new unique columns to add.
# Row 1796 does not have new unique columns to add.
# Row 1797 does not have new unique columns to add.
# Row 1798 does not have new unique columns to add.
# Row 1799 does not have new unique columns to add.
# Row 1800 does not have new unique columns to add.
# Row 1801 does not have new unique columns to add.
# Row 1802 does not have new unique columns to add.
# Row 1803 does not have new unique columns to add.
# Row 1804 does not have new unique columns to add.
# Row 1805 does not have new unique columns to add.
# Row 1806 does not have new unique columns to add.
# Row 1807 does not have new unique columns to add.
# Row 1808 does not have new unique columns to add.
# Row 1809 does not have new unique columns to add.
# Row 1811 does not have new unique columns to add.
# Row 1812 does not have new unique columns to add.
# Row 1813 does not have new unique columns to add.
# Row 1814 does not have new unique columns to add.
# Row 1815 does not have new unique columns to add.
# Row 1817 does not have new unique columns to add.
# Row 1818 does not have new unique columns to add.
# Row 1819 does not have new unique columns to add.
# Row 1820 does not have new unique columns to add.
# Row 1821 does not have new unique columns to add.
# Row 1822 does not have new unique columns to add.
# Row 1823 does not have new unique columns to add.
# Row 1824 does not have new unique columns to add.
# Row 1825 does not have new unique columns to add.
# Row 1827 does not have new unique columns to add.
# Row 1828 does not have new unique columns to add.
# Row 1830 does not have new unique columns to add.
# Row 1831 does not have new unique columns to add.
# Row 1832 does not have new unique columns to add.
# Row 1833 does not have new unique columns to add.
# Row 1834 does not have new unique columns to add.
# Row 1836 does not have new unique columns to add.
# Row 1837 does not have new unique columns to add.
# Row 1838 does not have new unique columns to add.
# Row 1839 does not have new unique columns to add.
# Row 1840 does not have new unique columns to add.
# Row 1841 does not have new unique columns to add.
# Row 1842 does not have new unique columns to add.
# Row 1843 does not have new unique columns to add.
# Row 1844 does not have new unique columns to add.
# Row 1845 does not have new unique columns to add.
# Row 1846 does not have new unique columns to add.
# Row 1848 does not have new unique columns to add.
# Row 1849 does not have new unique columns to add.
# Row 1850 does not have new unique columns to add.
# Row 1851 does not have new unique columns to add.
# Row 1853 does not have new unique columns to add.
# Row 1854 does not have new unique columns to add.
# Row 1855 does not have new unique columns to add.
# Row 1856 does not have new unique columns to add.
# Row 1857 does not have new unique columns to add.
# Row 1858 does not have new unique columns to add.
# Row 1859 does not have new unique columns to add.
# Row 1861 does not have new unique columns to add.
# Row 1862 does not have new unique columns to add.
# Row 1863 does not have new unique columns to add.
# Row 1864 does not have new unique columns to add.
# Row 1865 does not have new unique columns to add.
# Row 1866 does not have new unique columns to add.
# Row 1867 does not have new unique columns to add.
# Row 1868 does not have new unique columns to add.
# Row 1869 does not have new unique columns to add.
# Row 1870 does not have new unique columns to add.
# Row 1871 does not have new unique columns to add.
# Row 1872 does not have new unique columns to add.
# Row 1873 does not have new unique columns to add.
# Row 1874 does not have new unique columns to add.
# Row 1875 does not have new unique columns to add.
# Row 1876 does not have new unique columns to add.
# Row 1877 does not have new unique columns to add.
# Row 1878 does not have new unique columns to add.
# Row 1879 does not have new unique columns to add.
# Row 1880 does not have new unique columns to add.
# Row 1881 does not have new unique columns to add.
# Row 1882 does not have new unique columns to add.
# Row 1883 does not have new unique columns to add.
# Row 1884 does not have new unique columns to add.
# Row 1885 does not have new unique columns to add.
# Row 1886 does not have new unique columns to add.
# Row 1887 does not have new unique columns to add.
# Row 1888 does not have new unique columns to add.
# Row 1889 does not have new unique columns to add.
# Row 1891 does not have new unique columns to add.
# Row 1892 does not have new unique columns to add.
# Row 1893 does not have new unique columns to add.
# Row 1894 does not have new unique columns to add.
# Row 1895 does not have new unique columns to add.
# Row 1896 does not have new unique columns to add.
# Row 1897 does not have new unique columns to add.
# Row 1898 does not have new unique columns to add.
# Row 1899 does not have new unique columns to add.
# Row 1900 does not have new unique columns to add.
# Row 1901 does not have new unique columns to add.
# Row 1902 does not have new unique columns to add.
# Row 1903 does not have new unique columns to add.
# Row 1904 does not have new unique columns to add.
# Row 1905 does not have new unique columns to add.
# Row 1906 does not have new unique columns to add.
# Row 1907 does not have new unique columns to add.
# Row 1908 does not have new unique columns to add.
# Row 1910 does not have new unique columns to add.
# Row 1911 does not have new unique columns to add.
# Row 1912 does not have new unique columns to add.
# Row 1913 does not have new unique columns to add.
# Row 1914 does not have new unique columns to add.
# Row 1915 does not have new unique columns to add.
# Row 1917 does not have new unique columns to add.
# Row 1918 does not have new unique columns to add.
# Row 1919 does not have new unique columns to add.
# Row 1920 does not have new unique columns to add.
# Row 1921 does not have new unique columns to add.
# Row 1922 does not have new unique columns to add.
# Row 1923 does not have new unique columns to add.
# Row 1924 does not have new unique columns to add.
# Row 1925 does not have new unique columns to add.
# Row 1926 does not have new unique columns to add.
# Row 1927 does not have new unique columns to add.
# Row 1928 does not have new unique columns to add.
# Row 1929 does not have new unique columns to add.
# Row 1930 does not have new unique columns to add.
# Row 1931 does not have new unique columns to add.
# Row 1932 does not have new unique columns to add.
# Row 1933 does not have new unique columns to add.
# Row 1934 does not have new unique columns to add.
# Row 1935 does not have new unique columns to add.
# Row 1936 does not have new unique columns to add.
# Row 1937 does not have new unique columns to add.
# Row 1938 does not have new unique columns to add.
# Row 1940 does not have new unique columns to add.
# Row 1941 does not have new unique columns to add.
# Row 1942 does not have new unique columns to add.
# Row 1943 does not have new unique columns to add.
# Row 1944 does not have new unique columns to add.
# Row 1945 does not have new unique columns to add.
# Row 1946 does not have new unique columns to add.
# Row 1947 does not have new unique columns to add.
# Row 1948 does not have new unique columns to add.
# Row 1949 does not have new unique columns to add.
# Row 1950 does not have new unique columns to add.
# Row 1951 does not have new unique columns to add.
# Row 1952 does not have new unique columns to add.
# Row 1953 does not have new unique columns to add.
# Row 1954 does not have new unique columns to add.
# Row 1955 does not have new unique columns to add.
# Row 1956 does not have new unique columns to add.
# Row 1957 does not have new unique columns to add.
# Row 1958 does not have new unique columns to add.
# Row 1959 does not have new unique columns to add.
# Row 1960 does not have new unique columns to add.
# Row 1961 does not have new unique columns to add.
# Row 1962 does not have new unique columns to add.
# Row 1964 does not have new unique columns to add.
# Row 1965 does not have new unique columns to add.
# Row 1966 does not have new unique columns to add.
# Row 1967 does not have new unique columns to add.
# Row 1968 does not have new unique columns to add.
# Row 1969 does not have new unique columns to add.
# Row 1970 does not have new unique columns to add.
# Row 1971 does not have new unique columns to add.
# Row 1972 does not have new unique columns to add.
# Row 1973 does not have new unique columns to add.
# Row 1974 does not have new unique columns to add.
# Row 1975 does not have new unique columns to add.
# Row 1976 does not have new unique columns to add.
# Row 1977 does not have new unique columns to add.
# Row 1978 does not have new unique columns to add.
# Row 1979 does not have new unique columns to add.
# Row 1980 does not have new unique columns to add.
# Row 1981 does not have new unique columns to add.
# Row 1983 does not have new unique columns to add.
# Row 1984 does not have new unique columns to add.
# Row 1985 does not have new unique columns to add.
# Row 1987 does not have new unique columns to add.
# Row 1988 does not have new unique columns to add.
# Row 1989 does not have new unique columns to add.
# Row 1990 does not have new unique columns to add.
# Row 1991 does not have new unique columns to add.
# Row 1992 does not have new unique columns to add.
# Row 1993 does not have new unique columns to add.
# Row 1994 does not have new unique columns to add.
# Row 1995 does not have new unique columns to add.
# Row 1996 does not have new unique columns to add.
# Row 1997 does not have new unique columns to add.
# Row 1998 does not have new unique columns to add.
# Row 1999 does not have new unique columns to add.
# Row 2000 does not have new unique columns to add.
# Row 2001 does not have new unique columns to add.
# Row 2002 does not have new unique columns to add.
# Row 2003 does not have new unique columns to add.
# Row 2004 does not have new unique columns to add.
# Row 2005 does not have new unique columns to add.
# Row 2006 does not have new unique columns to add.
# Row 2007 does not have new unique columns to add.
# Row 2008 does not have new unique columns to add.
# Row 2009 does not have new unique columns to add.
# Row 2010 does not have new unique columns to add.
# Row 2011 does not have new unique columns to add.
# Row 2012 does not have new unique columns to add.
# Row 2013 does not have new unique columns to add.
# Row 2014 does not have new unique columns to add.
# Row 2015 does not have new unique columns to add.
# Row 2016 does not have new unique columns to add.
# Row 2017 does not have new unique columns to add.
# Row 2018 does not have new unique columns to add.
# Row 2020 does not have new unique columns to add.
# Row 2021 does not have new unique columns to add.
# Row 2022 does not have new unique columns to add.
# Row 2023 does not have new unique columns to add.
# Row 2024 does not have new unique columns to add.
# Row 2025 does not have new unique columns to add.
# Row 2026 does not have new unique columns to add.
# Row 2027 does not have new unique columns to add.
# Row 2028 does not have new unique columns to add.
# Row 2029 does not have new unique columns to add.
# Row 2030 does not have new unique columns to add.
# Row 2031 does not have new unique columns to add.
# Row 2032 does not have new unique columns to add.
# Row 2033 does not have new unique columns to add.
# Row 2034 does not have new unique columns to add.
# Row 2035 does not have new unique columns to add.
# Row 2036 does not have new unique columns to add.
# Row 2037 does not have new unique columns to add.
# Row 2038 does not have new unique columns to add.
# Row 2039 does not have new unique columns to add.
# Row 2040 does not have new unique columns to add.
# Row 2041 does not have new unique columns to add.
# Row 2042 does not have new unique columns to add.
# Row 2043 does not have new unique columns to add.
# Row 2044 does not have new unique columns to add.
# Row 2045 does not have new unique columns to add.
# Row 2046 does not have new unique columns to add.
# Row 2047 does not have new unique columns to add.
# Row 2048 does not have new unique columns to add.
# Row 2049 does not have new unique columns to add.
# Row 2050 does not have new unique columns to add.
# Row 2051 does not have new unique columns to add.
# Row 2052 does not have new unique columns to add.
# Row 2054 does not have new unique columns to add.
# Row 2055 does not have new unique columns to add.
# Row 2056 does not have new unique columns to add.
#      PRKCZ  RPL22  TNFRSF9  PIK3CD  CTNNBIP1   MTOR  PLA2G2D   WNT4  RUNX3  \
# 0   -0.001 -0.001   -0.001  -0.001    -0.001 -0.001   -0.001 -0.001 -0.001
# 1    0.304  0.363    0.333   0.338     0.338  0.338    0.338  0.338  0.262
# 2   -0.071 -0.071   -0.071  -0.071    -0.071 -0.071   -0.071 -0.071 -0.071
# 3   -0.423 -0.423   -0.423  -0.423    -0.423 -0.423   -0.427 -0.427 -0.387
# 4    0.100  0.100    0.100   0.100     0.100  0.100    0.108  0.083  0.709
# ..     ...    ...      ...     ...       ...    ...      ...    ...    ...
# 765 -0.013 -0.013   -0.013  -0.013    -0.013 -0.013   -0.013 -0.013 -0.013
# 766 -0.525 -0.525   -0.525  -0.525    -0.525 -0.525   -0.525 -0.525 -0.525
# 767  0.053  0.053    0.053   0.053     0.053  0.053    0.053  0.053  0.053
# 768 -0.373 -0.373   -0.373  -0.373    -0.373 -0.373   -0.373 -0.365 -0.365
# 769 -0.428 -0.428   -0.428  -0.428    -0.428 -0.428   -0.428 -0.428 -0.428
#
#      ZNF683  ...  TOPAZ1  AKR7A3    HYI  GRHPR  MSTO1   ARMC1   CLUH  GPR101  \
# 0    -0.001  ...  -0.018  -0.001 -0.001 -0.008 -0.001  0.1920  0.002  0.0300
# 1     0.262  ...  -0.629   0.338  0.310  0.258  1.207 -0.0180 -0.709  0.7000
# 2    -0.071  ...   0.001  -0.071 -0.071 -0.069  0.275  0.1520  0.008  0.0010
# 3    -0.387  ...  -0.753  -0.427 -0.387 -0.312  1.199  0.1170 -0.837 -0.1500
# 4     0.033  ...  -0.604   0.108  0.065 -0.593  1.086  0.6550  0.630  0.2420
# ..      ...  ...     ...     ...    ...    ...    ...     ...    ...     ...
# 765  -0.013  ...   0.004  -0.013 -0.016 -0.002  1.034  0.0074 -0.020  0.0010
# 766  -0.525  ...   0.255  -0.525 -0.525 -0.526  0.638 -0.5190 -0.257  0.0358
# 767   0.053  ...   0.012   0.053  0.019  0.011  0.441 -0.0100 -0.449 -0.0600
# 768  -0.365  ...  -0.385  -0.373 -0.370 -0.384  0.502  0.5370 -0.372  0.3820
# 769  -0.428  ...  -0.009  -0.428  0.771 -0.443  0.408  0.6760  0.012  0.1460
#
#       SMR3A   SMR3B
# 0    0.1170  0.1170
# 1   -0.7490 -0.7490
# 2   -0.0062 -0.0062
# 3   -0.2660 -0.2660
# 4    0.0330  0.0330
# ..      ...     ...
# 765  0.0040  0.0040
# 766 -0.0050 -0.0050
# 767  1.2350  1.2350
# 768  0.0660  0.0660
# 769 -0.0280 -0.0280
#
# [770 rows x 13239 columns]

# %%
BRCA_SCNA.to_csv('../../DATA/BRCA/BRCA_SCNA.csv', index=False)

# %%
RNAseq_pathgway = pd.read_csv('../../DATA/BRCA/GO_BRCA_RNAseq.csv').sort_values('pvalue')
# 筛选 pvalue 小于 0.05 的行
RNAseq_pathgway = RNAseq_pathgway[RNAseq_pathgway['pvalue'] < 0.05]
RNAseq_pathgway
# Out:
#       Unnamed: 0          ID  \
# 0     GO:0048732  GO:0048732
# 1     GO:0048568  GO:0048568
# 2     GO:0007264  GO:0007264
# 3     GO:0060562  GO:0060562
# 4     GO:1903131  GO:1903131
# ...          ...         ...
# 2838  GO:0032908  GO:0032908
# 2844  GO:0036151  GO:0036151
# 2886  GO:0120032  GO:0120032
# 2887  GO:0090090  GO:0090090
# 2888  GO:0030042  GO:0030042
#
#                                             Description  GeneRatio    BgRatio  \
# 0                                     gland development  433/15221  449/18888
# 1                           embryonic organ development  438/15221  455/18888
# 2             small GTPase-mediated signal transduction  476/15221  500/18888
# 3                         epithelial tube morphogenesis  327/15221  335/18888
# 4                      mononuclear cell differentiation  461/15221  484/18888
# ...                                                 ...        ...        ...
# 2838  regulation of transforming growth factor beta1...   14/15221   14/18888
# 2844          phosphatidylcholine acyl-chain remodeling   14/15221   14/18888
# 2886  regulation of plasma membrane bounded cell pro...  174/15221  204/18888
# 2887  negative regulation of canonical Wnt signaling...  125/15221  145/18888
# 2888                    actin filament depolymerization   52/15221   58/18888
#
#       RichFactor  FoldEnrichment    zScore        pvalue      p.adjust  \
# 0       0.964365        1.196697  8.594106  5.119744e-24  3.252573e-20
# 1       0.962637        1.194553  8.558423  1.087599e-23  3.454758e-20
# 2       0.952000        1.181353  8.373180  5.390264e-22  1.141478e-18
# 3       0.976119        1.211283  7.949287  1.030394e-21  1.636523e-18
# 4       0.952479        1.181948  8.261547  1.741060e-21  2.212190e-18
# ...          ...             ...       ...           ...           ...
# 2838    1.000000        1.240917  1.837162  4.865154e-02  1.070975e-01
# 2844    1.000000        1.240917  1.837162  4.865154e-02  1.070975e-01
# 2886    0.852941        1.058429  1.709459  4.907938e-02  1.080018e-01
# 2887    0.862069        1.069756  1.717887  4.918841e-02  1.082043e-01
# 2888    0.896552        1.112546  1.748913  4.947757e-02  1.088027e-01
#
#             qvalue                                             geneID  Count
# 0     1.866820e-20  ABL1/ACADM/ACAT1/ACER1/ACO2/ADA/AIRE/AKT1/AKT2...    433
# 1     1.982865e-20  A2M/ACVR1/ADA/ADM/AHI1/AKT1/ALDH1A2/ALDH1A3/AL...    438
# 2     6.551534e-19  ABCA1/ABI2/ABL1/ABL2/ABRA/ABR/ADCYAP1R1/ADRA2A...    476
# 3     9.392852e-19  ABL1/ACVR1/ACVRL1/ADAMTS12/ADAMTS16/ADM/AGTR2/...    327
# 4     1.269691e-18  ABL1/ACIN1/ACTB/ACTL6A/ACTL6B/ADAM17/ADAM8/ADA...    461
# ...            ...                                                ...    ...
# 2838  6.146878e-02  ADAM8/AGT/ATP6AP2/CD2AP/CX3CL1/FOXP3/FURIN/GAT...     14
# 2844  6.146878e-02  DBI/LPCAT1/LPCAT2/LPCAT3/LPCAT4/MBOAT2/MBOAT7/...     14
# 2886  6.198785e-02  ABI2/ABI3/ACTR2/ACTR3/ADAMTS16/AGRN/AKIRIN1/AK...    174
# 2887  6.210404e-02  AMFR/ANKRD6/APC2/APC/APOE/AXIN1/AXIN2/BICC1/BM...    125
# 2888  6.244750e-02  ACTN2/ADD1/ADD2/ADD3/AVIL/CAPG/CAPZA1/CAPZA2/C...     52
#
# [2889 rows x 13 columns]

# %%
# 读取制表符分隔的TSV文件
RNAseq = pd.read_csv('../../DATA/BRCA/Human__TCGA_BRCA__UNC__RNAseq__HiSeq_RNA__01_28_2016__BI__Gene__Firehose_RSEM_log2_common_samples.tsv', sep='\t')
RNAseq = drop_and_impute_knn(RNAseq)
# 显示 DataFrame
RNAseq
# Out:
#        Unnamed: 0    A1BG   A2LD1     A2ML1      A2M  A4GALT     AAAS  \
# 0    TCGA.D8.A1JH  6.6980  6.3376   2.60830  14.2918  8.0993   9.3871
# 1    TCGA.OL.A5RW  7.7634  5.8225  11.03610  11.5957  7.2305   9.4180
# 2    TCGA.XX.A899  7.8088  7.0469   0.47890  14.3127  8.9845   9.4678
# 3    TCGA.S3.A6ZH  7.7030  6.6799   1.53090  12.6917  7.5527   9.5746
# 4    TCGA.AQ.A54N  8.7511  5.4406   4.51570  12.1222  5.2704  10.3992
# ..            ...     ...     ...       ...      ...     ...      ...
# 765  TCGA.GM.A5PX  7.7700  7.1346   0.47590  13.7090  8.7206   9.8015
# 766  TCGA.AC.A5XU  9.2189  6.9065   0.47380  13.6766  8.8052  10.2893
# 767  TCGA.AR.A1AN  6.5663  6.7836   1.96188  13.6565  8.1580   9.2231
# 768  TCGA.E9.A1RG  8.8370  5.6676   2.60480  12.4005  9.8105  10.3453
# 769  TCGA.BH.A0GY  6.8407  5.7374   9.09890  13.5429  9.6893   9.5720
#
#         AACS   AADAT    AAGAB  ...    ZWINT    ZXDA     ZXDB     ZXDC  ZYG11A  \
# 0    10.0371  5.6856  10.7372  ...   8.4062  6.5275  10.0332  10.2976  5.1870
# 1     9.4474  7.0779  10.0665  ...   9.4494  4.8136   7.7614  10.4659  3.1757
# 2    10.1770  5.4173  10.5380  ...   8.8395  6.1672   9.3325  10.3078  4.4764
# 3    10.2573  5.0770  11.5846  ...  10.6381  5.7270   8.8121  10.3413  7.1729
# 4     8.9339  8.6147   8.6569  ...   9.7255  4.2822   7.5725  10.3845  7.5569
# ..       ...     ...      ...  ...      ...     ...      ...      ...     ...
# 765   9.4073  5.5217  10.5575  ...   7.5973  4.9029   8.7059   9.7945  6.4489
# 766  10.2266  5.4389  10.4232  ...   9.3056  6.8925  10.1809   9.8913  3.3689
# 767  10.9819  5.7909  10.5450  ...   8.8524  5.7450   9.0406  10.1056  7.6446
# 768  10.0707  4.5913  10.9778  ...   9.8428  4.8443   7.9174   9.7010  5.3647
# 769  10.1489  7.5415  11.0462  ...   9.6191  5.1585   8.4768   9.6759  8.3350
#
#       ZYG11B      ZYX    ZZEF1     ZZZ3  psiTPTE22
# 0    10.1598  11.5054  10.8429  10.3800     8.4436
# 1     7.8520  11.5437   8.7513   8.4453     8.1613
# 2     9.4288  12.3217  10.9180   9.3903     6.6355
# 3     9.4000  11.3007   9.3480   9.4683     4.4660
# 4     8.9157  12.8822  10.0081   9.1350     8.3291
# ..       ...      ...      ...      ...        ...
# 765   9.4401  11.6096   9.2053   9.6349     7.2050
# 766   8.8202  12.4825  10.7307   9.3012     5.0047
# 767  10.0345  11.8261  10.2996  10.2447     6.0082
# 768   8.6875  11.9177   9.7606   7.9393     4.6720
# 769  10.4521  11.6728  10.4816  10.7169     5.6737
#
# [770 rows x 16636 columns]

# %%
# 提取 geneID 列中每一行的基因ID，并存储为列表
gene_ids = RNAseq_pathgway['geneID'].apply(lambda x: x.split('/'))
gene_ids
# Out:
# 0       [ABL1, ACADM, ACAT1, ACER1, ACO2, ADA, AIRE, A...
# 1       [A2M, ACVR1, ADA, ADM, AHI1, AKT1, ALDH1A2, AL...
# 2       [ABCA1, ABI2, ABL1, ABL2, ABRA, ABR, ADCYAP1R1...
# 3       [ABL1, ACVR1, ACVRL1, ADAMTS12, ADAMTS16, ADM,...
# 4       [ABL1, ACIN1, ACTB, ACTL6A, ACTL6B, ADAM17, AD...
#                               ...
# 2838    [ADAM8, AGT, ATP6AP2, CD2AP, CX3CL1, FOXP3, FU...
# 2844    [DBI, LPCAT1, LPCAT2, LPCAT3, LPCAT4, MBOAT2, ...
# 2886    [ABI2, ABI3, ACTR2, ACTR3, ADAMTS16, AGRN, AKI...
# 2887    [AMFR, ANKRD6, APC2, APC, APOE, AXIN1, AXIN2, ...
# 2888    [ACTN2, ADD1, ADD2, ADD3, AVIL, CAPG, CAPZA1, ...
# Name: geneID, Length: 2889, dtype: object

# %%
# # 创建一个空的数据框来存储所有PCA结果
# BRCA_RNAseq = pd.DataFrame()

# # 设置累计解释方差的阈值
# explained_variance_threshold = 0.95

# # 对每一行的基因数据进行PCA
# for i, gene_list in enumerate(gene_ids):
#     # 找到RNAseq数据框中与gene_list对应的列
#     matching_columns = [col for col in RNAseq.columns if col in gene_list]
#     # 提取这些列的数据
#     data = RNAseq[matching_columns]
    
#     # 确保数据足够进行PCA（至少需要两个基因）
#     if len(matching_columns) > 1:
#         # 初始化PCA
#         pca = PCA()
#         pca.fit(data)
        
#         # 计算累计解释方差
#         cumulative_explained_variance = pca.explained_variance_ratio_.cumsum()
        
#         # 确定达到阈值的主成分数k
#         k = next(i for i, total_variance in enumerate(cumulative_explained_variance) if total_variance >= explained_variance_threshold) + 1
        
#         # 重新运行PCA，保留前k个主成分
#         pca = PCA(n_components=k)
#         pca_result = pca.fit_transform(data)
        
#         # 将PCA结果转换为DataFrame，并添加索引信息
#         pca_df = pd.DataFrame(pca_result, columns=[f'PC{j+1}_row_{i}' for j in range(k)])
        
#         # 合并PCA结果到总数据框
#         BRCA_RNAseq = pd.concat([BRCA_RNAseq, pca_df], axis=1)
#     else:
#         print(f"Row {i} does not have enough genes for PCA.")

# # 显示最终合并的PCA结果
# BRCA_RNAseq

# %%
# # 创建一个空的数据框来存储所有PCA结果
# BRCA_RNAseq = pd.DataFrame()

# # 对每一行的基因数据进行PCA
# for i, gene_list in enumerate(gene_ids):
#     # 找到Methylation数据框中与gene_list对应的列
#     matching_columns = [col for col in RNAseq.columns if col in gene_list]
#     # 提取这些列的数据
#     data = RNAseq[matching_columns]
    
#     # 确保数据足够进行PCA（至少需要两个基因）
#     if len(matching_columns) > 1:
#         # 初始化PCA，并指定n_components为1
#         pca = PCA(n_components=1)
#         pca_result = pca.fit_transform(data)
        
#         # 将PCA结果转换为DataFrame，并添加索引信息
#         pca_df = pd.DataFrame(pca_result, columns=[f'PC1_row_{i}'])
        
#         # 合并PCA结果到总数据框
#         BRCA_RNAseq = pd.concat([BRCA_RNAseq, pca_df], axis=1)
#     else:
#         print(f"Row {i} does not have enough genes for PCA.")

# # 显示最终合并的PCA结果
# BRCA_RNAseq

# %%
# 创建一个空的数据框来存储所有结果
BRCA_RNAseq = pd.DataFrame()

# 对每一行的基因数据进行拼接
for i, gene_list in enumerate(gene_ids):
    # 找到Methylation数据框中与gene_list对应的列
    matching_columns = [col for col in RNAseq.columns if col in gene_list]
    
    # 去重，保留唯一的基因列
    unique_columns = list(dict.fromkeys(matching_columns))  # 保留顺序的去重方法
    
    # 提取这些唯一列的数据
    data = RNAseq[unique_columns]
    
    # 确保有匹配到的基因列
    if len(unique_columns) > 0:
        # 检查是否有重复的列
        unique_columns_to_add = [col for col in unique_columns if col not in BRCA_RNAseq.columns]
        
        # 如果没有重复列，将新列的数据直接拼接
        if unique_columns_to_add:
            data_to_add = data[unique_columns_to_add]
            BRCA_RNAseq = pd.concat([BRCA_RNAseq, data_to_add], axis=1)
        else:
            print(f"Row {i} does not have new unique columns to add.")
    else:
        print(f"Row {i} does not have matching genes to concatenate.")

# 显示最终拼接的结果
BRCA_RNAseq
# Out:
# Row 6 does not have new unique columns to add.
# Row 7 does not have new unique columns to add.
# Row 8 does not have new unique columns to add.
# Row 15 does not have new unique columns to add.
# Row 17 does not have new unique columns to add.
# Row 20 does not have new unique columns to add.
# Row 28 does not have new unique columns to add.
# Row 30 does not have new unique columns to add.
# Row 34 does not have new unique columns to add.
# Row 38 does not have new unique columns to add.
# Row 44 does not have new unique columns to add.
# Row 45 does not have new unique columns to add.
# Row 48 does not have new unique columns to add.
# Row 49 does not have new unique columns to add.
# Row 51 does not have new unique columns to add.
# Row 55 does not have new unique columns to add.
# Row 58 does not have new unique columns to add.
# Row 59 does not have new unique columns to add.
# Row 65 does not have new unique columns to add.
# Row 67 does not have new unique columns to add.
# Row 71 does not have new unique columns to add.
# Row 72 does not have new unique columns to add.
# Row 73 does not have new unique columns to add.
# Row 74 does not have new unique columns to add.
# Row 77 does not have new unique columns to add.
# Row 85 does not have new unique columns to add.
# Row 86 does not have new unique columns to add.
# Row 96 does not have new unique columns to add.
# Row 97 does not have new unique columns to add.
# Row 101 does not have new unique columns to add.
# Row 102 does not have new unique columns to add.
# Row 104 does not have new unique columns to add.
# Row 108 does not have new unique columns to add.
# Row 114 does not have new unique columns to add.
# Row 115 does not have new unique columns to add.
# Row 116 does not have new unique columns to add.
# Row 118 does not have new unique columns to add.
# Row 119 does not have new unique columns to add.
# Row 120 does not have new unique columns to add.
# Row 123 does not have new unique columns to add.
# Row 126 does not have new unique columns to add.
# Row 129 does not have new unique columns to add.
# Row 131 does not have new unique columns to add.
# Row 134 does not have new unique columns to add.
# Row 135 does not have new unique columns to add.
# Row 136 does not have new unique columns to add.
# Row 137 does not have new unique columns to add.
# Row 138 does not have new unique columns to add.
# Row 139 does not have new unique columns to add.
# Row 140 does not have new unique columns to add.
# Row 141 does not have new unique columns to add.
# Row 142 does not have new unique columns to add.
# Row 144 does not have new unique columns to add.
# Row 145 does not have new unique columns to add.
# Row 147 does not have new unique columns to add.
# Row 148 does not have new unique columns to add.
# Row 153 does not have new unique columns to add.
# Row 154 does not have new unique columns to add.
# Row 155 does not have new unique columns to add.
# Row 156 does not have new unique columns to add.
# Row 158 does not have new unique columns to add.
# Row 162 does not have new unique columns to add.
# Row 167 does not have new unique columns to add.
# Row 168 does not have new unique columns to add.
# Row 170 does not have new unique columns to add.
# Row 171 does not have new unique columns to add.
# Row 173 does not have new unique columns to add.
# Row 174 does not have new unique columns to add.
# Row 177 does not have new unique columns to add.
# Row 179 does not have new unique columns to add.
# Row 180 does not have new unique columns to add.
# Row 181 does not have new unique columns to add.
# Row 185 does not have new unique columns to add.
# Row 187 does not have new unique columns to add.
# Row 188 does not have new unique columns to add.
# Row 189 does not have new unique columns to add.
# Row 192 does not have new unique columns to add.
# Row 193 does not have new unique columns to add.
# Row 196 does not have new unique columns to add.
# Row 197 does not have new unique columns to add.
# Row 198 does not have new unique columns to add.
# Row 199 does not have new unique columns to add.
# Row 200 does not have new unique columns to add.
# Row 203 does not have new unique columns to add.
# Row 204 does not have new unique columns to add.
# Row 205 does not have new unique columns to add.
# Row 207 does not have new unique columns to add.
# Row 208 does not have new unique columns to add.
# Row 211 does not have new unique columns to add.
# Row 219 does not have new unique columns to add.
# Row 221 does not have new unique columns to add.
# Row 222 does not have new unique columns to add.
# Row 223 does not have new unique columns to add.
# Row 225 does not have new unique columns to add.
# Row 229 does not have new unique columns to add.
# Row 230 does not have new unique columns to add.
# Row 231 does not have new unique columns to add.
# Row 234 does not have new unique columns to add.
# Row 235 does not have new unique columns to add.
# Row 236 does not have new unique columns to add.
# Row 237 does not have new unique columns to add.
# Row 238 does not have new unique columns to add.
# Row 242 does not have new unique columns to add.
# Row 243 does not have new unique columns to add.
# Row 247 does not have new unique columns to add.
# Row 248 does not have new unique columns to add.
# Row 249 does not have new unique columns to add.
# Row 250 does not have new unique columns to add.
# Row 251 does not have new unique columns to add.
# Row 252 does not have new unique columns to add.
# Row 253 does not have new unique columns to add.
# Row 257 does not have new unique columns to add.
# Row 259 does not have new unique columns to add.
# Row 263 does not have new unique columns to add.
# Row 264 does not have new unique columns to add.
# Row 268 does not have new unique columns to add.
# Row 269 does not have new unique columns to add.
# Row 271 does not have new unique columns to add.
# Row 272 does not have new unique columns to add.
# Row 273 does not have new unique columns to add.
# Row 274 does not have new unique columns to add.
# Row 275 does not have new unique columns to add.
# Row 277 does not have new unique columns to add.
# Row 278 does not have new unique columns to add.
# Row 280 does not have new unique columns to add.
# Row 281 does not have new unique columns to add.
# Row 282 does not have new unique columns to add.
# Row 283 does not have new unique columns to add.
# Row 286 does not have new unique columns to add.
# Row 287 does not have new unique columns to add.
# Row 288 does not have new unique columns to add.
# Row 289 does not have new unique columns to add.
# Row 290 does not have new unique columns to add.
# Row 291 does not have new unique columns to add.
# Row 292 does not have new unique columns to add.
# Row 293 does not have new unique columns to add.
# Row 294 does not have new unique columns to add.
# Row 296 does not have new unique columns to add.
# Row 297 does not have new unique columns to add.
# Row 299 does not have new unique columns to add.
# Row 300 does not have new unique columns to add.
# Row 302 does not have new unique columns to add.
# Row 304 does not have new unique columns to add.
# Row 305 does not have new unique columns to add.
# Row 306 does not have new unique columns to add.
# Row 307 does not have new unique columns to add.
# Row 308 does not have new unique columns to add.
# Row 310 does not have new unique columns to add.
# Row 312 does not have new unique columns to add.
# Row 313 does not have new unique columns to add.
# Row 314 does not have new unique columns to add.
# Row 317 does not have new unique columns to add.
# Row 320 does not have new unique columns to add.
# Row 321 does not have new unique columns to add.
# Row 322 does not have new unique columns to add.
# Row 323 does not have new unique columns to add.
# Row 325 does not have new unique columns to add.
# Row 326 does not have new unique columns to add.
# Row 327 does not have new unique columns to add.
# Row 328 does not have new unique columns to add.
# Row 329 does not have new unique columns to add.
# Row 330 does not have new unique columns to add.
# Row 331 does not have new unique columns to add.
# Row 332 does not have new unique columns to add.
# Row 333 does not have new unique columns to add.
# Row 335 does not have new unique columns to add.
# Row 336 does not have new unique columns to add.
# Row 339 does not have new unique columns to add.
# Row 341 does not have new unique columns to add.
# Row 344 does not have new unique columns to add.
# Row 346 does not have new unique columns to add.
# Row 347 does not have new unique columns to add.
# Row 348 does not have new unique columns to add.
# Row 349 does not have new unique columns to add.
# Row 350 does not have new unique columns to add.
# Row 351 does not have new unique columns to add.
# Row 352 does not have new unique columns to add.
# Row 354 does not have new unique columns to add.
# Row 355 does not have new unique columns to add.
# Row 356 does not have new unique columns to add.
# Row 357 does not have new unique columns to add.
# Row 359 does not have new unique columns to add.
# Row 360 does not have new unique columns to add.
# Row 361 does not have new unique columns to add.
# Row 362 does not have new unique columns to add.
# Row 363 does not have new unique columns to add.
# Row 366 does not have new unique columns to add.
# Row 369 does not have new unique columns to add.
# Row 370 does not have new unique columns to add.
# Row 373 does not have new unique columns to add.
# Row 375 does not have new unique columns to add.
# Row 377 does not have new unique columns to add.
# Row 378 does not have new unique columns to add.
# Row 379 does not have new unique columns to add.
# Row 380 does not have new unique columns to add.
# Row 382 does not have new unique columns to add.
# Row 383 does not have new unique columns to add.
# Row 387 does not have new unique columns to add.
# Row 388 does not have new unique columns to add.
# Row 389 does not have new unique columns to add.
# Row 390 does not have new unique columns to add.
# Row 391 does not have new unique columns to add.
# Row 392 does not have new unique columns to add.
# Row 393 does not have new unique columns to add.
# Row 394 does not have new unique columns to add.
# Row 397 does not have new unique columns to add.
# Row 398 does not have new unique columns to add.
# Row 400 does not have new unique columns to add.
# Row 401 does not have new unique columns to add.
# Row 403 does not have new unique columns to add.
# Row 405 does not have new unique columns to add.
# Row 406 does not have new unique columns to add.
# Row 407 does not have new unique columns to add.
# Row 408 does not have new unique columns to add.
# Row 409 does not have new unique columns to add.
# Row 410 does not have new unique columns to add.
# Row 411 does not have new unique columns to add.
# Row 412 does not have new unique columns to add.
# Row 413 does not have new unique columns to add.
# Row 415 does not have new unique columns to add.
# Row 416 does not have new unique columns to add.
# Row 417 does not have new unique columns to add.
# Row 418 does not have new unique columns to add.
# Row 419 does not have new unique columns to add.
# Row 420 does not have new unique columns to add.
# Row 421 does not have new unique columns to add.
# Row 422 does not have new unique columns to add.
# Row 425 does not have new unique columns to add.
# Row 426 does not have new unique columns to add.
# Row 427 does not have new unique columns to add.
# Row 428 does not have new unique columns to add.
# Row 429 does not have new unique columns to add.
# Row 430 does not have new unique columns to add.
# Row 431 does not have new unique columns to add.
# Row 432 does not have new unique columns to add.
# Row 434 does not have new unique columns to add.
# Row 439 does not have new unique columns to add.
# Row 440 does not have new unique columns to add.
# Row 441 does not have new unique columns to add.
# Row 445 does not have new unique columns to add.
# Row 447 does not have new unique columns to add.
# Row 448 does not have new unique columns to add.
# Row 449 does not have new unique columns to add.
# Row 452 does not have new unique columns to add.
# Row 453 does not have new unique columns to add.
# Row 454 does not have new unique columns to add.
# Row 458 does not have new unique columns to add.
# Row 459 does not have new unique columns to add.
# Row 461 does not have new unique columns to add.
# Row 462 does not have new unique columns to add.
# Row 463 does not have new unique columns to add.
# Row 464 does not have new unique columns to add.
# Row 466 does not have new unique columns to add.
# Row 467 does not have new unique columns to add.
# Row 468 does not have new unique columns to add.
# Row 469 does not have new unique columns to add.
# Row 470 does not have new unique columns to add.
# Row 473 does not have new unique columns to add.
# Row 474 does not have new unique columns to add.
# Row 475 does not have new unique columns to add.
# Row 476 does not have new unique columns to add.
# Row 477 does not have new unique columns to add.
# Row 478 does not have new unique columns to add.
# Row 479 does not have new unique columns to add.
# Row 480 does not have new unique columns to add.
# Row 482 does not have new unique columns to add.
# Row 483 does not have new unique columns to add.
# Row 484 does not have new unique columns to add.
# Row 485 does not have new unique columns to add.
# Row 486 does not have new unique columns to add.
# Row 487 does not have new unique columns to add.
# Row 488 does not have new unique columns to add.
# Row 489 does not have new unique columns to add.
# Row 490 does not have new unique columns to add.
# Row 492 does not have new unique columns to add.
# Row 493 does not have new unique columns to add.
# Row 495 does not have new unique columns to add.
# Row 496 does not have new unique columns to add.
# Row 499 does not have new unique columns to add.
# Row 500 does not have new unique columns to add.
# Row 501 does not have new unique columns to add.
# Row 502 does not have new unique columns to add.
# Row 504 does not have new unique columns to add.
# Row 506 does not have new unique columns to add.
# Row 507 does not have new unique columns to add.
# Row 508 does not have new unique columns to add.
# Row 509 does not have new unique columns to add.
# Row 510 does not have new unique columns to add.
# Row 513 does not have new unique columns to add.
# Row 514 does not have new unique columns to add.
# Row 515 does not have new unique columns to add.
# Row 517 does not have new unique columns to add.
# Row 518 does not have new unique columns to add.
# Row 519 does not have new unique columns to add.
# Row 520 does not have new unique columns to add.
# Row 521 does not have new unique columns to add.
# Row 522 does not have new unique columns to add.
# Row 523 does not have new unique columns to add.
# Row 524 does not have new unique columns to add.
# Row 525 does not have new unique columns to add.
# Row 526 does not have new unique columns to add.
# Row 527 does not have new unique columns to add.
# Row 528 does not have new unique columns to add.
# Row 529 does not have new unique columns to add.
# Row 530 does not have new unique columns to add.
# Row 531 does not have new unique columns to add.
# Row 533 does not have new unique columns to add.
# Row 535 does not have new unique columns to add.
# Row 537 does not have new unique columns to add.
# Row 538 does not have new unique columns to add.
# Row 540 does not have new unique columns to add.
# Row 541 does not have new unique columns to add.
# Row 546 does not have new unique columns to add.
# Row 547 does not have new unique columns to add.
# Row 549 does not have new unique columns to add.
# Row 551 does not have new unique columns to add.
# Row 553 does not have new unique columns to add.
# Row 554 does not have new unique columns to add.
# Row 556 does not have new unique columns to add.
# Row 557 does not have new unique columns to add.
# Row 558 does not have new unique columns to add.
# Row 559 does not have new unique columns to add.
# Row 561 does not have new unique columns to add.
# Row 562 does not have new unique columns to add.
# Row 564 does not have new unique columns to add.
# Row 566 does not have new unique columns to add.
# Row 567 does not have new unique columns to add.
# Row 569 does not have new unique columns to add.
# Row 571 does not have new unique columns to add.
# Row 572 does not have new unique columns to add.
# Row 573 does not have new unique columns to add.
# Row 575 does not have new unique columns to add.
# Row 581 does not have new unique columns to add.
# Row 582 does not have new unique columns to add.
# Row 583 does not have new unique columns to add.
# Row 584 does not have new unique columns to add.
# Row 585 does not have new unique columns to add.
# Row 586 does not have new unique columns to add.
# Row 587 does not have new unique columns to add.
# Row 589 does not have new unique columns to add.
# Row 590 does not have new unique columns to add.
# Row 591 does not have new unique columns to add.
# Row 592 does not have new unique columns to add.
# Row 593 does not have new unique columns to add.
# Row 594 does not have new unique columns to add.
# Row 596 does not have new unique columns to add.
# Row 601 does not have new unique columns to add.
# Row 602 does not have new unique columns to add.
# Row 603 does not have new unique columns to add.
# Row 604 does not have new unique columns to add.
# Row 605 does not have new unique columns to add.
# Row 606 does not have new unique columns to add.
# Row 608 does not have new unique columns to add.
# Row 610 does not have new unique columns to add.
# Row 611 does not have new unique columns to add.
# Row 612 does not have new unique columns to add.
# Row 613 does not have new unique columns to add.
# Row 614 does not have new unique columns to add.
# Row 615 does not have new unique columns to add.
# Row 616 does not have new unique columns to add.
# Row 617 does not have new unique columns to add.
# Row 618 does not have new unique columns to add.
# Row 619 does not have new unique columns to add.
# Row 620 does not have new unique columns to add.
# Row 621 does not have new unique columns to add.
# Row 622 does not have new unique columns to add.
# Row 624 does not have new unique columns to add.
# Row 625 does not have new unique columns to add.
# Row 627 does not have new unique columns to add.
# Row 628 does not have new unique columns to add.
# Row 629 does not have new unique columns to add.
# Row 631 does not have new unique columns to add.
# Row 632 does not have new unique columns to add.
# Row 633 does not have new unique columns to add.
# Row 634 does not have new unique columns to add.
# Row 635 does not have new unique columns to add.
# Row 636 does not have new unique columns to add.
# Row 637 does not have new unique columns to add.
# Row 639 does not have new unique columns to add.
# Row 640 does not have new unique columns to add.
# Row 643 does not have new unique columns to add.
# Row 644 does not have new unique columns to add.
# Row 645 does not have new unique columns to add.
# Row 647 does not have new unique columns to add.
# Row 648 does not have new unique columns to add.
# Row 649 does not have new unique columns to add.
# Row 650 does not have new unique columns to add.
# Row 651 does not have new unique columns to add.
# Row 653 does not have new unique columns to add.
# Row 654 does not have new unique columns to add.
# Row 656 does not have new unique columns to add.
# Row 657 does not have new unique columns to add.
# Row 659 does not have new unique columns to add.
# Row 660 does not have new unique columns to add.
# Row 661 does not have new unique columns to add.
# Row 662 does not have new unique columns to add.
# Row 663 does not have new unique columns to add.
# Row 664 does not have new unique columns to add.
# Row 665 does not have new unique columns to add.
# Row 666 does not have new unique columns to add.
# Row 668 does not have new unique columns to add.
# Row 669 does not have new unique columns to add.
# Row 670 does not have new unique columns to add.
# Row 671 does not have new unique columns to add.
# Row 673 does not have new unique columns to add.
# Row 675 does not have new unique columns to add.
# Row 676 does not have new unique columns to add.
# Row 677 does not have new unique columns to add.
# Row 678 does not have new unique columns to add.
# Row 680 does not have new unique columns to add.
# Row 681 does not have new unique columns to add.
# Row 682 does not have new unique columns to add.
# Row 683 does not have new unique columns to add.
# Row 684 does not have new unique columns to add.
# Row 685 does not have new unique columns to add.
# Row 687 does not have new unique columns to add.
# Row 688 does not have new unique columns to add.
# Row 689 does not have new unique columns to add.
# Row 690 does not have new unique columns to add.
# Row 693 does not have new unique columns to add.
# Row 694 does not have new unique columns to add.
# Row 695 does not have new unique columns to add.
# Row 696 does not have new unique columns to add.
# Row 697 does not have new unique columns to add.
# Row 698 does not have new unique columns to add.
# Row 699 does not have new unique columns to add.
# Row 700 does not have new unique columns to add.
# Row 701 does not have new unique columns to add.
# Row 702 does not have new unique columns to add.
# Row 703 does not have new unique columns to add.
# Row 704 does not have new unique columns to add.
# Row 705 does not have new unique columns to add.
# Row 706 does not have new unique columns to add.
# Row 707 does not have new unique columns to add.
# Row 708 does not have new unique columns to add.
# Row 710 does not have new unique columns to add.
# Row 711 does not have new unique columns to add.
# Row 712 does not have new unique columns to add.
# Row 713 does not have new unique columns to add.
# Row 714 does not have new unique columns to add.
# Row 715 does not have new unique columns to add.
# Row 716 does not have new unique columns to add.
# Row 717 does not have new unique columns to add.
# Row 719 does not have new unique columns to add.
# Row 721 does not have new unique columns to add.
# Row 723 does not have new unique columns to add.
# Row 724 does not have new unique columns to add.
# Row 726 does not have new unique columns to add.
# Row 728 does not have new unique columns to add.
# Row 729 does not have new unique columns to add.
# Row 730 does not have new unique columns to add.
# Row 731 does not have new unique columns to add.
# Row 732 does not have new unique columns to add.
# Row 733 does not have new unique columns to add.
# Row 734 does not have new unique columns to add.
# Row 735 does not have new unique columns to add.
# Row 736 does not have new unique columns to add.
# Row 737 does not have new unique columns to add.
# Row 738 does not have new unique columns to add.
# Row 739 does not have new unique columns to add.
# Row 740 does not have new unique columns to add.
# Row 742 does not have new unique columns to add.
# Row 743 does not have new unique columns to add.
# Row 744 does not have new unique columns to add.
# Row 745 does not have new unique columns to add.
# Row 746 does not have new unique columns to add.
# Row 747 does not have new unique columns to add.
# Row 748 does not have new unique columns to add.
# Row 751 does not have new unique columns to add.
# Row 752 does not have new unique columns to add.
# Row 754 does not have new unique columns to add.
# Row 755 does not have new unique columns to add.
# Row 756 does not have new unique columns to add.
# Row 757 does not have new unique columns to add.
# Row 758 does not have new unique columns to add.
# Row 759 does not have new unique columns to add.
# Row 760 does not have new unique columns to add.
# Row 762 does not have new unique columns to add.
# Row 763 does not have new unique columns to add.
# Row 764 does not have new unique columns to add.
# Row 765 does not have new unique columns to add.
# Row 766 does not have new unique columns to add.
# Row 768 does not have new unique columns to add.
# Row 769 does not have new unique columns to add.
# Row 770 does not have new unique columns to add.
# Row 771 does not have new unique columns to add.
# Row 772 does not have new unique columns to add.
# Row 774 does not have new unique columns to add.
# Row 775 does not have new unique columns to add.
# Row 776 does not have new unique columns to add.
# Row 778 does not have new unique columns to add.
# Row 779 does not have new unique columns to add.
# Row 781 does not have new unique columns to add.
# Row 782 does not have new unique columns to add.
# Row 783 does not have new unique columns to add.
# Row 784 does not have new unique columns to add.
# Row 785 does not have new unique columns to add.
# Row 786 does not have new unique columns to add.
# Row 787 does not have new unique columns to add.
# Row 788 does not have new unique columns to add.
# Row 789 does not have new unique columns to add.
# Row 790 does not have new unique columns to add.
# Row 791 does not have new unique columns to add.
# Row 793 does not have new unique columns to add.
# Row 794 does not have new unique columns to add.
# Row 795 does not have new unique columns to add.
# Row 796 does not have new unique columns to add.
# Row 797 does not have new unique columns to add.
# Row 798 does not have new unique columns to add.
# Row 799 does not have new unique columns to add.
# Row 800 does not have new unique columns to add.
# Row 802 does not have new unique columns to add.
# Row 803 does not have new unique columns to add.
# Row 804 does not have new unique columns to add.
# Row 805 does not have new unique columns to add.
# Row 806 does not have new unique columns to add.
# Row 807 does not have new unique columns to add.
# Row 808 does not have new unique columns to add.
# Row 809 does not have new unique columns to add.
# Row 810 does not have new unique columns to add.
# Row 811 does not have new unique columns to add.
# Row 814 does not have new unique columns to add.
# Row 815 does not have new unique columns to add.
# Row 816 does not have new unique columns to add.
# Row 817 does not have new unique columns to add.
# Row 818 does not have new unique columns to add.
# Row 819 does not have new unique columns to add.
# Row 820 does not have new unique columns to add.
# Row 821 does not have new unique columns to add.
# Row 823 does not have new unique columns to add.
# Row 824 does not have new unique columns to add.
# Row 825 does not have new unique columns to add.
# Row 829 does not have new unique columns to add.
# Row 830 does not have new unique columns to add.
# Row 831 does not have new unique columns to add.
# Row 832 does not have new unique columns to add.
# Row 833 does not have new unique columns to add.
# Row 834 does not have new unique columns to add.
# Row 836 does not have new unique columns to add.
# Row 838 does not have new unique columns to add.
# Row 839 does not have new unique columns to add.
# Row 840 does not have new unique columns to add.
# Row 841 does not have new unique columns to add.
# Row 844 does not have new unique columns to add.
# Row 845 does not have new unique columns to add.
# Row 846 does not have new unique columns to add.
# Row 848 does not have new unique columns to add.
# Row 849 does not have new unique columns to add.
# Row 850 does not have new unique columns to add.
# Row 851 does not have new unique columns to add.
# Row 852 does not have new unique columns to add.
# Row 853 does not have new unique columns to add.
# Row 854 does not have new unique columns to add.
# Row 855 does not have new unique columns to add.
# Row 856 does not have new unique columns to add.
# Row 857 does not have new unique columns to add.
# Row 859 does not have new unique columns to add.
# Row 860 does not have new unique columns to add.
# Row 862 does not have new unique columns to add.
# Row 863 does not have new unique columns to add.
# Row 864 does not have new unique columns to add.
# Row 865 does not have new unique columns to add.
# Row 866 does not have new unique columns to add.
# Row 867 does not have new unique columns to add.
# Row 868 does not have new unique columns to add.
# Row 869 does not have new unique columns to add.
# Row 870 does not have new unique columns to add.
# Row 871 does not have new unique columns to add.
# Row 873 does not have new unique columns to add.
# Row 874 does not have new unique columns to add.
# Row 875 does not have new unique columns to add.
# Row 876 does not have new unique columns to add.
# Row 877 does not have new unique columns to add.
# Row 879 does not have new unique columns to add.
# Row 880 does not have new unique columns to add.
# Row 882 does not have new unique columns to add.
# Row 883 does not have new unique columns to add.
# Row 884 does not have new unique columns to add.
# Row 885 does not have new unique columns to add.
# Row 886 does not have new unique columns to add.
# Row 887 does not have new unique columns to add.
# Row 888 does not have new unique columns to add.
# Row 889 does not have new unique columns to add.
# Row 890 does not have new unique columns to add.
# Row 891 does not have new unique columns to add.
# Row 892 does not have new unique columns to add.
# Row 893 does not have new unique columns to add.
# Row 894 does not have new unique columns to add.
# Row 895 does not have new unique columns to add.
# Row 896 does not have new unique columns to add.
# Row 897 does not have new unique columns to add.
# Row 898 does not have new unique columns to add.
# Row 900 does not have new unique columns to add.
# Row 901 does not have new unique columns to add.
# Row 903 does not have new unique columns to add.
# Row 904 does not have new unique columns to add.
# Row 905 does not have new unique columns to add.
# Row 906 does not have new unique columns to add.
# Row 907 does not have new unique columns to add.
# Row 908 does not have new unique columns to add.
# Row 909 does not have new unique columns to add.
# Row 910 does not have new unique columns to add.
# Row 911 does not have new unique columns to add.
# Row 913 does not have new unique columns to add.
# Row 914 does not have new unique columns to add.
# Row 915 does not have new unique columns to add.
# Row 917 does not have new unique columns to add.
# Row 918 does not have new unique columns to add.
# Row 919 does not have new unique columns to add.
# Row 921 does not have new unique columns to add.
# Row 922 does not have new unique columns to add.
# Row 923 does not have new unique columns to add.
# Row 924 does not have new unique columns to add.
# Row 925 does not have new unique columns to add.
# Row 926 does not have new unique columns to add.
# Row 927 does not have new unique columns to add.
# Row 928 does not have new unique columns to add.
# Row 929 does not have new unique columns to add.
# Row 930 does not have new unique columns to add.
# Row 931 does not have new unique columns to add.
# Row 932 does not have new unique columns to add.
# Row 933 does not have new unique columns to add.
# Row 934 does not have new unique columns to add.
# Row 935 does not have new unique columns to add.
# Row 936 does not have new unique columns to add.
# Row 937 does not have new unique columns to add.
# Row 938 does not have new unique columns to add.
# Row 940 does not have new unique columns to add.
# Row 941 does not have new unique columns to add.
# Row 942 does not have new unique columns to add.
# Row 943 does not have new unique columns to add.
# Row 945 does not have new unique columns to add.
# Row 946 does not have new unique columns to add.
# Row 947 does not have new unique columns to add.
# Row 948 does not have new unique columns to add.
# Row 950 does not have new unique columns to add.
# Row 951 does not have new unique columns to add.
# Row 952 does not have new unique columns to add.
# Row 953 does not have new unique columns to add.
# Row 954 does not have new unique columns to add.
# Row 955 does not have new unique columns to add.
# Row 956 does not have new unique columns to add.
# Row 957 does not have new unique columns to add.
# Row 959 does not have new unique columns to add.
# Row 960 does not have new unique columns to add.
# Row 962 does not have new unique columns to add.
# Row 963 does not have new unique columns to add.
# Row 964 does not have new unique columns to add.
# Row 965 does not have new unique columns to add.
# Row 966 does not have new unique columns to add.
# Row 967 does not have new unique columns to add.
# Row 968 does not have new unique columns to add.
# Row 969 does not have new unique columns to add.
# Row 970 does not have new unique columns to add.
# Row 971 does not have new unique columns to add.
# Row 972 does not have new unique columns to add.
# Row 973 does not have new unique columns to add.
# Row 975 does not have new unique columns to add.
# Row 976 does not have new unique columns to add.
# Row 977 does not have new unique columns to add.
# Row 978 does not have new unique columns to add.
# Row 979 does not have new unique columns to add.
# Row 980 does not have new unique columns to add.
# Row 981 does not have new unique columns to add.
# Row 983 does not have new unique columns to add.
# Row 984 does not have new unique columns to add.
# Row 985 does not have new unique columns to add.
# Row 986 does not have new unique columns to add.
# Row 987 does not have new unique columns to add.
# Row 988 does not have new unique columns to add.
# Row 989 does not have new unique columns to add.
# Row 990 does not have new unique columns to add.
# Row 991 does not have new unique columns to add.
# Row 992 does not have new unique columns to add.
# Row 993 does not have new unique columns to add.
# Row 994 does not have new unique columns to add.
# Row 996 does not have new unique columns to add.
# Row 997 does not have new unique columns to add.
# Row 998 does not have new unique columns to add.
# Row 999 does not have new unique columns to add.
# Row 1000 does not have new unique columns to add.
# Row 1001 does not have new unique columns to add.
# Row 1002 does not have new unique columns to add.
# Row 1003 does not have new unique columns to add.
# Row 1004 does not have new unique columns to add.
# Row 1005 does not have new unique columns to add.
# Row 1007 does not have new unique columns to add.
# Row 1008 does not have new unique columns to add.
# Row 1009 does not have new unique columns to add.
# Row 1010 does not have new unique columns to add.
# Row 1011 does not have new unique columns to add.
# Row 1012 does not have new unique columns to add.
# Row 1013 does not have new unique columns to add.
# Row 1014 does not have new unique columns to add.
# Row 1015 does not have new unique columns to add.
# Row 1016 does not have new unique columns to add.
# Row 1017 does not have new unique columns to add.
# Row 1018 does not have new unique columns to add.
# Row 1019 does not have new unique columns to add.
# Row 1020 does not have new unique columns to add.
# Row 1021 does not have new unique columns to add.
# Row 1022 does not have new unique columns to add.
# Row 1023 does not have new unique columns to add.
# Row 1024 does not have new unique columns to add.
# Row 1025 does not have new unique columns to add.
# Row 1030 does not have new unique columns to add.
# Row 1031 does not have new unique columns to add.
# Row 1032 does not have new unique columns to add.
# Row 1033 does not have new unique columns to add.
# Row 1034 does not have new unique columns to add.
# Row 1035 does not have new unique columns to add.
# Row 1036 does not have new unique columns to add.
# Row 1038 does not have new unique columns to add.
# Row 1039 does not have new unique columns to add.
# Row 1041 does not have new unique columns to add.
# Row 1042 does not have new unique columns to add.
# Row 1043 does not have new unique columns to add.
# Row 1044 does not have new unique columns to add.
# Row 1045 does not have new unique columns to add.
# Row 1047 does not have new unique columns to add.
# Row 1049 does not have new unique columns to add.
# Row 1050 does not have new unique columns to add.
# Row 1051 does not have new unique columns to add.
# Row 1052 does not have new unique columns to add.
# Row 1053 does not have new unique columns to add.
# Row 1054 does not have new unique columns to add.
# Row 1055 does not have new unique columns to add.
# Row 1057 does not have new unique columns to add.
# Row 1059 does not have new unique columns to add.
# Row 1060 does not have new unique columns to add.
# Row 1063 does not have new unique columns to add.
# Row 1064 does not have new unique columns to add.
# Row 1065 does not have new unique columns to add.
# Row 1067 does not have new unique columns to add.
# Row 1068 does not have new unique columns to add.
# Row 1069 does not have new unique columns to add.
# Row 1070 does not have new unique columns to add.
# Row 1071 does not have new unique columns to add.
# Row 1072 does not have new unique columns to add.
# Row 1073 does not have new unique columns to add.
# Row 1074 does not have new unique columns to add.
# Row 1075 does not have new unique columns to add.
# Row 1076 does not have new unique columns to add.
# Row 1077 does not have new unique columns to add.
# Row 1078 does not have new unique columns to add.
# Row 1079 does not have new unique columns to add.
# Row 1081 does not have new unique columns to add.
# Row 1082 does not have new unique columns to add.
# Row 1084 does not have new unique columns to add.
# Row 1085 does not have new unique columns to add.
# Row 1090 does not have new unique columns to add.
# Row 1091 does not have new unique columns to add.
# Row 1092 does not have new unique columns to add.
# Row 1093 does not have new unique columns to add.
# Row 1094 does not have new unique columns to add.
# Row 1096 does not have new unique columns to add.
# Row 1097 does not have new unique columns to add.
# Row 1098 does not have new unique columns to add.
# Row 1099 does not have new unique columns to add.
# Row 1100 does not have new unique columns to add.
# Row 1101 does not have new unique columns to add.
# Row 1102 does not have new unique columns to add.
# Row 1103 does not have new unique columns to add.
# Row 1104 does not have new unique columns to add.
# Row 1105 does not have new unique columns to add.
# Row 1106 does not have new unique columns to add.
# Row 1107 does not have new unique columns to add.
# Row 1108 does not have new unique columns to add.
# Row 1109 does not have new unique columns to add.
# Row 1110 does not have new unique columns to add.
# Row 1111 does not have new unique columns to add.
# Row 1112 does not have new unique columns to add.
# Row 1113 does not have new unique columns to add.
# Row 1114 does not have new unique columns to add.
# Row 1115 does not have new unique columns to add.
# Row 1116 does not have new unique columns to add.
# Row 1117 does not have new unique columns to add.
# Row 1118 does not have new unique columns to add.
# Row 1119 does not have new unique columns to add.
# Row 1120 does not have new unique columns to add.
# Row 1121 does not have new unique columns to add.
# Row 1122 does not have new unique columns to add.
# Row 1123 does not have new unique columns to add.
# Row 1124 does not have new unique columns to add.
# Row 1125 does not have new unique columns to add.
# Row 1126 does not have new unique columns to add.
# Row 1127 does not have new unique columns to add.
# Row 1128 does not have new unique columns to add.
# Row 1129 does not have new unique columns to add.
# Row 1130 does not have new unique columns to add.
# Row 1131 does not have new unique columns to add.
# Row 1132 does not have new unique columns to add.
# Row 1133 does not have new unique columns to add.
# Row 1134 does not have new unique columns to add.
# Row 1135 does not have new unique columns to add.
# Row 1136 does not have new unique columns to add.
# Row 1137 does not have new unique columns to add.
# Row 1138 does not have new unique columns to add.
# Row 1139 does not have new unique columns to add.
# Row 1141 does not have new unique columns to add.
# Row 1143 does not have new unique columns to add.
# Row 1144 does not have new unique columns to add.
# Row 1145 does not have new unique columns to add.
# Row 1146 does not have new unique columns to add.
# Row 1147 does not have new unique columns to add.
# Row 1148 does not have new unique columns to add.
# Row 1149 does not have new unique columns to add.
# Row 1150 does not have new unique columns to add.
# Row 1151 does not have new unique columns to add.
# Row 1152 does not have new unique columns to add.
# Row 1153 does not have new unique columns to add.
# Row 1154 does not have new unique columns to add.
# Row 1155 does not have new unique columns to add.
# Row 1156 does not have new unique columns to add.
# Row 1157 does not have new unique columns to add.
# Row 1158 does not have new unique columns to add.
# Row 1159 does not have new unique columns to add.
# Row 1161 does not have new unique columns to add.
# Row 1162 does not have new unique columns to add.
# Row 1163 does not have new unique columns to add.
# Row 1164 does not have new unique columns to add.
# Row 1165 does not have new unique columns to add.
# Row 1166 does not have new unique columns to add.
# Row 1167 does not have new unique columns to add.
# Row 1168 does not have new unique columns to add.
# Row 1169 does not have new unique columns to add.
# Row 1170 does not have new unique columns to add.
# Row 1171 does not have new unique columns to add.
# Row 1172 does not have new unique columns to add.
# Row 1173 does not have new unique columns to add.
# Row 1174 does not have new unique columns to add.
# Row 1175 does not have new unique columns to add.
# Row 1176 does not have new unique columns to add.
# Row 1177 does not have new unique columns to add.
# Row 1178 does not have new unique columns to add.
# Row 1179 does not have new unique columns to add.
# Row 1180 does not have new unique columns to add.
# Row 1181 does not have new unique columns to add.
# Row 1182 does not have new unique columns to add.
# Row 1183 does not have new unique columns to add.
# Row 1184 does not have new unique columns to add.
# Row 1185 does not have new unique columns to add.
# Row 1186 does not have new unique columns to add.
# Row 1187 does not have new unique columns to add.
# Row 1188 does not have new unique columns to add.
# Row 1189 does not have new unique columns to add.
# Row 1190 does not have new unique columns to add.
# Row 1192 does not have new unique columns to add.
# Row 1193 does not have new unique columns to add.
# Row 1194 does not have new unique columns to add.
# Row 1195 does not have new unique columns to add.
# Row 1197 does not have new unique columns to add.
# Row 1198 does not have new unique columns to add.
# Row 1199 does not have new unique columns to add.
# Row 1200 does not have new unique columns to add.
# Row 1201 does not have new unique columns to add.
# Row 1202 does not have new unique columns to add.
# Row 1203 does not have new unique columns to add.
# Row 1204 does not have new unique columns to add.
# Row 1205 does not have new unique columns to add.
# Row 1206 does not have new unique columns to add.
# Row 1207 does not have new unique columns to add.
# Row 1208 does not have new unique columns to add.
# Row 1209 does not have new unique columns to add.
# Row 1211 does not have new unique columns to add.
# Row 1212 does not have new unique columns to add.
# Row 1213 does not have new unique columns to add.
# Row 1214 does not have new unique columns to add.
# Row 1215 does not have new unique columns to add.
# Row 1216 does not have new unique columns to add.
# Row 1217 does not have new unique columns to add.
# Row 1218 does not have new unique columns to add.
# Row 1219 does not have new unique columns to add.
# Row 1220 does not have new unique columns to add.
# Row 1221 does not have new unique columns to add.
# Row 1223 does not have new unique columns to add.
# Row 1224 does not have new unique columns to add.
# Row 1225 does not have new unique columns to add.
# Row 1226 does not have new unique columns to add.
# Row 1227 does not have new unique columns to add.
# Row 1228 does not have new unique columns to add.
# Row 1230 does not have new unique columns to add.
# Row 1231 does not have new unique columns to add.
# Row 1232 does not have new unique columns to add.
# Row 1233 does not have new unique columns to add.
# Row 1234 does not have new unique columns to add.
# Row 1235 does not have new unique columns to add.
# Row 1236 does not have new unique columns to add.
# Row 1237 does not have new unique columns to add.
# Row 1239 does not have new unique columns to add.
# Row 1240 does not have new unique columns to add.
# Row 1241 does not have new unique columns to add.
# Row 1242 does not have new unique columns to add.
# Row 1243 does not have new unique columns to add.
# Row 1244 does not have new unique columns to add.
# Row 1245 does not have new unique columns to add.
# Row 1246 does not have new unique columns to add.
# Row 1247 does not have new unique columns to add.
# Row 1248 does not have new unique columns to add.
# Row 1249 does not have new unique columns to add.
# Row 1250 does not have new unique columns to add.
# Row 1251 does not have new unique columns to add.
# Row 1252 does not have new unique columns to add.
# Row 1253 does not have new unique columns to add.
# Row 1254 does not have new unique columns to add.
# Row 1255 does not have new unique columns to add.
# Row 1257 does not have new unique columns to add.
# Row 1258 does not have new unique columns to add.
# Row 1260 does not have new unique columns to add.
# Row 1261 does not have new unique columns to add.
# Row 1262 does not have new unique columns to add.
# Row 1263 does not have new unique columns to add.
# Row 1264 does not have new unique columns to add.
# Row 1265 does not have new unique columns to add.
# Row 1266 does not have new unique columns to add.
# Row 1267 does not have new unique columns to add.
# Row 1268 does not have new unique columns to add.
# Row 1269 does not have new unique columns to add.
# Row 1270 does not have new unique columns to add.
# Row 1271 does not have new unique columns to add.
# Row 1273 does not have new unique columns to add.
# Row 1274 does not have new unique columns to add.
# Row 1275 does not have new unique columns to add.
# Row 1276 does not have new unique columns to add.
# Row 1278 does not have new unique columns to add.
# Row 1279 does not have new unique columns to add.
# Row 1280 does not have new unique columns to add.
# Row 1281 does not have new unique columns to add.
# Row 1282 does not have new unique columns to add.
# Row 1283 does not have new unique columns to add.
# Row 1284 does not have new unique columns to add.
# Row 1285 does not have new unique columns to add.
# Row 1286 does not have new unique columns to add.
# Row 1287 does not have new unique columns to add.
# Row 1288 does not have new unique columns to add.
# Row 1289 does not have new unique columns to add.
# Row 1290 does not have new unique columns to add.
# Row 1291 does not have new unique columns to add.
# Row 1292 does not have new unique columns to add.
# Row 1293 does not have new unique columns to add.
# Row 1294 does not have new unique columns to add.
# Row 1295 does not have new unique columns to add.
# Row 1296 does not have new unique columns to add.
# Row 1297 does not have new unique columns to add.
# Row 1298 does not have new unique columns to add.
# Row 1299 does not have new unique columns to add.
# Row 1300 does not have new unique columns to add.
# Row 1301 does not have new unique columns to add.
# Row 1303 does not have new unique columns to add.
# Row 1304 does not have new unique columns to add.
# Row 1305 does not have new unique columns to add.
# Row 1306 does not have new unique columns to add.
# Row 1307 does not have new unique columns to add.
# Row 1308 does not have new unique columns to add.
# Row 1309 does not have new unique columns to add.
# Row 1311 does not have new unique columns to add.
# Row 1312 does not have new unique columns to add.
# Row 1313 does not have new unique columns to add.
# Row 1314 does not have new unique columns to add.
# Row 1315 does not have new unique columns to add.
# Row 1316 does not have new unique columns to add.
# Row 1317 does not have new unique columns to add.
# Row 1318 does not have new unique columns to add.
# Row 1320 does not have new unique columns to add.
# Row 1321 does not have new unique columns to add.
# Row 1322 does not have new unique columns to add.
# Row 1323 does not have new unique columns to add.
# Row 1324 does not have new unique columns to add.
# Row 1325 does not have new unique columns to add.
# Row 1326 does not have new unique columns to add.
# Row 1327 does not have new unique columns to add.
# Row 1328 does not have new unique columns to add.
# Row 1329 does not have new unique columns to add.
# Row 1330 does not have new unique columns to add.
# ...
# Row 2607 does not have new unique columns to add.
# Row 2608 does not have new unique columns to add.
# Row 2609 does not have new unique columns to add.
# Row 2610 does not have new unique columns to add.
# Row 2612 does not have new unique columns to add.
# Row 2613 does not have new unique columns to add.
# Row 2614 does not have new unique columns to add.
# Row 2615 does not have new unique columns to add.
# Row 2616 does not have new unique columns to add.
# Row 2617 does not have new unique columns to add.
# Row 2618 does not have new unique columns to add.
# Row 2619 does not have new unique columns to add.
# Row 2621 does not have new unique columns to add.
# Row 2622 does not have new unique columns to add.
# Row 2623 does not have new unique columns to add.
# Row 2624 does not have new unique columns to add.
# Row 2625 does not have new unique columns to add.
# Row 2626 does not have new unique columns to add.
# Row 2627 does not have new unique columns to add.
# Row 2628 does not have new unique columns to add.
# Row 2629 does not have new unique columns to add.
# Row 2630 does not have new unique columns to add.
# Row 2631 does not have new unique columns to add.
# Row 2632 does not have new unique columns to add.
# Row 2633 does not have new unique columns to add.
# Row 2634 does not have new unique columns to add.
# Row 2635 does not have new unique columns to add.
# Row 2636 does not have new unique columns to add.
# Row 2637 does not have new unique columns to add.
# Row 2638 does not have new unique columns to add.
# Row 2639 does not have new unique columns to add.
# Row 2640 does not have new unique columns to add.
# Row 2641 does not have new unique columns to add.
# Row 2642 does not have new unique columns to add.
# Row 2643 does not have new unique columns to add.
# Row 2644 does not have new unique columns to add.
# Row 2645 does not have new unique columns to add.
# Row 2646 does not have new unique columns to add.
# Row 2647 does not have new unique columns to add.
# Row 2648 does not have new unique columns to add.
# Row 2649 does not have new unique columns to add.
# Row 2650 does not have new unique columns to add.
# Row 2651 does not have new unique columns to add.
# Row 2652 does not have new unique columns to add.
# Row 2653 does not have new unique columns to add.
# Row 2654 does not have new unique columns to add.
# Row 2655 does not have new unique columns to add.
# Row 2656 does not have new unique columns to add.
# Row 2657 does not have new unique columns to add.
# Row 2658 does not have new unique columns to add.
# Row 2659 does not have new unique columns to add.
# Row 2660 does not have new unique columns to add.
# Row 2661 does not have new unique columns to add.
# Row 2662 does not have new unique columns to add.
# Row 2663 does not have new unique columns to add.
# Row 2664 does not have new unique columns to add.
# Row 2665 does not have new unique columns to add.
# Row 2666 does not have new unique columns to add.
# Row 2667 does not have new unique columns to add.
# Row 2668 does not have new unique columns to add.
# Row 2669 does not have new unique columns to add.
# Row 2670 does not have new unique columns to add.
# Row 2671 does not have new unique columns to add.
# Row 2672 does not have new unique columns to add.
# Row 2673 does not have new unique columns to add.
# Row 2674 does not have new unique columns to add.
# Row 2675 does not have new unique columns to add.
# Row 2676 does not have new unique columns to add.
# Row 2677 does not have new unique columns to add.
# Row 2678 does not have new unique columns to add.
# Row 2679 does not have new unique columns to add.
# Row 2680 does not have new unique columns to add.
# Row 2681 does not have new unique columns to add.
# Row 2682 does not have new unique columns to add.
# Row 2683 does not have new unique columns to add.
# Row 2684 does not have new unique columns to add.
# Row 2685 does not have new unique columns to add.
# Row 2686 does not have new unique columns to add.
# Row 2687 does not have new unique columns to add.
# Row 2688 does not have new unique columns to add.
# Row 2689 does not have new unique columns to add.
# Row 2690 does not have new unique columns to add.
# Row 2691 does not have new unique columns to add.
# Row 2692 does not have new unique columns to add.
# Row 2693 does not have new unique columns to add.
# Row 2694 does not have new unique columns to add.
# Row 2695 does not have new unique columns to add.
# Row 2696 does not have new unique columns to add.
# Row 2697 does not have new unique columns to add.
# Row 2698 does not have new unique columns to add.
# Row 2699 does not have new unique columns to add.
# Row 2700 does not have new unique columns to add.
# Row 2701 does not have new unique columns to add.
# Row 2702 does not have new unique columns to add.
# Row 2703 does not have new unique columns to add.
# Row 2704 does not have new unique columns to add.
# Row 2705 does not have new unique columns to add.
# Row 2706 does not have new unique columns to add.
# Row 2707 does not have new unique columns to add.
# Row 2708 does not have new unique columns to add.
# Row 2709 does not have new unique columns to add.
# Row 2710 does not have new unique columns to add.
# Row 2711 does not have new unique columns to add.
# Row 2712 does not have new unique columns to add.
# Row 2713 does not have new unique columns to add.
# Row 2714 does not have new unique columns to add.
# Row 2715 does not have new unique columns to add.
# Row 2716 does not have new unique columns to add.
# Row 2717 does not have new unique columns to add.
# Row 2718 does not have new unique columns to add.
# Row 2719 does not have new unique columns to add.
# Row 2720 does not have new unique columns to add.
# Row 2721 does not have new unique columns to add.
# Row 2722 does not have new unique columns to add.
# Row 2723 does not have new unique columns to add.
# Row 2724 does not have new unique columns to add.
# Row 2725 does not have new unique columns to add.
# Row 2726 does not have new unique columns to add.
# Row 2727 does not have new unique columns to add.
# Row 2728 does not have new unique columns to add.
# Row 2729 does not have new unique columns to add.
# Row 2730 does not have new unique columns to add.
# Row 2731 does not have new unique columns to add.
# Row 2732 does not have new unique columns to add.
# Row 2733 does not have new unique columns to add.
# Row 2734 does not have new unique columns to add.
# Row 2735 does not have new unique columns to add.
# Row 2736 does not have new unique columns to add.
# Row 2737 does not have new unique columns to add.
# Row 2738 does not have new unique columns to add.
# Row 2739 does not have new unique columns to add.
# Row 2740 does not have new unique columns to add.
# Row 2741 does not have new unique columns to add.
# Row 2742 does not have new unique columns to add.
# Row 2743 does not have new unique columns to add.
# Row 2744 does not have new unique columns to add.
# Row 2745 does not have new unique columns to add.
# Row 2746 does not have new unique columns to add.
# Row 2747 does not have new unique columns to add.
# Row 2748 does not have new unique columns to add.
# Row 2751 does not have new unique columns to add.
# Row 2752 does not have new unique columns to add.
# Row 2753 does not have new unique columns to add.
# Row 2754 does not have new unique columns to add.
# Row 2757 does not have new unique columns to add.
# Row 2758 does not have new unique columns to add.
# Row 2759 does not have new unique columns to add.
# Row 2760 does not have new unique columns to add.
# Row 2761 does not have new unique columns to add.
# Row 2762 does not have new unique columns to add.
# Row 2763 does not have new unique columns to add.
# Row 2764 does not have new unique columns to add.
# Row 2765 does not have new unique columns to add.
# Row 2766 does not have new unique columns to add.
# Row 2767 does not have new unique columns to add.
# Row 2768 does not have new unique columns to add.
# Row 2769 does not have new unique columns to add.
# Row 2771 does not have new unique columns to add.
# Row 2772 does not have new unique columns to add.
# Row 2773 does not have new unique columns to add.
# Row 2774 does not have new unique columns to add.
# Row 2775 does not have new unique columns to add.
# Row 2777 does not have new unique columns to add.
# Row 2778 does not have new unique columns to add.
# Row 2779 does not have new unique columns to add.
# Row 2780 does not have new unique columns to add.
# Row 2781 does not have new unique columns to add.
# Row 2782 does not have new unique columns to add.
# Row 2783 does not have new unique columns to add.
# Row 2784 does not have new unique columns to add.
# Row 2785 does not have new unique columns to add.
# Row 2786 does not have new unique columns to add.
# Row 2787 does not have new unique columns to add.
# Row 2788 does not have new unique columns to add.
# Row 2789 does not have new unique columns to add.
# Row 2790 does not have new unique columns to add.
# Row 2791 does not have new unique columns to add.
# Row 2792 does not have new unique columns to add.
# Row 2793 does not have new unique columns to add.
# Row 2794 does not have new unique columns to add.
# Row 2795 does not have new unique columns to add.
# Row 2796 does not have new unique columns to add.
# Row 2797 does not have new unique columns to add.
# Row 2798 does not have new unique columns to add.
# Row 2799 does not have new unique columns to add.
# Row 2800 does not have new unique columns to add.
# Row 2801 does not have new unique columns to add.
# Row 2802 does not have new unique columns to add.
# Row 2803 does not have new unique columns to add.
# Row 2804 does not have new unique columns to add.
# Row 2805 does not have new unique columns to add.
# Row 2806 does not have new unique columns to add.
# Row 2807 does not have new unique columns to add.
# Row 2808 does not have new unique columns to add.
# Row 2809 does not have new unique columns to add.
# Row 2810 does not have new unique columns to add.
# Row 2812 does not have new unique columns to add.
# Row 2813 does not have new unique columns to add.
# Row 2816 does not have new unique columns to add.
# Row 2817 does not have new unique columns to add.
# Row 2818 does not have new unique columns to add.
# Row 2820 does not have new unique columns to add.
# Row 2821 does not have new unique columns to add.
# Row 2822 does not have new unique columns to add.
# Row 2823 does not have new unique columns to add.
# Row 2824 does not have new unique columns to add.
# Row 2825 does not have new unique columns to add.
# Row 2826 does not have new unique columns to add.
# Row 2827 does not have new unique columns to add.
# Row 2828 does not have new unique columns to add.
# Row 2829 does not have new unique columns to add.
# Row 2830 does not have new unique columns to add.
# Row 2831 does not have new unique columns to add.
# Row 2832 does not have new unique columns to add.
# Row 2833 does not have new unique columns to add.
# Row 2834 does not have new unique columns to add.
# Row 2835 does not have new unique columns to add.
# Row 2836 does not have new unique columns to add.
# Row 2837 does not have new unique columns to add.
# Row 2838 does not have new unique columns to add.
# Row 2839 does not have new unique columns to add.
# Row 2840 does not have new unique columns to add.
# Row 2841 does not have new unique columns to add.
# Row 2842 does not have new unique columns to add.
# Row 2843 does not have new unique columns to add.
# Row 2844 does not have new unique columns to add.
# Row 2845 does not have new unique columns to add.
# Row 2846 does not have new unique columns to add.
# Row 2847 does not have new unique columns to add.
# Row 2848 does not have new unique columns to add.
# Row 2849 does not have new unique columns to add.
# Row 2850 does not have new unique columns to add.
# Row 2851 does not have new unique columns to add.
# Row 2852 does not have new unique columns to add.
# Row 2853 does not have new unique columns to add.
# Row 2854 does not have new unique columns to add.
# Row 2855 does not have new unique columns to add.
# Row 2856 does not have new unique columns to add.
# Row 2857 does not have new unique columns to add.
# Row 2858 does not have new unique columns to add.
# Row 2859 does not have new unique columns to add.
# Row 2860 does not have new unique columns to add.
# Row 2861 does not have new unique columns to add.
# Row 2862 does not have new unique columns to add.
# Row 2863 does not have new unique columns to add.
# Row 2864 does not have new unique columns to add.
# Row 2865 does not have new unique columns to add.
# Row 2866 does not have new unique columns to add.
# Row 2867 does not have new unique columns to add.
# Row 2868 does not have new unique columns to add.
# Row 2869 does not have new unique columns to add.
# Row 2870 does not have new unique columns to add.
# Row 2871 does not have new unique columns to add.
# Row 2872 does not have new unique columns to add.
# Row 2873 does not have new unique columns to add.
# Row 2874 does not have new unique columns to add.
# Row 2875 does not have new unique columns to add.
# Row 2876 does not have new unique columns to add.
# Row 2877 does not have new unique columns to add.
# Row 2878 does not have new unique columns to add.
# Row 2879 does not have new unique columns to add.
# Row 2880 does not have new unique columns to add.
# Row 2881 does not have new unique columns to add.
# Row 2882 does not have new unique columns to add.
# Row 2883 does not have new unique columns to add.
# Row 2884 does not have new unique columns to add.
# Row 2885 does not have new unique columns to add.
# Row 2886 does not have new unique columns to add.
# Row 2887 does not have new unique columns to add.
# Row 2888 does not have new unique columns to add.
#         ABL1    ACADM    ACAT1     ACO2     ADA     AKT1     AKT2  ALDH1A2  \
# 0    11.1922   9.8565  10.6013  11.0607  6.9935  11.8391  11.0237   5.5665
# 1     9.7755   8.5877   9.6203  11.5186  7.9402  12.8907  11.4956   4.8889
# 2    11.3155  10.4236   9.8686  11.3374  7.7755  11.6033  11.6151   6.9614
# 3    10.6537  11.4840   8.8371  11.3729  5.5148  12.2656  12.0471   5.8103
# 4    10.2955   9.0557   9.3345  10.4181  8.6322  12.0699  11.4128   1.9008
# ..       ...      ...      ...      ...     ...      ...      ...      ...
# 765  10.4632  10.0001  11.4173  10.7544  7.8649  11.6967  10.9855   5.8199
# 766  11.6356   8.6519  10.7598  11.9914  7.5397  12.1868  12.8083   3.1336
# 767  11.4497  10.7140  10.3352  11.2001  6.6691  12.7403  11.6774   7.7411
# 768  10.4021   9.2604  10.6261  11.6921  8.7099  13.1232  11.0644   3.5396
# 769  10.6078  10.5369  10.3567  11.1495  6.9656  12.2580  11.0204   5.2121
#
#      ALDH1A3  ALOX15B  ...    SURF1   UQCR10   UQCR11    UQCRB   UQCRC2  \
# 0     9.8314   8.3599  ...   9.3959   9.3948   9.5402  11.0453  11.5041
# 1     8.2605   5.8519  ...   9.9592  11.0420  10.9705  12.3146  11.3483
# 2     9.1619  12.6663  ...   9.3351   9.8759  10.1307  11.3989  11.6124
# 3     6.1662   3.7653  ...   9.8281  10.5420  10.3690  11.6772  12.0496
# 4     9.5649   4.5994  ...   9.3037  10.5910  10.1829  12.3978  10.3072
# ..       ...      ...  ...      ...      ...      ...      ...      ...
# 765   7.9579   9.4490  ...   9.9846  10.9903  10.8845  11.8077  11.8706
# 766   8.6952   5.0729  ...   9.7506  10.5215  10.0663  10.9821  11.9018
# 767   8.1145   5.0381  ...   9.3969   9.6158  10.3063  11.4330  11.1893
# 768   6.0385   6.8356  ...  10.5980  11.4647  11.2425  12.1177  12.2192
# 769   9.7595   6.0128  ...   8.8454  10.1918   9.7794  12.7210  11.3775
#
#      UQCRFS1   UQCRHL    UQCRH   WDR93     CGB7
# 0    10.3084   7.2733   9.3964  5.4703  1.01410
# 1    11.9523  10.7069  12.8206  3.4653  5.16440
# 2    10.0885   8.3823  10.2502  4.5986  2.39290
# 3    11.1781   8.7979  10.6588  3.5877  0.39500
# 4     9.6428   9.7032  11.9100  4.0035  0.75150
# ..       ...      ...      ...     ...      ...
# 765  10.5575   8.4381  10.8952  6.7766  1.56260
# 766   9.7408   7.7471  10.0362  5.9552  1.11530
# 767  10.5109   9.0697  11.0288  3.6354  1.43788
# 768  11.1764   9.0552  10.9535  5.6958  3.63070
# 769  10.4752   8.5671  10.7959  4.9845  1.23430
#
# [770 rows x 11094 columns]

# %%
BRCA_RNAseq.to_csv('../../DATA/BRCA/BRCA_RNAseq.csv', index=False)
